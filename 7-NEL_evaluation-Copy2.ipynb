# %%
# https://towardsdatascience.com/calculating-string-similarity-in-python-276e18a7d33a
# https://pypi.org/project/fuzzywuzzy/
# https://www.adamsmith.haus/python/answers/how-to-find-a-similarity-metric-between-two-strings-in-python


from transformers import T5TokenizerFast, T5ForConditionalGeneration 
from transformers import Trainer

import os

os.environ["CUDA_VISIBLE_DEVICES"] = "1,2,3" 
import pandas as pd
import numpy as np
import torch
import torchvision
import Levenshtein
from fuzzywuzzy import fuzz


device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
# device = torch.device("cuda:2") if torch.cuda.is_available() else torch.device("cpu")

# %%
# Create torch dataset
# https://towardsdatascience.com/fine-tuning-pretrained-nlp-models-with-huggingfaces-trainer-6326a4456e7b

class Dataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels=None):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        if self.labels:
            item["labels"] = torch.tensor(self.labels['input_ids'][idx])
        return item

    def __len__(self):
        return len(self.encodings["input_ids"])

# %%
def get_levenshtein_dis(str_1, str_2):
    return Levenshtein.distance(str_1, str_2)

# %%
def get_fuzzy_ration(str_1, str_2):
    return fuzz.ratio(str_1, str_2)

# %%
max_source_length = 1024
max_target_length = 128

# %%
tokenizer = T5TokenizerFast.from_pretrained("t5-base")
model_path = "./NEL_model_normal_shuffled/checkpoint-8500"
model = T5ForConditionalGeneration.from_pretrained(model_path).to(device)

# %% [markdown]
# ## testing with the shuffled data

# %%
test_data = pd.read_csv('./2-NEL_Data/2-csv_format_2/test_data_shuffled.csv')
test_data = test_data.sample(frac=1, random_state=1)
test_data
# Out:
#            qid                                           question  \
# 5758  Q1891138  **what kind of music does the go-betweens perf...
# 5975   Q838368                   **Name a black-and-white film.**
# 1984  Q2659421  **is evilenko a animation or crime fiction film**
# 5832   Q557632  **Which English band is on the record label de...
# 1945     Q9036     **What company was named after nikola tesla?**
# ...        ...                                                ...
# 2895  Q7913657                 **what type of music is van she?**
# 7813  Q3134980     **what is located in the mountain time zone?**
# 905   Q4952351                    **Which gender is boyd irwin?**
# 5192    Q33999                                 **Name an actor.**
# 235   Q1660749  **what country did needful things take place in**
#
#                       entity  \
# 5758     **the go-betweens**
# 5975     **black-and-white**
# 1984            **evilenko**
# 5832               **decca**
# 1945        **nikola tesla**
# ...                      ...
# 2895             **van she**
# 7813  **mountain time zone**
# 905           **boyd irwin**
# 5192               **actor**
# 235       **needful things**
#
#                                          wikidata_reply
# 5758  **[[Q1891138, The Go-Betweens, Australian indi...
# 5975  **[[Q2407593, White and Black in chess, chess ...
# 1984  **[[Q2659421, Evilenko, 2004 film directed by ...
# 5832  **[[Q3338174, Echinochloa colona, species of p...
# 1945  **[[Q16085077, Nicola Tesla, 1977 TV series], ...
# ...                                                 ...
# 2895  **[[Q945687, Van She, Electropop band from Syd...
# 7813  **[[Q3134980, Mountain Time Zone, time zone of...
# 905     **[[Q4952351, Boyd Irwin, actor (1880-1957)]]**
# 5192  **[[Q421946, actor, person performing an actio...
# 235   **[[Q2145196, Needful Things, Wikimedia disamb...
#
# [9921 rows x 4 columns]

# %%
input_text = list(test_data['question'] + ',' + test_data['entity'] + ',' + test_data['wikidata_reply'])
input_text[0]
# Out:
# '**what kind of music does the go-betweens perform**,**the go-betweens**,**[[Q1891138, The Go-Betweens, Australian indie rock band]]**'

# %%
target_text = list(test_data['qid'])
target_text[0]
# Out:
# 'Q1891138'

# %%
X_test_tokenized = tokenizer(['nel: ' + sequence for sequence in input_text], 
                              padding=True, 
                              truncation=True, 
                              max_length=max_source_length)

y_test_tokenized = tokenizer(target_text, 
                              padding=True, 
                              truncation=True, 
                              max_length=max_target_length)

print(len(test_data))
# Out:
# 9921

# %%
from transformers import Seq2SeqTrainingArguments

test_args = Seq2SeqTrainingArguments(
    "test_trainer",
    per_device_train_batch_size = 2,
    per_device_eval_batch_size = 2,
    eval_accumulation_steps = 50,  # VIP
    predict_with_generate=True
)

# %%
from transformers import Seq2SeqTrainer

trainer = Seq2SeqTrainer(
    model=model, 
    args=test_args
#     train_dataset= train_dataset, 
#     eval_dataset= eval_dataset
)

# %%
test_dataset = Dataset(X_test_tokenized, y_test_tokenized)

# %%
#     # Define test trainer
# test_trainer = Seq2SeqTrainer(model, args=test_args, tokenizer=tokenizer)

#     # Make prediction
# raw_pred = test_trainer.predict(test_dataset)''

# %%
# predicitons = tokenizer.batch_decode(raw_pred[1], skip_special_tokens=True)
# predicitons'

# %%
tokens = []
for text in input_text:
    tokens.append(tokenizer('nel: ' + text, return_tensors="pt", padding=True, truncation=True, max_length=512).input_ids)

# %%
results = []
model = model.to(device)

for token in tokens:
    results.append(model.generate(token.to(device)))

# %%
final_ouput_2 = []
for result in results:
    final_ouput_2.append(tokenizer.decode(result[0], skip_special_tokens=True))

# %%
# counter = 0
# for i in range(len(final_ouput_2)):
#     if final_ouput_2[i] != predicitons[i]:
#         print(target_text[i] + "    " + final_ouput_2[i] + "    " + predicitons[i])
#         counter += 1
# counter

# %%
# counter = 0
# for i in range(len(final_ouput_2)):
#     if predicitons[i] != target_text[i]:
#         counter += 1
# 1- counter/len(predicitons)

# %%
counter = 0
for i in range(len(final_ouput_2)):
    if final_ouput_2[i] != target_text[i]:
        counter += 1
1- counter/len(final_ouput_2)
# Out:
# 0.892450357826832

# %%
wikidata_data = list(test_data['wikidata_reply'])

# %%
import re
entities = []
for wiki_reply in wikidata_data:
    entities.append(re.findall(r'\[+(Q.*?),', wiki_reply))
len(entities)
# Out:
# 9921

# %%
final_copy = final_ouput_2.copy()
for i in range(len(final_copy)):
    min_value = 10000
    value_to_add = ''
    for entity in entities[i]:
        if get_levenshtein_dis(entity, final_ouput_2[i]) < min_value:
            min_value =  get_levenshtein_dis(entity, final_ouput_2[i])
            value_to_add = entity
    final_copy[i] = value_to_add

# %%
counter = 0
for i in range(len(final_copy)):
    if final_copy[i] != target_text[i]:
        counter += 1
1- counter/len(final_copy)
# Out:
# 0.8917447837919564

# %%
final_copy_3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-366534b4d624> in <module>
# ----> 1 final_copy_3
#
# NameError: name 'final_copy_3' is not defined

# %%
final_copy_3 = final_ouput_2.copy()
for i in range(len(final_copy)):
    diff = 10000
    value_to_add = ''
    for entity in entities[i]:
        try:
            if abs(int(entity[1:]) -  int(final_ouput_2[i][1:])) < diff:
                diff =  abs(int(entity[1:]) -  int(final_ouput_2[i][1:]))
                value_to_add = entity
        except:
            pass
    final_copy_3[i] = value_to_add

# %%
counter = 0
for i in range(len(final_copy_3)):
    if final_copy_3[i] != target_text[i]:
        counter += 1
1- counter/len(final_copy_3)
# Out:
# 0.8941045830809611

# %%
final_copy_2 = final_ouput_2.copy()
for i in range(len(final_copy_2)):
    max_value = -10000
    value_to_add = ''
    for entity in entities[i]:
        if get_levenshtein_dis(entity, final_ouput_2[i]) > max_value:
            max_value =  get_fuzzy_ration(entity, final_ouput_2[i])
            value_to_add = entity
    final_copy_2[i] = value_to_add
    print(max_value)
# Out:
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 36
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 24
# 100
# 100
# 100
# 100
# 57
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 36
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 36
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 57
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 50
# 50
# 100
# 100
# 100
# 46
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 62
# 100
# 100
# 36
# 100
# 50
# 100
# 50
# 25
# 100
# 100
# 59
# 33
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 71
# 100
# 35
# 100
# 100
# 100
# 100
# 27
# 100
# 100
# 88
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 36
# 100
# 100
# 57
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 46
# 100
# 100
# 53
# 100
# 47
# 29
# 100
# 100
# 100
# 86
# 100
# 88
# 27
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 57
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 44
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 33
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 94
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 67
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 25
# 43
# 24
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 31
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 88
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 62
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 25
# 100
# 33
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 40
# 43
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 88
# 100
# 100
# 40
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 33
# 100
# 62
# 100
# 62
# 100
# 100
# 100
# 100
# 50
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 12
# 22
# 100
# 100
# 100
# 100
# 100
# 50
# 36
# 100
# 100
# 100
# 100
# 59
# 100
# 100
# 100
# 100
# 100
# 100
# 60
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 57
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 31
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 33
# 100
# 100
# 100
# 33
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 40
# 38
# 100
# 100
# 100
# 100
# 88
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 24
# 100
# 40
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 44
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 27
# 100
# 100
# 100
# 100
# 100
# 100
# 56
# 100
# 100
# 100
# 100
# 100
# 100
# 57
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 35
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 53
# 100
# 100
# 27
# 40
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 46
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 46
# 100
# 40
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 47
# 100
# 38
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 50
# 100
# 100
# 43
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 86
# 100
# 100
# 100
# 36
# 100
# 100
# 100
# 100
# 50
# 100
# 67
# 100
# 62
# 100
# 27
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 38
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 86
# 100
# 44
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 27
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 25
# 100
# 47
# 50
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 67
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 56
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 40
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 44
# 100
# 100
# 100
# 100
# 100
# 100
# 59
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 67
# 100
# 100
# 100
# 100
# 100
# 57
# 100
# 100
# 100
# 35
# 17
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 31
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 31
# 100
# 100
# 100
# 27
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 88
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 40
# 100
# 100
# 100
# 100
# 53
# 100
# 57
# 40
# 100
# 100
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 20
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 40
# 100
# 100
# 100
# 100
# 100
# 86
# 35
# 27
# 100
# 100
# 100
# 88
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 44
# 100
# 83
# 100
# 29
# 100
# 46
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 46
# 100
# 31
# 100
# 100
# 25
# 33
# 43
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 27
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 62
# 100
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 62
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 62
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 24
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 57
# 100
# 100
# 100
# 100
# 100
# 50
# 27
# 100
# 100
# 100
# 100
# 100
# 62
# 27
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 13
# 100
# 100
# 100
# 100
# 44
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 44
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 67
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 88
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 22
# 35
# 57
# 88
# 100
# 100
# 62
# 35
# 100
# 100
# 100
# 100
# 31
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 35
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 24
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 53
# 100
# 100
# 100
# 38
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 88
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 38
# 25
# 35
# 100
# 100
# 100
# 100
# 100
# 40
# 43
# 100
# 35
# 29
# 100
# 38
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 57
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 46
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 46
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 31
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 36
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 33
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 33
# 100
# 100
# 53
# 100
# 50
# 50
# 100
# 100
# 29
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 44
# 100
# 100
# 53
# 100
# 100
# 43
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 53
# 100
# 100
# 47
# 100
# 100
# 100
# 88
# 40
# 31
# 100
# 100
# 100
# 40
# 100
# 100
# 31
# 100
# 100
# 50
# 100
# 100
# 35
# 33
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 57
# 100
# 46
# 100
# 100
# 27
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 88
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 29
# 47
# 100
# 38
# 100
# 62
# 100
# 100
# 100
# 100
# 93
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 88
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 40
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 27
# 43
# 100
# 100
# 100
# 46
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 31
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 31
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 25
# 100
# 100
# 43
# 40
# 100
# 88
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 27
# 100
# 27
# 100
# 100
# 29
# 35
# 100
# 100
# 100
# 100
# 46
# 100
# 22
# 24
# 57
# 25
# 100
# 100
# 100
# 59
# 100
# 100
# 100
# 59
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 27
# 53
# 40
# 100
# 33
# 100
# 47
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 24
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 27
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 31
# 100
# 100
# 100
# 100
# 43
# 100
# 31
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 14
# 100
# 100
# 56
# 100
# 40
# 100
# 100
# 100
# 100
# 33
# 100
# 100
# 100
# 88
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 93
# 57
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 62
# 100
# 67
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 57
# 100
# 100
# 100
# 88
# 59
# 100
# 100
# 100
# 93
# 100
# 100
# 25
# 100
# 100
# 57
# 100
# 100
# 100
# 100
# 100
# 100
# 36
# 100
# 100
# 40
# 100
# 33
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 31
# 46
# 100
# 100
# 62
# 40
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 67
# 35
# 100
# 100
# 50
# 27
# 100
# 100
# 100
# 33
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 31
# 100
# 100
# 100
# 100
# 100
# 100
# 75
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 59
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 27
# 100
# 100
# 22
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 75
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 31
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 59
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 88
# 100
# 100
# 100
# 100
# 100
# 43
# 62
# 100
# 67
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 86
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 43
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 29
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 67
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 46
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 55
# 100
# 100
# 100
# 31
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 43
# 50
# 100
# 100
# 100
# 100
# 57
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 46
# 100
# 100
# 100
# 27
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 27
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 27
# 50
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 40
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 62
# 100
# 40
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 24
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 33
# 27
# 100
# 100
# 100
# 100
# 100
# 100
# 56
# 31
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 50
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 27
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 20
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 33
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 47
# 100
# 100
# 57
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 62
# 100
# 53
# 31
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 75
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 31
# 100
# 53
# 88
# 100
# 22
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 59
# 36
# 100
# 29
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 88
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 22
# 57
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 57
# 100
# 100
# 100
# 100
# 60
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 31
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 31
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 59
# 100
# 100
# 100
# 100
# 27
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 35
# 27
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 93
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 38
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 29
# 47
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 33
# 100
# 100
# 100
# 100
# 27
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 94
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 25
# 100
# 46
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 43
# 100
# 100
# 100
# 40
# 100
# 100
# 88
# 12
# 100
# 27
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 38
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 38
# 100
# 62
# 100
# 100
# 100
# 100
# 100
# 31
# 31
# 100
# 100
# 100
# 100
# 46
# 100
# 33
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 31
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 62
# 100
# 40
# 40
# 46
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 47
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 13
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 88
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 88
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 31
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 40
# 38
# 100
# 100
# 100
# 100
# 47
# 100
# 57
# 40
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 36
# 100
# 100
# 100
# 100
# 100
# 57
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 31
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 67
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 88
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 50
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 47
# 100
# 100
# 27
# 100
# 46
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 50
# 100
# 100
# 100
# 100
# 94
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 24
# 100
# 100
# 100
# 24
# 100
# 100
# 100
# 100
# 40
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 88
# 50
# 100
# 100
# 38
# 100
# 100
# 24
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 46
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 46
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 67
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 18
# 100
# 43
# 100
# 100
# 62
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 62
# 100
# 33
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 62
# 100
# 100
# 43
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 47
# 40
# 100
# 100
# 100
# 100
# 25
# 57
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 42
# 100
# 86
# 88
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 31
# 100
# 100
# 47
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 57
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 88
# 25
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 62
# 100
# 100
# 100
# 100
# 38
# 40
# 100
# 100
# 100
# 100
# 100
# 27
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 25
# 100
# 38
# 100
# 100
# 40
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 47
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 27
# 100
# 100
# 100
# 100
# 100
# 100
# 88
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 33
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 88
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 50
# 43
# 100
# 100
# 100
# 100
# 29
# 100
# 88
# 100
# 100
# 57
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 44
# 38
# 100
# 100
# 100
# 53
# 100
# 100
# 40
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 44
# 100
# 100
# 35
# 100
# 100
# 100
# 88
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 46
# 100
# 100
# 100
# 40
# 38
# 27
# 100
# 100
# 100
# 40
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 62
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 24
# 100
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 38
# 100
# 100
# 88
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 57
# 100
# 62
# 100
# 22
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 75
# 24
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 18
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 36
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 40
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 33
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 67
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 59
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 57
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 27
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 31
# 100
# 100
# 29
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 25
# 100
# 100
# 29
# 100
# 50
# 100
# 44
# 53
# 100
# 100
# 100
# 100
# 100
# 35
# 33
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 25
# 100
# 100
# 53
# 100
# 31
# 100
# 100
# 38
# 100
# 38
# 100
# 100
# 31
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 46
# 100
# 100
# 47
# 47
# 38
# 100
# 43
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 29
# 100
# 100
# 43
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 44
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 25
# 22
# 100
# 43
# 40
# 100
# 100
# 83
# 33
# 100
# 100
# 36
# 100
# 100
# 100
# 100
# 100
# 100
# 33
# 100
# 100
# 100
# 38
# 100
# 100
# 38
# 100
# 47
# 100
# 100
# 100
# 40
# 43
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 71
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 14
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 38
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 67
# 50
# 100
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 25
# 43
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 57
# 47
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 25
# 88
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 29
# 100
# 27
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 71
# 46
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 24
# 100
# 100
# 100
# 100
# 100
# 88
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 27
# 25
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 88
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 88
# 100
# 100
# 100
# 100
# 75
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 46
# 100
# 100
# 33
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 27
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 25
# 100
# 40
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 38
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 38
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 67
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 44
# 53
# 100
# 100
# 31
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 47
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 55
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 31
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 33
# 100
# 100
# 62
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 59
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 36
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 46
# 67
# 100
# 100
# 100
# 100
# 100
# 100
# 22
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 88
# 46
# 100
# 100
# 57
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 31
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 14
# 100
# 40
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 44
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 35
# 100
# 47
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 46
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 27
# 100
# 100
# 100
# 100
# 100
# 40
# 88
# 100
# 100
# 50
# 100
# 100
# 47
# 100
# 100
# 100
# 47
# 100
# 27
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 56
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 40
# 100
# 40
# 100
# 100
# 31
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 88
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 57
# 100
# 100
# 100
# 40
# 55
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 86
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 59
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 50
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 50
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 24
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 71
# 40
# 35
# 71
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 17
# 100
# 100
# 100
# 100
# 62
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 46
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 36
# 100
# 100
# 38
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 27
# 36
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 36
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 62
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 57
# 100
# 100
# 50
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 27
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 31
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 46
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 33
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 31
# 100
# 100
# 100
# 100
# 100
# 100
# 27
# 100
# 57
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 31
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 93
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 62
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 38
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 59
# 59
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 22
# 100
# 100
# 100
# 27
# 35
# 100
# 53
# 100
# 100
# 100
# 38
# 100
# 62
# 100
# 100
# 100
# 33
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 44
# 100
# 100
# 100
# 100
# 100
# 100
# 56
# 100
# 100
# 100
# 31
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 82
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 31
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 44
# 100
# 100
# 40
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 44
# 100
# 100
# 100
# 100
# 100
# 25
# 62
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 59
# 40
# 100
# 100
# 100
# 59
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 13
# 100
# 33
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 31
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 24
# 100
# 35
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 40
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 27
# 100
# 100
# 100
# 100
# 15
# 100
# 35
# 38
# 100
# 100
# 33
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 40
# 33
# 27
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 15
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 100
# 24
# 100
# 100
# 100
# 100
# 100
# 38
# 24
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 43
# 12
# 22
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 27
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 57
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 33
# 53
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 25
# 100
# 50
# 100
# 100
# 100
# 100
# 27
# 100
# 100
# 46
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 44
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 40
# 33
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 22
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 33
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 47
# 100
# 38
# 40
# 100
# 100
# 100
# 100
# 38
# 40
# 100
# 100
# 100
# 100
# 100
# 50
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 33
# 100
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 31
# 100
# 27
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 47
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 15
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 94
# 100
# 100
# 40
# 40
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 86
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 95
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 75
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 25
# 47
# 62
# 100
# 100
# 100
# 100
# 100
# 100
# 31
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 59
# 100
# 100
# 100
# 100
# 100
# 77
# 100
# 100
# 25
# 100
# 100
# 47
# 100
# 100
# 31
# 38
# 100
# 67
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 33
# 100
# 100
# 47
# 100
# 50
# 100
# 100
# 100
# 62
# 27
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 43
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 29
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 36
# 100
# 100
# 100
# 100
# 100
# 100
# 62
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 27
# 100
# 100
# 100
# 88
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 15
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 27
# 100
# 100
# 38
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 38
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 27
# 100
# 100
# 100
# 100
# 100
# 38
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 27
# 100
# 100
# 100
# 50
# 100
# 40
# 50
# 100
# 100
# 46
# 100
# 38
# 86
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 33
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 57
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 33
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 14
# 100
# 40
# 100
# 100
# 29
# 43
# 100
# 100
# 100
# 29
# 88
# 100
# 100
# 100
# 100
# 59
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 75
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 46
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 27
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 50
# 20
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 55
# 100
# 100
# 27
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 88
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 27
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 38
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 24
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 44
# 100
# 100
# 100
# 100
# 100
# 47
# 38
# 100
# 100
# 100
# 27
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 36
# 62
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 56
# 47
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 57
# 50
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 38
# 100
# 100
# 100
# 50
# 100
# 100
# 31
# 100
# 18
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 36
# 100
# 100
# 57
# 47
# 100
# 100
# 100
# 100
# 100
# 24
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 31
# 100
# 43
# 31
# 100
# 100
# 100
# 100
# 100
# 62
# 44
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 59
# 100
# 53
# 100
# 38
# 100
# 100
# 100
# 57
# 35
# 35
# 100
# 100
# 17
# 100
# 47
# 33
# 100
# 100
# 100
# 100
# 100
# 40
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 14
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 24
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 67
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 33
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 27
# 100
# 100
# 40
# 100
# 100
# 100
# 57
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 43
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 62
# 100
# 100
# 100
# 100
# 100
# 100
# 88
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 40
# 100
# 100
# 100
# 27
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 57
# 100
# 100
# 100
# 100
# 100
# 25
# 100
# 100
# 75
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 20
# 100
# 100
# 100
# 31
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 46
# 43
# 100
# 100
# 100
# 88
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 31
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 18
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 40
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 46
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 55
# 100
# 100
# 43
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 33
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 46
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 38
# 43
# 100
# 62
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 100
# 44
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 62
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 88
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 62
# 100
# 43
# 100
# 14
# 100
# 100
# 13
# 27
# 100
# 100
# 100
# 59
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 86
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 46
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 36
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 33
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 88
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 60
# 100
# 100
# 100
# 100
# 57
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 25
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 50
# 31
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 14
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 36
# 88
# 100
# 100
# 35
# 100
# 53
# 100
# 100
# 93
# 35
# 43
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 13
# 100
# 100
# 100
# 100
# 100
# 100
# 44
# 100
# 100
# 100
# 62
# 100
# 50
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 18
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 57
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 25
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 88
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 44
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 94
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 50
# 100
# 27
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 27
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 33
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 62
# 100
# 47
# 24
# 100
# 100
# 100
# 100
# 100
# 100
# 33
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 46
# 50
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 93
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 24
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 36
# 100
# 100
# 100
# 15
# 100
# 100
# 100
# 100
# 100
# 24
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 44
# 100
# 100
# 57
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 44
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 44
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 31
# 100
# 27
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 25
# 62
# 100
# 100
# 100
# 100
# 100
# 14
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 13
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 14
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 75
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 38
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 27
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 44
# 100
# 53
# 100
# 100
# 100
# 100
# 27
# 100
# 47
# 50
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 57
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 40
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 44
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 57
# 100
# 100
# 88
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 88
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100

# %%
counter = 0
for i in range(len(final_copy_2)):
    if final_copy_2[i] != target_text[i]:
        counter += 1
1- counter/len(final_copy_2)
# Out:
# 0.8339390268524127

# %% [markdown]
# ## testing with the unshuffled data

# %%
test_data = pd.read_csv('./2-NEL_Data/2-csv_format_2/test_data.csv')
test_data = test_data.sample(frac=1, random_state=1)
test_data
# Out:
#             qid                                           question  \
# 8687    Q183862                **what album has metalcore music?**
# 7972   Q1641839               **Name an experimental rock album.**
# 1628  Q17285413                    **Where is joy sengupta from?**
# 8699    Q513674             **What is the sex of matthew breeze?**
# 5648   Q7333580               **what country is  tuxbury pond in**
# ...         ...                                                ...
# 2895    Q200092  **What is the name of a horror movie on netflix**
# 7813   Q7038198        **what kind of film is ninaithen vandhai?**
# 905     Q534599                    **Where did damon knight die?**
# 5192     Q21077   **what artist is signed to warner music group?**
# 235     Q507984         **which country is andrew thorndike from**
#
#                       entity  \
# 8687           **metalcore**
# 7972   **experimental rock**
# 1628        **joy sengupta**
# 8699      **matthew breeze**
# 5648        **tuxbury pond**
# ...                      ...
# 2895        **horror movie**
# 7813   **ninaithen vandhai**
# 905         **damon knight**
# 5192  **warner music group**
# 235     **andrew thorndike**
#
#                                          wikidata_reply
# 8687  **[[Q183862, metalcore, fusion genre of heavy ...
# 7972  **[[Q1641839, experimental rock, type of music...
# 1628  **[[Q17285413, Joy Sengupta, Indian actor and ...
# 8699  **[[Q513674, Matthew Breeze, Australian soccer...
# 5648  **[[Q7333580, Tuxbury Pond, lake in Rockingham...
# ...                                                 ...
# 2895  **[[Q200092, horror film, film genre], [Q59051...
# 7813  **[[Q7038198, Ninaithen Vandhai, 1998 film by ...
# 905   **[[Q534599, Damon Knight, American science fi...
# 5192  **[[Q21077, Warner Music Group, American multi...
# 235   **[[Q507984, Andrew Thorndike, Film director, ...
#
# [9906 rows x 4 columns]

# %%
input_text = list(test_data['question'] + ',' + test_data['entity'] + ',' + test_data['wikidata_reply'])
input_text[0]
# Out:
# '**what album has metalcore music?**,**metalcore**,**[[Q183862, metalcore, fusion genre of heavy metal and hardcore punk], [Q108940567, Metalcore Superstars, album by One Morning Left], [Q4490718, melodic metalcore, subgenre of metalcore], [Q30587784, progressive metalcore, subgenre of metalcore], [Q3501147, gabber metal, fusion of gabber and metal], [Q1965804, Metalcore-bändide loend, Wikimedia list article]]**'

# %%
target_text = list(test_data['qid'])
target_text[0]
# Out:
# 'Q183862'

# %%
X_test_tokenized = tokenizer(['nel: ' + sequence for sequence in input_text], 
                              padding=True, 
                              truncation=True, 
                              max_length=max_source_length)

y_test_tokenized = tokenizer(target_text, 
                              padding=True, 
                              truncation=True, 
                              max_length=max_target_length)

print(len(test_data))
# Out:
# 9906

# %%
from transformers import Seq2SeqTrainingArguments

test_args = Seq2SeqTrainingArguments(
    "test_trainer",
    per_device_train_batch_size = 2,
    per_device_eval_batch_size = 2,
    eval_accumulation_steps = 50,  # VIP
    predict_with_generate=True
)
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
from transformers import Seq2SeqTrainer

trainer = Seq2SeqTrainer(
    model=model, 
    args=test_args
#     train_dataset= train_dataset, 
#     eval_dataset= eval_dataset
)

# %%
test_dataset = Dataset(X_test_tokenized, y_test_tokenized)

# %%
tokens = []
for text in input_text:
    tokens.append(tokenizer('nel: ' + text, return_tensors="pt", padding=True, truncation=True, max_length=512).input_ids)

# %%
results = []
model = model.to(device)

for token in tokens:
    results.append(model.generate(token.to(device)))

# %%
final_ouput_2 = []
for result in results:
    final_ouput_2.append(tokenizer.decode(result[0], skip_special_tokens=True))

# %%
counter = 0
for i in range(len(final_ouput_2)):
    if final_ouput_2[i] != target_text[i]:
        counter += 1
1- counter/len(final_ouput_2)
# Out:
# 0.8921865536038764

# %%
wikidata_data = list(test_data['wikidata_reply'])

# %%
import re
entities = []
for wiki_reply in wikidata_data:
    entities.append(re.findall(r'\[+(Q.*?),', wiki_reply))
len(entities)
# Out:
# 9906

# %%
final_copy = final_ouput_2.copy()
for i in range(len(final_copy)):
    min_value = 10000
    value_to_add = ''
    for entity in entities[i]:
        if get_levenshtein_dis(entity, final_ouput_2[i]) < min_value:
            min_value =  get_levenshtein_dis(entity, final_ouput_2[i])
            value_to_add = entity
    final_copy[i] = value_to_add

# %%
counter = 0
for i in range(len(final_copy)):
    if final_copy[i] != target_text[i]:
        counter += 1
1- counter/len(final_copy)
# Out:
# 0.8924894003634161
