# %%
# https://www.datacamp.com/tutorial/fuzzy-string-python
# https://towardsdatascience.com/fuzzy-string-matching-in-python-68f240d910fe#:~:text=Fuzzywuzzy%20is%20a%20python%20library,showcase%20them%20on%20one%20platform.

# %%
# !pip install wandb
# !pip install transformers
# !pip install sentencepiece

from transformers import T5TokenizerFast, T5ForConditionalGeneration 
from transformers import Trainer

import os

os.environ["CUDA_VISIBLE_DEVICES"] = "1,2,3" 
import pandas as pd
import numpy as np
import torch
import torchvision
import Levenshtein
from fuzzywuzzy import fuzz
from datasets import list_metrics
from sklearn.metrics import precision_recall_fscore_support

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# wandb.login()

# os.environ["WANDB_DISABLED"] = "true"

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# %%
# Create torch dataset
# https://towardsdatascience.com/fine-tuning-pretrained-nlp-models-with-huggingfaces-trainer-6326a4456e7b

class Dataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels=None):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        if self.labels:
            item["labels"] = torch.tensor(self.labels['input_ids'][idx])
        return item

    def __len__(self):
        return len(self.encodings["input_ids"])

# %%
# conellpp_test.to_csv('./1-NER_Data/1-csv_format/test/conell_test_data.csv', index = False)
# wikineural_test.to_csv('./1-NER_Data/1-csv_format/test/wiki_neural_test_data.csv', index = False)
# onto_test.to_csv('./1-NER_Data/1-csv_format/test/onto_test_data.csv', index = False)
# wnut_test.to_csv('./1-NER_Data/1-csv_format/test/wnut_test_data.csv', index = False)

# %%
def read_test_data(path):
    return pd.read_csv(path)

# %%
def encode_input_as_tokens(dataset):
    tokens = []
    for text in dataset["input_text"]:
        tokens.append(tokenizer('ner: ' + text, return_tensors="pt", padding=True, truncation=True, max_length=512).input_ids)
    return tokens

# %%
def predict_ner(model, tokens):
    results = []
    model = model.to(device)
    counter =0
    for token in tokens:
        results.append(model.generate(token.to(device))) 
        counter +=1
        if counter % 100==0:
            print(counter)
    return results

# %%
def decode_prediction(predicted_tokens):
    final_ouput_2 = []
    for result in predicted_tokens:
        final_ouput_2.append(tokenizer.decode(result[0], skip_special_tokens=True))
    return final_ouput_2

# %%
def compare_prediction_with_target(predictions, target_text):
    counter = 0
    for i in range(len(predictions)):
        if predictions[i] != target_text[i]:
            counter += 1
    return 1- counter/len(predictions)

# %%
def compute_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)
    precision, recall, f1, _ = precision_recall_fscore_support(labels, preds, average='binary')
    acc = accuracy_score(labels, preds)
    return {
        'accuracy': acc,
        'f1': f1,
        'precision': precision,
        'recall': recall
    }

# %%
max_source_length = 512
max_target_length = 128

# %%
tokenizer = T5TokenizerFast.from_pretrained("t5-base")
model_path = "./NER_normal/checkpoint-29000"
model = T5ForConditionalGeneration.from_pretrained(model_path).to(device)

# %%
# from transformers import Seq2SeqTrainingArguments

# test_args = Seq2SeqTrainingArguments(
#     "test_trainer",
#     per_device_train_batch_size = 8,
#     per_device_eval_batch_size = 8,
#     eval_accumulation_steps = 50,  # VIP
#     predict_with_generate=True
# )

# %%
# from transformers import Seq2SeqTrainer

# trainer = Seq2SeqTrainer(
#     model=model, 
#     args=test_args
# #     train_dataset= train_dataset, 
# #     eval_dataset= eval_dataset
# )

# %% [markdown]
# ## conell test data

# %%
conell_test_data = read_test_data('./1-NER_Data/1-csv_format/test/conell_test_data.csv')
conell_test_data
# Out:
#                                              input_text  \
# 0     SOCCER - JAPAN GET LUCKY WIN , CHINA IN SURPRI...
# 1                                           Nadim Ladki
# 2              AL-AIN , United Arab Emirates 1996-12-06
# 3     Japan began the defence of their Asian Cup tit...
# 4     But China saw their luck desert them in the se...
# ...                                                 ...
# 3444  It all culminated in the fact that I now have ...
# 3445  That is why this is so emotional a night for m...
# 3446  " It was the joy that we all had over the peri...
# 3447  Charlton managed Ireland for 93 matches , duri...
# 3448  He guided Ireland to two successive World Cup ...
#
#                                             target_text  word_count  NE_count  \
# 0                                       *JAPAN*,*CHINA*           9         2
# 1                                         *Nadim Ladki*           2         2
# 2                       *AL-AIN*,*United Arab Emirates*           5         4
# 3                           *Japan*,*Asian Cup*,*Syria*          24         4
# 4                                  *China*,*Uzbekistan*          23         2
# ...                                                 ...         ...       ...
# 3444                                          *Ireland*          17         1
# 3445                                         *Charlton*          13         1
# 3446                                                 **          27         0
# 3447                               *Charlton*,*Ireland*          24         2
# 3448  *Ireland*,*World Cup*,*European*,*Germany*,*Ir...          32         7
#
#       %_NE_in_sentence
# 0                  0.2
# 1                  1.0
# 2                  0.8
# 3                  0.2
# 4                  0.1
# ...                ...
# 3444               0.1
# 3445               0.1
# 3446               0.0
# 3447               0.1
# 3448               0.2
#
# [3449 rows x 5 columns]

# %%
conell_test_data['target_text'].str.len().hist()
# Out:
# <AxesSubplot:>

# %%
conell_tokens = encode_input_as_tokens(conell_test_data)

# %%
len(conell_tokens)
# Out:
# 3449

# %%
conell_pred = predict_ner(model, conell_tokens)
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400

# %%
conell_pred_decoded = decode_prediction(conell_pred)

# %%
conell_target_text = conell_test_data['target_text']

# %%
conell_accuracy = compare_prediction_with_target(conell_pred_decoded, conell_target_text)
conell_accuracy
# Out:
# 0.7929834734705712

# %%
# lower_normal
conell_accuracy = compare_prediction_with_target(conell_pred_decoded, conell_target_text)
conell_accuracy
# Out:
# 0.795592925485648

# %%
# predictions = pd.DataFrame({'predictions':conell_pred_decoded, 'actual':conell_target_text})

# %%
# predictions.to_csv('./1-NER_Data/2-predictions/lower_normal_conell.csv')

# %%
conell_false_pos = 0
conell_false_neg = 0
conell_true_pos = 0
conell_errors = 0

for i in range(len(conell_pred_decoded)):
    split_predicted_entities = conell_pred_decoded[i].split(',')
    split_target_entities = conell_target_text[i].split(',')
    
    for pred in split_predicted_entities:
        if pred in split_target_entities:
            conell_true_pos += 1
        else:
            print(split_predicted_entities) 
            print(split_target_entities)
            conell_errors += 1
        if len(split_predicted_entities) > len(split_target_entities):
            conell_false_pos += len(split_predicted_entities) - len(split_target_entities)
        elif len(split_predicted_entities) < len(split_target_entities):
            conell_false_neg += len(split_target_entities) - len(split_predicted_entities)
# Out:
# ['*JAPAN*', '*CHICA*']
# ['*JAPAN*', '*CHINA*']
# ['*China*', '*Uzbek*', '*Igor Shkvy']
# ['*China*', '*Uzbek*', '*Igor Shkvyrin*', '*Chinese*']
# ['*Takuya Takagi*', '*Hiroshige Yanagimoto*', '']
# ['*Takuya Takagi*', '*Hiroshige Yanagimoto*', '*Syrian*', '*Salem Bitar*']
# ['*UAE*', '*Kuwait*', '*South Korea*', '*Indon']
# ['*UAE*', '*Kuwait*', '*South Korea*', '*Indonesia*']
# ['*Cuttitta*', '*George Coste*', '*England']
# ['*Cuttitta*', '*George Coste*', '*England*', '*Twickenham*']
# ['*Stefano Bordon*', '*Coste*', '*Corrado Covi']
# ['*Stefano Bordon*', '*Coste*', '*Corrado Covi*', '*England*']
# ['*Cuttitta*', '*1995 World Cup*', '*It']
# ['*Cuttitta*', '*1995 World Cup*', '*Italy*', '*England*']
# ['*Javier Pertile*', '*Paolo Vaccari*', '']
# ['*Javier Pertile*', '*Paolo Vaccari*', '*Marcello Cuttitta*', '*Ivan Francescato*', '*Leandro Manteri*', '*Diego Dominguez*', '*Francesco Mazzariol*', '*Alessandro Troncon*', '*Orazio Arancio*', '*Andrea Sgorlon*', '*Massimo Giovanelli*', '*Carlo Checchinato*', '*Walter Cristofoletto*', '*Franco Properzi Curti*', '*Carlo Orlandi*', '*Massimo Cuttitta*', '*Giambatista Croci*', '*Gianluca Guidi*', '*Nicola Mazzucato*', '*Alessandro Moscardi*', '*Andrea Castellani*']
# ['*Nader Jokhadar*', '*Ammar Awad*', '*']
# ['*Nader Jokhadar*', '*Ammar Awad*', '*Kenichi Shimokawa*']
# ['*Bitar*', '*Kazuyoshi Miura*', '*T']
# ['*Bitar*', '*Kazuyoshi Miura*', '*Takagi*']
# ['*Japan*', '*Bitar*', '*Naoki Som']
# ['*Japan*', '*Bitar*', '*Naoki Soma*']
# ['*Japan*', '*Kenichi Shimokawa*', '*Hi']
# ['*Japan*', '*Kenichi Shimokawa*', '*Hiroshige Yanagimoto*', '*Naoki Soma*', '*Masami Ihara*', '*Norio Omura*', '*Motohiro Yamaguchi*', '*Masakiyo Maezono*', '*Yasuto Honda*', '*Takuya Takagi*', '*Hiroshi Nanami*', '*Kazuyoshi Miura*', '*Hiroaki Morishima*', '*Masayuki Okano*']
# ['*Syria*', '*Salem Bitar*', '*B']
# ['*Syria*', '*Salem Bitar*', '*Bachar Srour*', '*Hassan Abbas*', '*Tarek Jabban*', '*Ammar Awad*', '*Louay Taleb*', '*Nihad al-Boushi*', '*Mohammed Afash*', '*Ali Dib*', '*Abdul Latif Helou*', '*Ammar Rihawiy*', '*Khaled Zaher*', '*Nader Jokhadar*']
# ['*WORLD CUP*', '*MOGUL*']
# ['*SKIING-WORLD CUP*']
# ['*WORLD CUP*', '*MOGUL*']
# ['*SKIING-WORLD CUP*']
# ['*Dominic Gauthier*', '*Canada*']
# ['*Dominick Gauthier*', '*Canada*']
# ['*ASIAN CUP*', '*GROUP*']
# ['*ASIAN CUP*']
# ['*Japan*', '*Hassan Abbas*', '*Taku']
# ['*Japan*', '*Hassan Abbas*', '*Takuya Takagi*']
# ['*Shkvyrin Igor*', '*Shatskikh O']
# ['*Shkvyrin Igor*', '*Shatskikh Oleg*']
# ['*one-day*', '*Pakistan*', '*New Zealand*']
# ['*Pakistan*', '*New Zealand*']
# ['*Inzamamul Haq*', '*Germon*', '*Ast']
# ['*Inzamamul Haq*', '*Germon*', '*Astle*']
# ['*Waqar Younis*', '*Germon*', '*Harri']
# ['*Waqar Younis*', '*Germon*', '*Harris*']
# ['*Dull*', '*Kennedy*']
# ['*Doull*', '*Kennedy*']
# ['**']
# ['*Astle*']
# ['*C. Spearman*', '*Moin Khan*', '*Was']
# ['*C. Spearman*', '*Moin Khan*', '*Wasim*']
# ['*A. Parore*', '*Ijaz Ahmad*', '*Saq']
# ['*A. Parore*', '*Ijaz Ahmad*', '*Saqlain*']
# ['*N. Astle*', '*Ijaz Ahmad*', '*Salim']
# ['*N. Astle*', '*Ijaz Ahmad*', '*Salim Malik*']
# ['*J. Vaughan*', '*Moin Khan*', '*Was']
# ['*J. Vaughan*', '*Moin Khan*', '*Wasim*']
# ['*S. Doull*', '*M. Wasim*', '*Waqar']
# ['*S. Doull*', '*M. Wasim*', '*Waqar*']
# ['*Saqlain Mushtaq*', '*Mushtaq']
# ['*Saqlain Mushtaq*', '*Mushtaq Ahmad*']
# ['*ENGLISH*', '*F.A. CUP*']
# ['*ENGLISH F.A. CUP*']
# ['*ENGLISH*', '*F.A. CUP*']
# ['*ENGLISH F.A. CUP*']
# ['*English*']
# ['*English F.A. Challenge*']
# ['*BLINKER BAN*']
# ['*BLINKER*']
# ['*Dutch*', '*Reggie Blinker*', '*FIFA*', '']
# ['*Dutch*', '*Reggie Blinker*', '*FIFA*', '*Sheffield Wednesday*', '*Liverpool*']
# ['*Blinker*', '*FIFA*', '*Udinese*', '*']
# ['*Blinker*', '*FIFA*', '*Wednesday*', '*Udinese*', '*Feyenoord*']
# ['*Blinker*', '*Swiss*', '*Endllsh']
# ['*Blinker*', '*Swiss*', '*Engllsh*', '*Udinese*']
# ['*Leeds*', '*England*', '*Lee Bowyer*', '']
# ['*Leeds*', '*England*', '*Lee Bowyer*', "*McDonald's*"]
# ['*Bowyer*', '*Yorkshire*', '*Middlesb']
# ['*Bowyer*', '*Yorkshire*', '*Middlesbrough*']
# ['*EUROLEEAGUE*']
# ['*EUROLEAGUE*']
# ['*Jason Little*', '*Australia*', '*Barbarians*', '*T']
# ['*Jason Little*', '*Australia*', '*Barbarians*', '*Twickenham*']
# ['*Owen Finegan*', '*Wales*', '*Daniel Man']
# ['*Owen Finegan*', '*Wales*', '*Daniel Manu*']
# ['*Wallabies European*', '*David Campese Australian*']
# ['*Wallabies*', '*European*', '*David Campese*', '*Australian*']
# ['*Wallabies European*', '*David Campese Australian*']
# ['*Wallabies*', '*European*', '*David Campese*', '*Australian*']
# ['*Campese*', '*Barbarians*', '*Rob Andrew*', '*']
# ['*Campese*', '*Barbarians*', '*Rob Andrew*', '*Australia*', '*World Cup*', '*Cape Town*']
# ['*Australia*', '*Italy*', '*Scotland*', '*']
# ['*Australia*', '*Italy*', '*Scotland*', '*Ireland*', '*Wales*']
# ['*Barbarians*', '*England*', '*Tim Stimpson']
# ['*Barbarians*', '*England*', '*Tim Stimpson*', '*Tony Underwood*', '*All Black*', '*Ian Jones*', '*Norm Hewitt*']
# ['*Barbarians*', '*Tim Stimpson*', '*England']
# ['*Barbarians*', '*Tim Stimpson*', '*England*', '*Nigel Walker*', '*Wales*', '*Allan Bateman*', '*Wales*', '*Gregor Townsend*', '*Scotland*', '*Tony Underwood*', '*England*', '*Rob Andrew*', '*England*', '*Rob Howley*', '*Wales*', '*Scott Quinnell*', '*Wales*', '*Neil Back*', '*England*', '*Dale McIntosh*', '*Pontypridd*', '*Ian Jones*', '*New Zealand*', '*Craig Quinnell*', '*Wales*', '*Darren Garforth*', '*Leicester*', '*Norm Hewitt*', '*New Zealand*', '*Nick Popplewell*', '*Ireland*']
# ['*Zimbabwe Open*', '*Chapman Golf Club*', '*South African']
# ['*Zimbabwe Open*', '*Chapman Golf Club*', '*South African*', '*Des Terblanche*', '*Mark McNulty*', '*Zimbabwe*', '*Steve van Vuuren*', '*Nick Price*', '*Zimbabwe*', '*Justin Hobday*']
# ['*Andrew Pitts*', '*U.S.*', '*Mark Cay']
# ['*Andrew Pitts*', '*U.S.*', '*Mark Cayeux*', '*Zimbabwe*', '*Mark Murless*', '*Hennie Swart*', '*Andrew Park*', '*Schalk van der Merwe*', '*Namibia*', '*Desvonde*']
# ['*Botes*', '*Greg Reid*', '*Clinton White']
# ['*Botes*', '*Greg Reid*', '*Clinton Whitelaw*']
# ['*Brett Liddle*', '*Hugh Baiocchi*', '*']
# ['*Brett Liddle*', '*Hugh Baiocchi*', '*Adilson da Silva*', '*Brazil*', '*Sammy Daniels*']
# ['*Trevor Dodds*', '*Namibia*', '*Don Robert']
# ['*Trevor Dodds*', '*Namibia*', '*Don Robertson*', '*U.S.*', '*Dion Fourie*']
# ['*UNCAPPED*', '*MACEDONIA*']
# ['*MACEDONIA*']
# ['*Romania*', '*Anghel Iordanescu*', '*Mace']
# ['*Romania*', '*Anghel Iordanescu*', '*Macedonia*', '*World Cup*']
# ['*Valentin Stefan*', '*Viorel Ion*', '*O']
# ['*Valentin Stefan*', '*Viorel Ion*', '*Otelul Galati*', '*Liviu Ciobotariu*', '*National Bucharest*', '*European*', '*Macedonia*']
# ['*Iordanescu*', '*National Bucharest*', '*Otelul Gala']
# ['*Iordanescu*', '*National Bucharest*', '*Otelul Galati*']
# ["*Steaua Bucharest Champions'League*", '*European Cup*']
# ['*Steaua Bucharest*', "*Champions ' League*", '*European Cup*']
# ['*Adrian Ilie*', '*Steaua*', '*Turk']
# ['*Adrian Ilie*', '*Steaua*', '*Turkish*', '*Galatasaray*']
# ['*Bogdan Stelea*', '*Gillian Prunea*']
# ['*Bogdan Stelea*', '*Florin Prunea*']
# ['*Dan Petrescu*', '*Daniel Prodan*', '*Anton']
# ['*Dan Petrescu*', '*Daniel Prodan*', '*Anton Dobos*', '*Cornel Papura*', '*Liviu Ciobotariu*', '*Tibor Selymess*', '*Iulian Filipescu*']
# ['*Gheorghe Hagi*', '*Gheorghe Popescu*', '*Con']
# ['*Gheorghe Hagi*', '*Gheorghe Popescu*', '*Constantin Galca*', '*Valentin Stefan*', '*Basarab Panduru*', '*Dorinel Munteanu*', '*Ovidiu Stinga*']
# ['*Ioan Vladoiu*', '*Gheorghe Craiov']
# ['*Ioan Vladoiu*', '*Gheorghe Craioveanu*', '*Ionel Danciulescu*', '*Viorel Ion*']
# ['*BRAZILIAN*']
# ['*BRAZILIAN CHAMPIONSHIP*']
# ['*Australia*', '*Brian Lara*', '*West Indies*', '*World']
# ['*Australia*', '*Brian Lara*', '*West Indies*', '*World Series*']
# ['*Lara*', '*Australia*', '*Geoff Marsh*', '*Ian']
# ['*Lara*', '*Australia*', '*Geoff Marsh*', '*Ian Healy*']
# ['*AUSTRALIA*', '*WEST INDIES*', '*WORLD SER']
# ['*AUSTRALIA*', '*WEST INDIES*', '*WORLD SERIES*']
# ['*S. Chanderpaul*', '*Healy*', '*Ble']
# ['*S. Chanderpaul*', '*Healy*', '*Blewett*']
# ['*I. Healy*', '*P. Reiffel*', '*S.']
# ['*I. Healy*', '*P. Reiffel*', '*S. Warne*', '*J. Gillespie*']
# ['*Australia*', '*West Indies*', '*World Series*', '*Mel']
# ['*Australia*', '*West Indies*', '*World Series*', '*Melbourne Cricket Ground*']
# ['*OBART*', '*Australia*']
# ['*HOBART*', '*Australia*']
# ['*Sheffield Shield*', '*Tasmania*', '*Victori']
# ['*Sheffield Shield*', '*Tasmania*', '*Victoria*', '*Bellerive Oval*']
# ['*Tasmania*', '*David Boon*', '*Shaun']
# ['*Tasmania*', '*David Boon*', '*Shaun Young*', '*Michael DiVenuto*', '*Victoria*']
# ['*West Indies*', '*Brian Lara*', '*Australian*', '*']
# ['*West Indies*', '*Brian Lara*', '*Australian*', '*Australia*']
# ['*West Indies*', '*Tom Moody*', '*Shane Warn']
# ['*West Indies*', '*Tom Moody*', '*Shane Warne*']
# ['*West Indies*', '*Melbourne Cricket Ground*', '*Court']
# ['*West Indies*', '*Melbourne Cricket Ground*', '*Courtney Walsh*']
# ['*Clive Lloyd*', '*Lara*', '*Australia*', '*Geoff']
# ['*Clive Lloyd*', '*Lara*', '*Australia*', '*Geoff Marsh*']
# ['*WEST*']
# ['*WEST INDIES*']
# ['*West Indies*', '*Courtney Walsh*', '*World Series*', '']
# ['*West Indies*', '*Courtney Walsh*', '*World Series*', '*Australia*', '*Melbourne Cricket Ground*']
# ['*Australia*', '*Mark Taylor*', '*Mark Waugh*', '*Ricky']
# ['*Australia*', '*Mark Taylor*', '*Mark Waugh*', '*Ricky Ponting*', '*Greg Blewett*', '*Michael Bevan*', '*Stuart Law*', '*Tom Moody*', '*Ian Healy*', '*Paul Reiffel*', '*Shane Warne*', '*Jason Gillespie*', '*Glenn McGrath*']
# ['*West Indies*', '*Sherwin Campbell*', '*Robert Samuels']
# ['*West Indies*', '*Sherwin Campbell*', '*Robert Samuels*', '*Brian Lara*', '*Shivnarine Chanderpaul*', '*Carl Hooper*', '*Jimmy Adams*', '*Junior Murray*', '*Nixon McLean*', '*Kenneth Benjamin*', '*Curtly Ambrose*', '*Courtney Walsh*', '*Roland Holder*']
# ['*Chen Gang*', '*China*', '*Martin Londgaard Hansen']
# ['*Chen Gang*', '*China*', '*Martin Londgaard Hansen*', '*Denmark*']
# ['*Dong Jiong*', '*China*', '*Thomas Stuer-La']
# ['*Dong Jiong*', '*China*', '*Thomas Stuer-Lauridsen*', '*Denmark*']
# ['*Indra Wijaya*', '*Indonesia*', '*']
# ['*Indra Wijaya*', '*Indonesia*', '*Ong Ewe Hock*', '*Malaysia*']
# ['*Sun Jun*', '*China*', '*Rashid Sidek*', '*']
# ['*Sun Jun*', '*China*', '*Rashid Sidek*', '*Malaysia*']
# ['*Hermawan Susanto*', '*Indonesia*', '*']
# ['*Hermawan Susanto*', '*Indonesia*', '*Soren B. Nielsen*', '*Denmark*']
# ['*Budi Santoso*', '*Indonesia*', '']
# ['*Budi Santoso*', '*Indonesia*', '*Hu Zhilan*', '*China*']
# ['*Wijaya*', '*Indonesia*', '*S']
# ['*Wijaya*', '*Indonesia*', '*Sun Jun*', '*China*', '*Allan Budi Kusuma*']
# ['*Gong Zhichao*', '*China*', '*Mia Audi']
# ['*Gong Zhichao*', '*China*', '*Mia Audina*', '*Indonesia*']
# ['*Ye Zhaoying*', '*China*', '*Meiluawati']
# ['*Ye Zhaoying*', '*China*', '*Meiluawati*', '*Indonesia*']
# ['*Susi Susanti*', '*Indonesia*', '*']
# ['*Susi Susanti*', '*Indonesia*', '*Han Jingna*', '*China*']
# ['*Susi Susanti*', '*Indonesia*', '*']
# ['*Susi Susanti*', '*Indonesia*', '*Camilla Martin*', '*Denmark*', '*Ye Zhaoying*', '*China*', '*Gong Zichao*', '*China*']
# ['*ARAB*', "*AFRICAN CUP WINNERS'CUP"]
# ['*ARAB CONTRACTORS*', "*AFRICAN CUP WINNERS ' CUP*"]
# ['*ARAB*', "*AFRICAN CUP WINNERS'CUP"]
# ['*ARAB CONTRACTORS*', "*AFRICAN CUP WINNERS ' CUP*"]
# ["*African Cup Winners'Cup*", '*National stadium*', '*Arab']
# ["*African Cup Winners ' Cup*", '*National stadium*', '*Arab Contractors*', '*Egypt*', '*Sodigraf*', '*Zaire*']
# ["*African Cup Winners'Cup*", '*National stadium*', '*Arab']
# ["*African Cup Winners ' Cup*", '*National stadium*', '*Arab Contractors*', '*Egypt*', '*Sodigraf*', '*Zaire*']
# ['**']
# ['*Contractors*']
# ['**']
# ['*League*']
# ['*EASTERN*']
# ['*EASTERN CONFERENCE*']
# ['*NORTHEAST DIVISION*']
# ['**']
# ['*ATLANTIC DIVISION*']
# ['*ATLANTIC*']
# ['*WESTERN*']
# ['*WESTERN CONFERENCE*']
# ['*PACIFIC DIVISION*']
# ['*PACIFIC*']
# ['*NBA*', '*NHL*', '*La Clippers*', '*Ny']
# ['*NBA*', '*NHL*', '*La Clippers*', '*Ny Islanders*']
# ['**']
# ['*League*']
# ['*NFL*', '*AMERICAN*', '*EAGLES*']
# ['*NFL*', '*FOOTBALL-COLTS*', '*EAGLES*']
# ['*Indianapolis Colts*', '*AFC*', '*Philadelphi']
# ['*Indianapolis Colts*', '*AFC*', '*Philadelphia Eagles*']
# ['*Marshall Faulk*', '*Jason Belser*', '*']
# ['*Marshall Faulk*', '*Jason Belser*', '*Colts*', '*Eagles*']
# ['*Indianapolis*', '*Kansas City*', '*Cincin']
# ['*Indianapolis*', '*Kansas City*', '*Cincinnati*']
# ['*Philadelphia*', '*NFC East*', '*Dallas Cow']
# ['*Philadelphia*', '*NFC East*', '*Dallas Cowboys*', '*Washington Redskins*', '*New York Jets*', '*Arizona*']
# ['*Colts*', '*Tony Siragusa*', '*Ray Buch']
# ['*Colts*', '*Tony Siragusa*', '*Ray Buchanan*', '*Quentin Coryatt*']
# ['**']
# ['*National*']
# ['*EASTERN*']
# ['*EASTERN CONFERENCE*']
# ['*ATLANTIC DIVISION*']
# ['*ATLANTIC*']
# ['*WESTERN*']
# ['*WESTERN CONFERENCE*']
# ['*MIDWEST DIVISION*']
# ['**']
# ['*PACIFIC DIVISION*']
# ['*PACIFIC*']
# ['*INDIANA*', '*GOLDEN*']
# ['*INDIANA*', '*GOLDEN STATE*']
# ['*NFL AMERICAN*']
# ['*NFL*']
# ['*AMERICAN*']
# ['*AMERICAN FOOTBALL CONFERENCE*']
# ['*CLINCHED*', '*BERTH*']
# ['**']
# ['*CLINCHED*', '*BERTH*']
# ['**']
# ['*NY*', '*MIAMI*']
# ['*NY GIANTS*', '*MIAMI*']
# ['*NFL AMERICAN*']
# ['*NFL*']
# ['**']
# ['*League*']
# ['*NCAA AMERICAN*', '*OHIO*', '*LOMBARDI']
# ['*NCAA*', '*FOOTBALL-OHIO STATE*', '*PACE*', '*LOMBARDI AWARD*']
# ['*NCAA AMERICAN*', '*OHIO*', '*LOMBARDI']
# ['*NCAA*', '*FOOTBALL-OHIO STATE*', '*PACE*', '*LOMBARDI AWARD*']
# ['*NCAA AMERICAN*', '*OHIO*', '*LOMBARDI']
# ['*NCAA*', '*FOOTBALL-OHIO STATE*', '*PACE*', '*LOMBARDI AWARD*']
# ['*Ohio State*', '*Orlando Pace*', '*Lombard']
# ['*Ohio State*', '*Orlando Pace*', '*Lombardi Award*', '*Rotary Club*', '*Houston*']
# ['*Virginia Tech*', '*Cornell Brown*', '*Arizon']
# ['*Pace*', '*Virginia Tech*', '*Cornell Brown*', '*Arizona State*', '*Juan Roque*', '*Jared Tomich*', '*Nebraska*']
# ['*Lombardi Award*', '*Vince Lombardi*', '*']
# ['*Lombardi Award*', '*Vince Lombardi*', '*Green Bay Packers*']
# ['*FC Cologne*']
# ['*1. FC Cologne*']
# ['*Lens*', '*Nantes*', "*Japhet N'"]
# ['*Lens*', '*Nantes*', "*Japhet N'Doram*", '*Claude Makelele*', '*Jocelyn*']
# ['*RKC Waalwijk*', '*Starbuck*', '*Willem']
# ['*RKC Waalwijk*', '*Starbuck*', '*Willem II Tilburg*', '*Konterman*']
# ['*Bochum*', '*Stickelth*', '*Wosz*']
# ['*Bochum*', '*Stickroth*', '*Wosz*', '*Bayer Leverkusen*', '*Kirsten*', '*Ramelow*']
# ['*Werder Bremen*', '*Bode*', '*1860 Munich*', '*']
# ['*Werder Bremen*', '*Bode*', '*1860 Munich*', '*Bormirow*']
# ['*Grand Slam Cup*', '*Goran Ivanisevic*', '*C']
# ['*Grand Slam Cup*', '*Goran Ivanisevic*', '*Croatia*', '*Mark Woodforde*', '*Australia*']
# ['*Yevgeny Kafelnikov*', '*Russia*', '*J']
# ['*Yevgeny Kafelnikov*', '*Russia*', '*Jim Courier*', '*U.S.*']
# ['*WEAH*', '*PORTUGAL OF COSTA*']
# ['*WEAH*', '*PORTUGAL*', '*COSTA*']
# ['*Portugal*', '*Porto*', '*Joao Manuel Pinto']
# ['*Portugal*', '*Porto*', '*Joao Manuel Pinto*', '*Germany*', '*World Cup*', '*Jorge Costa*', '*Liberian*', '*Georg Weah*']
# ['*Costa*', '*AC Milan*', "*European Champions'League*"]
# ['*Costa*', '*AC Milan*', "*European Champions ' League*"]
# ['*Portugal*', '*European*', '*Ukraine*', '*German']
# ['*Portugal*', '*European*', '*Ukraine*', '*Germany*']
# ['*Vitor Baia*', '*Barcelona*', '*Spain']
# ['*Vitor Baia*', '*Barcelona*', '*Spain*', '*Rui Correia*', '*Braga*']
# ['*Paulinho Santos*', '*Porto*', '*Sergio Conce']
# ['*Paulinho Santos*', '*Porto*', '*Sergio Conceicao*', '*Porto*', '*Joao Manuel Pinto*', '*Porto*', '*Oceano Cruz*', '*Sporting*', '*Fernando Couto*', '*Barcelona*', '*Helder Cristovao*', '*Deportivo Coruna*', '*Spain*', '*Dimas Teixeira*', '*Juventus*', '*Italy*', '*Carlos Secretario*', '*Real Madrid*', '*Spain*']
# ['*Rui Barros*', '*Porto*', '*Jose Barros']
# ['*Rui Barros*', '*Porto*', '*Jose Barroso*', '*Porto*', '*Luis Figo*', '*Barcelona*', '*Paulo Bento*', '*Oviedo*', '*Spain*', '*Jose Taira*', '*Salamanca*', '*Spain*']
# ['*Antonio Folha*', '*Porto*', '*Joao']
# ['*Antonio Folha*', '*Porto*', '*Joao Vieira Pinto*', '*Benfica*', '*Paulo Alves*', '*Sporting*', '*Rui Costa*', '*Fiorentina*', '*Italy*', '*Jorge Cadete*', '*Celtic Glasgow*', '*Scotland*']
# ['*READ MADRID*', '*BARCELONA*']
# ['*REAL MADRID*', '*BARCELONA*']
# ['*Barcelona Real Madrid*']
# ['*Barcelona*', '*Real Madrid*']
# ['*Putin Popescu*']
# ['*Popescu*']
# ['*BREATHALYSER*']
# ['**']
# ['*Spanish*', '*Santiago Bernabeu*', '*Real']
# ['*Spanish*', '*Santiago Bernabeu stadium*', '*Real Madrid-Barcelona*', '*Madrid*', '*El Mundo*']
# ['*Spanish*', '*Santiago Bernabeu*', '*Real']
# ['*Spanish*', '*Santiago Bernabeu stadium*', '*Real Madrid-Barcelona*', '*Madrid*', '*El Mundo*']
# ['*UNCAPPED*', '*ARMANDO*', '*WORLD CUP*']
# ['*SPAIN*', '*ARMANDO*', '*WORLD CUP*']
# ['*Spain*', '*Javier Clemente*', '*Deporti']
# ['*Spain*', '*Javier Clemente*', '*Deportivo Coruna*', '*Armando Alvarez*', '*World Cup*', '*Yugoslavia*']
# ['*Armando*', '*Atletico Madrid*', '*Jose']
# ['*Armando*', '*Atletico Madrid*', '*Jose Luis Caminero*']
# ['*FIFA*', '*Joao Havelange*', '*AC Milan George We']
# ['*FIFA*', '*Joao Havelange*', '*AC Milan*', '*George Weah*', '*Porto*', '*Jorge Costa*']
# ['*Italian*', '*Gazetta dello Sport*', '*']
# ['*Italian*', '*Gazzetta dello Sport*', '*Weah*', '*Costa*']
# ['*Italian*', '*Gazetta dello Sport*', '*']
# ['*Italian*', '*Gazzetta dello Sport*', '*Weah*', '*Costa*']
# ['*FIFA*', '*Liberian*', '*Fair Play*', '*H']
# ['*FIFA*', '*Liberian*', '*Havelange*']
# ['*FIFA*', '*Liberian*', '*Fair Play*', '*H']
# ['*FIFA*', '*Liberian*', '*Havelange*']
# ['*Weah*', '*UEFA*', '*European soccer*']
# ['*Weah*', '*UEFA*', '*European*']
# ["*European Champions'League*"]
# ["*European Champions ' League*"]
# ['*GUNMEN*', '*TWO MANCHESTER UNITED FANS*']
# ['*MANCHESTER UNITED*', '*AUSTRIA*']
# ['*GUNMEN*', '*TWO MANCHESTER UNITED FANS*']
# ['*MANCHESTER UNITED*', '*AUSTRIA*']
# ['*Brittons*', '*Mercedes*', '*Reuters*']
# ['*Britons*', '*Mercedes*', '*Reuters*']
# ['*Vicenza*', '*Bologna*', '*Ita']
# ['*Vicenza*', '*Bologna*', '*Italian*']
# ['*Cagliari*', '*Napoli*', '*Inter*', '*S']
# ['*Cagliari*', '*Napoli*', '*Inter*', '*Swiss*', '*Ramon Vega*']
# ['*Roman*', '*Rome*', '*Italian*', '*UEFA']
# ['*Roman*', '*Rome*', '*Italian*', '*UEFA Cups*']
# ['*Liberian*', '*George Weah*', '*Milan*', '']
# ['*Liberian*', '*George Weah*', '*Milan*', '*Roberto Baggio*', '*Montenegrin*', '*Dejan Savicevic*']
# ['*Milan*', '*Udinese*', '*German*', '*O']
# ['*Milan*', '*Udinese*', '*German*', '*Oliver Bierhoff*']
# ['*Napoli*', '*Verona*', '*Argentine*', '*Rob']
# ['*Napoli*', '*Verona*', '*Argentine*', '*Roberto Ayala*']
# ['*Parma*', '*Croat*', '*Mario Stanic*', '']
# ['*Parma*', '*Croat*', '*Mario Stanic*', '*Cagliari*']
# ['*Parma*', '*French*', '*Daniel Bravo*', '']
# ['*Parma*', '*French*', '*Daniel Bravo*', '*Fabio Cannavaro*', '*Argentine*', '*Nestor Sensini*']
# ['*Juventus*', '*Portuguese*', '*Dimas*', '']
# ['*Juventus*', '*Portuguese*', '*Dimas*', '*Alessandro Del Piero*', '*Croat*', '*Alen Boksic*']
# ['*Sampdoria*', '*Roberto Mancini*', '*Fre']
# ['*Sampdoria*', '*Roberto Mancini*', '*French*', '*Pierre Laigle*']
# ['*Vicenza*', '*Uruguayan*', '*Marcel']
# ['*Vicenza*', '*Uruguayan*', '*Marcelo Otero*', '*Inter*']
# ['*Inter*', '*French*', '*Joceyln Anglo']
# ['*Inter*', '*French*', '*Joceyln Angloma*', '*Chilean*', '*Ivan Zamorano*']
# ['*Charleroi*', '*Belgium*', '*Estudiantes Madrid']
# ['*Charleroi*', '*Belgium*', '*Estudiantes Madrid*', '*Spain*']
# ['*Charleroi*', '*Eric Cleymans*', '*Ron']
# ['*Charleroi*', '*Eric Cleymans*', '*Ron Ellis*', '*Jacques Stas*']
# ['*Harper Williams*', '*Chadler Thompson*', '*Juan Ais']
# ['*Estudiantes*', '*Harper Williams*', '*Chadler Thompson*', '*Juan Aisa*']
# ['*Partizan Belgrade*', '*Yugoslavia*', '*K']
# ['*Partizan Belgrade*', '*Yugoslavia*', '*Kinder Bologna*', '*Italy*']
# ['*Kinder*', '*Zoran Savic*']
# ['*Zoran Savic*']
# ['*Rodney Eyles*', '*World Open*', '*Mahin']
# ['*Rodney Eyles*', '*World Open*', '*Mahindra International*']
# ['*Eyles*', '*Peter Nicol*', '*Scotland']
# ['*Eyles*', '*Peter Nicol*', '*Scotland*', '*Simon Parke*', '*England*']
# ['*MAHINDRA*']
# ['*MAHINDRA INTERNATIONAL*']
# ['*Peter Nicol*', '*Scotland*', '*Simon']
# ['*Peter Nicol*', '*Scotland*', '*Simon Parke*', '*England*', '*Rodney Eyles*', '*Australia*', '*Mark Cairns*', '*England*']
# ['*GUNMEN KILL FOUR*', '*S.AFRICA*', '*']
# ['*S.AFRICA*', '*ZULU PROVINCE*']
# ['*GUNMEN KILL FOUR*', '*S.AFRICA*', '*']
# ['*S.AFRICA*', '*ZULU PROVINCE*']
# ['*South Africa*', '*Zulu*']
# ['*South Africa*', '*Zulu heartland*']
# ['*Nelson Mandela*', '*African National Congress*', '*ANC*', '']
# ['*Nelson Mandela*', '*African National Congress*', '*ANC*', '*Izingolweni*', '*KwaZulu-Natal*']
# ['*KwaZulu-Natal*', '*last Christmas*']
# ['*KwaZulu-Natal*']
# ['*ANC*', '*Zulu Chief Mangosuthu Buthelezi']
# ['*ANC*', '*Zulu*', '*Mangosuthu Buthelezi*', '*Inkatha Freedom Party*']
# ['*Klaina Gajduskova*']
# ['*Klara Gajduskova*']
# ['*Czech*', '*Vaclav Havel*', '*Madeleine']
# ['*Czech*', '*Vaclav Havel*', '*Madeleine Albright*', '*Czech*', '*United States*']
# ['*Havel*', '*Communist*', '*Prague*', '']
# ['*Havel*', '*velvet revolution*', '*Communist*', '*Prague*', '*Albright*']
# ['*Marie Korbelova*', '*Czechoslovak*', '*Uni']
# ['*Albright*', '*Marie Korbelova*', '*Czechoslovak*', '*United States*', '*Communists*']
# ['*Albright*', '*Europe*', '*U.S.*', '*Uni']
# ['*Albright*', '*Europe*', '*U.S.*', '*United Nations*']
# ['*Europe*', '*US*', '*Josef Zieleniec*', '']
# ['*trans-Atlantic*', '*Europe*', '*US*', '*Josef Zieleniec*', '*Reuters*']
# ['*United Nations*', '*Karel Kovanda*', '*M']
# ['*Czech*', '*United Nations*', '*Karel Kovanda*', '*Mlada Fronta Dnes*', '*Albright*', '*Czechs*']
# ['*Romania*']
# ['*Radio Romania*']
# ['*Democratic Convention*', '*Social Democratic Union*', '*Hungarian Democratic Union']
# ['*Democratic Convention*', '*Social Democratic Union*', '*Hungarian Democratic Union*', '*UDMR*']
# ['*Romania*', '*Constantino*']
# ['*Romania*', '*Constantinescu*']
# ['*Timișoara*', '*Adria*', '*Ocurt']
# ['*Timisoara*', '*Arad*', '*Oradea*', '*Sibiu*']
# ['*Timișoara*', '*Adria*', '*Ocurt']
# ['*Timisoara*', '*Arad*', '*Oradea*', '*Sibiu*']
# ['*Timișoara*', '*Adria*', '*Ocurt']
# ['*Timisoara*', '*Arad*', '*Oradea*', '*Sibiu*']
# ['*Czech Civic Democratic Party*', '*ODS*', '*ODS*', '']
# ['*Czech Civic Democratic Party*', '*ODS*', '*ODS*', '*Josef Zieleniec*']
# ['*Zacheniec*', '*Reuters*']
# ['*Zieleniec*', '*Reuters*']
# ['*ODS*', '*Vaclav Klaus*', '*Czech*', '*']
# ['*ODS*', '*Vaclav Klaus*', '*Czech*', '*Brno*']
# ['*ODS*', '*Klaus*', '*British*', '*']
# ['*ODS*', '*Klaus*', '*British*', '*Margaret Thatcher*', '*Czech*']
# ['*Zeckeniec*', '*Klaus*']
# ['*Zieleniec*', '*Klaus*', '*post-Communist*']
# ['*POLAND*', '*POST-WAR SWISS*']
# ['*POLAND*', '*SWISS*']
# ['*Poland*', '*Swiss*', '*Polish*', '*Je']
# ['*Poland*', '*Swiss*', '*Polish*', '*Jews*', '*Holocaust*', '*World War Two*']
# ['*Dariusz Rosati*', '*Poland*', '*Swiss']
# ['*Dariusz Rosati*', '*Poland*', '*Swiss*']
# ['*Switzerland*', "*Alfonse D'Amato"]
# ['*Switzerland*', "*Alfonse D'Amato*", '*U.S. Senate Banking Committee*', '*Poland*', '*Polish*', '*Swiss*', '*Poland*']
# ['*Jews*', '*Nazi German*', '*Poland*', '*']
# ['*Jews*', '*Nazi German*', '*Poland*', '*Jews*']
# ['*Rosati*', '*Warsaw*', '*Switzerland*', '*']
# ['*Rosati*', '*Warsaw*', '*Switzerland*', '*Swiss*', '*Soviet-imposed*', '*World War Two*']
# ['*Zywiec*', '*Zaklady Piwowarskie']
# ['*Zywiec*', '*Zaklady Piwowarskie w Zywcu SA*']
# ['*South African Breweries Ltd*', '*SAB*', '*Lech*', '']
# ['*South African Breweries Ltd*', '*SAB*', '*Lech*', '*Tychy*', '*Australia*', '*Brewpole BV*', '*Poland*', '*Elbrewery Company Ltd.*', '*EB*']
# ['*Czech*', '*Poland*', '*CEFTA*', '*van']
# ['*Czech*', '*Poland*', '*CEFTA*', '*van Boxmeer*', '*Czech*']
# ['*Van Boxmeer*', '*Zywiec*', '*Oko']
# ['*Van Boxmeer*', '*Zywiec*', '*Okocim*', '*Carlsberg*', '*Zywiec*', '*Heineken*']
# ['*Zywiec Full Light*']
# ['*Zywiec*', '*Full Light*']
# ['*Polish*', '*van Boxmeer*', '*Heineken*', '*']
# ['*Polish*', '*van Boxmeer*', '*Heineken*', '*Poland*']
# ['*WORSENS*']
# ['*HAVEL*']
# ['*UK Department of Transport*', '*U.S.*']
# ['*UK*', '*Department of Transport*', '*U.S.*']
# ['*Global Depository Receipt*']
# ['**']
# ['*PT Telekomunikasi Indonesia*', '*Telkom*', '*London']
# ['*PT Telekomunikasi Indonesia*', '*Telkom*', '*London*']
# ['*British*', '*British Airways Plc*', '*American']
# ['*British*', '*trans-Atlantic*', '*British Airways Plc*', '*American Airlines*', '*Britain*', '*Monopolies and Mergers Commission*']
# ['*British Airways*', '*American*', '*London Heathrow*', '']
# ['*British Airways*', '*American*', '*London Heathrow*', '*Europe*']
# ['*British Airways*', '*USAir*', '*British Airways']
# ['*British Airways*', '*USAir*', '*trans-Atlantic*', '*British Airways*', '*American*', '*London*', '*Dallas-Fort Worth*']
# ['*Syria*', '*Lebanon*', '*France*', '']
# ['*Syria*', '*Lebanon*', '*France*', '*Spain*']
# ['*U.S.*', '*Italian*', '*Elf*', '']
# ['*U.S.*', '*Italian*', '*Elf*', '*Med*']
# ['*Gorst*', '*Major*', '*House of Commons']
# ['*Gorst*', '*Major*', '*House of Commons*', '*lower house of parliament*']
# ['*Oceanic Control Centre*', '*Prestwick*', '*Scotl']
# ['*Oceanic Control Centre*', '*Prestwick*', '*Scotland*', '*National Air Traffic Services Ltd*', '*NATS*', '*Civil Aviation Authority*']
# ['*West Indies*', '*Sherwin Campbell*', '*Shivna']
# ['*West Indies*', '*Sherwin Campbell*', '*Shivnarine Chanderpaul*']
# ['*Manitoba*']
# ['*Manitoba Government Price Index*', '*C$*']
# ['*Canadian West Coast*', '*Loadings*', '*CW']
# ['*Canadian*', '*CWB*']
# ['*Canadian West Coast*', '*Loadings*', '*CW']
# ['*Canadian*', '*CWB*']
# ['*Canadian West Coast*', '*Loadings*', '*CW']
# ['*Canadian*', '*CWB*']
# ['*Canadian Wheat Board*', '*Canadian West Coast*']
# ['*Canadian Wheat Board*', '*Canadian*']
# ['*East Coast*']
# ['**']
# ['*Port Loading Waiting*']
# ['**']
# ['*Dampier*', '*Kaohsiung*', '*China Steel']
# ['*Maritime Queen*', '*Dampier*', '*Kaohsiung*', '*China Steel*']
# ['*WESTERN HEMISPHERE*']
# ['**']
# ['*Thai*', '*Ras Tanura*', '*Red Sea*']
# ['*Thai Resource*', '*Ras Tanura*', '*Red Sea*', '*Mobil*']
# ['*Lula I*', '*Sidi Kreir*', '*August']
# ['*Lula I*', '*Sidi Kreir*', '*Augusta*', '*Exxon*']
# ['*Spetses*', '*Sidi Kreir*', '*August']
# ['*Spetses*', '*Sidi Kreir*', '*Augusta*', '*Exxon*']
# ['*Mesipia*', '*Bajaia*', '*']
# ['*Mesipia*', '*Bajaia*', '*Fos*', '*Exxon*']
# ['*Goldman', ' Sachs*']
# ['*Goldman ', ' Sachs*']
# ['*New York City*', '*U.S.*', '*European*', '*']
# ['*New York City*', '*U.S.*', '*European*', '*London Stock Exchange*']
# ['*Homestake Mining Co*', '*Wall Street*', '*Santa Fe']
# ['*Homestake Mining Co*', '*Wall Street*', '*Santa Fe Pacific Gold Corp*', '*Santa Fe*', '*Newmont Mining Corp*']
# ['*Barrick Gold Corp*', '*Bre-X Minerals Ltd*', '*S']
# ['*Barrick Gold Corp*', '*Bre-X Minerals Ltd*', '*Santa Fe*', '*Indonesia*', '*Busang*']
# ['*Placent Dome Inc*', '*Santa Fe*', '*Ne']
# ['*Placer Dome Inc*', '*Santa Fe*', '*Nevada*', '*South America*', '*Central Asia*']
# ['*Placent Dome Inc*', '*Santa Fe*', '*Ne']
# ['*Placer Dome Inc*', '*Santa Fe*', '*Nevada*', '*South America*', '*Central Asia*']
# ['*Homestake*', '*San Francisco*', '*United States*', '']
# ['*Homestake*', '*San Francisco*', '*United States*', '*Australia*', '*Chile*', '*Canada*']
# ['*Santa Fe*', '*Albuquerque*', '*N.M']
# ['*Santa Fe*', '*Albuquerque*', '*N.M.*']
# ['*Santa Fe*', '*Nevada*', '*Californi']
# ['*Santa Fe*', '*Nevada*', '*California*', '*Montana*', '*Canada*', '*Brazil*', '*Australia*', '*Chile*', '*Kazakstan*', '*Mexico*', '*Ghana*']
# ['*PaineWebber*', '*Marc Cohen*', '*Newmont*', '*']
# ['*PaineWebber*', '*Marc Cohen*', '*Newmont*', '*Newmont*', '*Santa Fe*']
# ['*Newmont*', '*Santa Fe*', '*Newmont*', '*S']
# ['*Newmont*', '*Santa Fe*', '*Newmont*', '*Santa Fe*']
# ['*Russ Berrie and Co Inc*', '*A. Curts Cooke']
# ['*Russ Berrie and Co Inc*', '*A. Curts Cooke*']
# ['*Canadian*', '*Zaire*', '*Zaire*', '*Rwan']
# ['*Canadian*', '*Zaire*', '*Zaire*', '*Rwandan*']
# ['*Baril*', '*Laurent Kabila*', '*Goma*', '']
# ['*Baril*', '*Laurent Kabila*', '*Goma*', '*Rwandan*']
# ['*Baril*', '*U.S.*', '*British*', '']
# ['*Baril*', '*U.S.*', '*British*', '*Masisi*', '*Bukavu*', '*Kindu*']
# ['*Kisangani*', '*Medecins sans Frontieres*', '']
# ['*Kisangani*', '*Medecins sans Frontieres*', '*Goma-Bukavu*', '*Walikale*']
# ['*U.N.*', '*UNHCR*', '*Bangui*', '']
# ['*U.N.*', '*UNHCR*', '*Bangui*', '*Abidjan*', '*Ivory Coast*']
# ['*Senegal*', '*Abdou Diouf*', '*Mout']
# ['*Senegal*', '*Abdou Diouf*', '*Moustapha Niasse*', '*United Nations*']
# ['*Diouf*', '*Franco-African*', '*Bur']
# ['*Diouf*', '*Franco-African*', '*Burkina Faso*', '*African*', '*Boutros Boutros-Ghali*']
# ['*Moutapha Niasse*']
# ['*Moustapha Niasse*']
# ['*David Dofara*', '*Red Cross*', '*Reuters*', '']
# ['*David Dofara*', '*Red Cross*', '*Reuters*', '*Christophe Grelombe*']
# ['*Chirac*', '*Burkina Faso*', '*Bl']
# ['*Chirac*', '*Burkina Faso*', '*Blaise Compaore*', '*Bangui*', '*Gabon*', '*Mali*', '*Chad*']
# ['*Church-led*']
# ['**']
# ['*Patasse*', '*May rebellion*']
# ['*Patasse*']
# ['*Skinheads*', '*Bratislava Rabbi*']
# ['*Bratislava*']
# ['*Skinheads*', '*Bratislava Rabbi*']
# ['*Bratislava*']
# ['*Buza*', '*Berisha*', '*Italian*', '']
# ['*Buza*', '*Berisha*', '*Italian*', '*Oscar Luigi Scalfaro*']
# ['*Poland*', '*Aleksander Kwasniewski*', '']
# ['*Poland*', '*Aleksander Kwasniewski*', '*Polish-born*', '*John Paul*', '*Vatican*', '*Warsaw*']
# ['*Kwasniewski*', '*Italy*', '*O']
# ['*Kwasniewski*', '*Italy*', '*Oscar Scalfaro*']
# ['*Vatican*', '*Poland*', '*Kwasniewski']
# ['*Vatican*', '*Poland*', '*Kwasniewski*']
# ['*Russian*', '*Alexander Livshits*', '*Norils']
# ['*Russian*', '*Alexander Livshits*', '*Norilsk Nickel*']
# ['*Itar-Tass*', '*Livshits*', '']
# ['*Itar-Tass*', '*Livshits*', '*RAO Norilsky Nikel*']
# ['*Christopher Granville*', '*United City Bank*', '*Mo']
# ['*Christopher Granville*', '*United City Bank*', '*Moscow*']
# ['*Tass*', '*Livshits*', '*Dum']
# ['*Tass*', '*Livshits*', '*Duma*', '*Norilsk*']
# ['*Interfax*', '*First*', '*Igor Ivanov*', '*']
# ['*Interfax*', '*Igor Ivanov*', '*Moscow*', '*Albright*']
# ['*Interfax*', '*First*', '*Igor Ivanov*', '*']
# ['*Interfax*', '*Igor Ivanov*', '*Moscow*', '*Albright*']
# ['*Russian*', '*Russian-U.S.*', '*Ivanov']
# ['*Russian*', '*Russian-U.S.*', '*Ivanov*', '*Interfax*']
# ['*Interfax*', '*Albright*', '*Washington*', '*U.']
# ['*Interfax*', '*Albright*', '*Washington*', '*U.S.*', '*United Nations*', '*NATO*']
# ['*Russia*', '*NATO*', '*Europe*', '*Soviet-led']
# ['*Russia*', '*NATO*', '*Europe*', '*Soviet-led*', '*Warsaw Pact*']
# ['*Russian*', '*Boris Yeltsin*', '*Interfax']
# ['*Russian*', '*Boris Yeltsin*', '*Interfax*']
# ['*Russia*', '*Yeltsin*', '*Kremlin']
# ['*Russia*', '*Yeltsin*', '*Kremlin*']
# ['*TASR*', '*Frantisek Gaulieder*', '*Gal']
# ['*TASR*', '*Frantisek Gaulieder*', '*Galanta*', '*Slovakia*']
# ['*Gaulieder*', '*Vladimir Meciar*', '*']
# ['*Gaulieder*', '*Vladimir Meciar*', '*Movement for a Democratic Slovakia*']
# ['*Kazanluk*', '*Moslems*', '*Islam']
# ['*Kazanluk*', '*Moslems*', '*Islam*', '*Ottoman Turkish*']
# ['*Dow*', '*Jones*', '*Federal Reserve*', '']
# ['*Dow ( Jones industrial average )*', '*Federal Reserve*', '*Alan Greenspan*']
# ['*Dow*', '*Jones*', '*Federal Reserve*', '']
# ['*Dow ( Jones industrial average )*', '*Federal Reserve*', '*Alan Greenspan*']
# ['*Dow*', '*Jones*', '*Federal Reserve*', '']
# ['*Dow ( Jones industrial average )*', '*Federal Reserve*', '*Alan Greenspan*']
# ['*U.S. Treasury*', '*Mexico*']
# ['*U.S.*', '*Treasury*', '*Mexico*']
# ['*Brazil*', '*Farid Hakme*', '*Brazilian']
# ['*Brazil*', '*Farid Hakme*', '*Brazilian Plastic Surgery Society*', '*SBCP*']
# ['*United States*', '*SBCP*', '*Oswaldo Sal']
# ['*United States*', '*SBCP*', '*Oswaldo Saldanha*']
# ['*Beauty*']
# ['**']
# ['*Buenos Aires Quequen*', '*Rosario Bahia']
# ['*Buenos Aires*', '*Quequen*', '*Rosario*', '*Bahia Blanca*']
# ['*Buenos Aires Quequen*', '*Rosario Bahia']
# ['*Buenos Aires*', '*Quequen*', '*Rosario*', '*Bahia Blanca*']
# ['*Maize*', '*Flint*']
# ['**']
# ['*Maize*', '*Flint*']
# ['**']
# ['*Maize*', '*Dent*']
# ['**']
# ['*Maize*', '*Dent*']
# ['**']
# ['*Soybeans*']
# ['**']
# ['*Sunseeds*']
# ['**']
# ['*Gulf of Mexico*', '*Caribbean*', '*Pacific Coast']
# ['*Gulf of Mexico*', '*Caribbean*', '*Pacific Coast*']
# ['*Chile*', '*Mexico*', '*Eduardo Aninat']
# ['*Chile*', '*Mexico*', '*Eduardo Aninat*']
# ['*East Timorese Roman Catholic*', '*Carlos Belo*', '*Dil']
# ['*East Timorese*', '*Roman Catholic*', '*Carlos Belo*', '*Dili*', '*Norway*', '*Nobel Peace Prize*']
# ['*East Timorese Roman Catholic*', '*Carlos Belo*', '*Dil']
# ['*East Timorese*', '*Roman Catholic*', '*Carlos Belo*', '*Dili*', '*Norway*', '*Nobel Peace Prize*']
# ['*East Timorese-born*', '*Jose Ramos Hort']
# ['*Nobel*', '*East Timorese-born*', '*Jose Ramos Horta*', '*Australia*']
# ['*Indonesian*', '*Ramos Horta*', '*A']
# ['*Indonesian*', '*Ramos Horta*', '*Ali Alatas*', '*Indonesia*', '*Norwegian*']
# ['*East Timor*', '*Alas*']
# ['*East Timor*', '*Alatas*']
# ['*Organisation of the Islamic Conference*', '*OIC*', '*Jakart']
# ['*Organisation of the Islamic Conference*', '*OIC*', '*Jakarta*']
# ['*Belo*', '*Ramos Horta*', '*East Tim']
# ['*Belo*', '*Ramos Horta*', '*East Timor*', '*Portuguese*', '*Indonesia*']
# ['*Alas*', '*Nobel Peace Prize*', '*Belo*']
# ['*Alatas*', '*Nobel Peace Prize*', '*Belo*']
# ['*Indonesian*', '*Norway*', '*Belo*', '']
# ['*Indonesian*', '*Norway*', '*Belo*', '*Alatas*']
# ['*Alas*', '*Oslo*', '*Belo*', '']
# ['*Alatas*', '*Oslo*', '*Belo*', '*Vatican*', '*German*', '*Helmut Kohl*', '*Bonn*']
# ['*Alas*', '*Oslo*', '*Belo*', '']
# ['*Alatas*', '*Oslo*', '*Belo*', '*Vatican*', '*German*', '*Helmut Kohl*', '*Bonn*']
# ['*Kohl*', '*Belo*', '*Indonesi']
# ['*Kohl*', '*Belo*', '*Indonesia*', '*East Timor*', '*Jakarta*']
# ['*China*', '*State Council*', '*Hainan*', '*X']
# ['*China*', '*State Council*', '*Hainan*', '*Xinhua*']
# ['*Xinhua*', '*Qinglan*', '*Wenchang']
# ['*Xinhua*', '*Qinglan*', '*Wenchang*']
# ['*Ranyon*', '*Rangoon*', '*University*']
# ['*Burmese*', '*Ranyon ( Rangoon ) University*']
# ['*Ranyon*', '*Rangoon*', '*University*']
# ['*Burmese*', '*Ranyon ( Rangoon ) University*']
# ['*Ranyon*', '*Rangoon*', '*University*']
# ['*Burmese*', '*Ranyon ( Rangoon ) University*']
# ['*Burmese*', '*Yangon Institute of Technology*', '*Rango']
# ['*Burmese*', '*Yangon Institute of Technology*', '*Rangoon*', '*University of Yangon*']
# ['*International Labour Organisation*', '*ILO*', '*WTO*', '*Sing']
# ['*International trade union*', '*International Labour Organisation*', '*ILO*', '*WTO*', '*Singapore*']
# ['*Bill Jordan*', '*International Confederation of Free Trade Unions*', '*']
# ['*Bill Jordan*', '*International Confederation of Free Trade Unions*', '*ICFTU*', '*WTO*', '*ILO*', '*Michel Hansenne*']
# ['*Jordan*', '*World Trade Organisation*', '*WTO*', '*H']
# ['*Jordan*', '*World Trade Organisation*', '*WTO*', '*Hansenne*']
# ['*ASEAN*', '*Brunei*', '*Indonesia']
# ['*ASEAN*', '*Brunei*', '*Indonesia*', '*Malaysia*', '*Philippines*', '*Singapore*', '*Thailand*', '*Vietnam*']
# ['*K.J. Matthew*', '*Asia Rubber Markets*', '*']
# ['*K.J. Matthew*', '*Asia Rubber Markets*', '*Indian*']
# ['*Bank of Japan*', '*BOJ*', '*Yasuo Mats']
# ['*Bank of Japan*', '*BOJ*', '*Yasuo Matsushita*', '*Japan*']
# ['*U.S. Treasury*', '*Robert ) Rubin*', '*']
# ['*U.S. Treasury*', '*Robert*', '*Rubin*', '*Hank Note*', '*Sumitomo Bank*']
# ['*U.S. Treasury*', '*Robert ) Rubin*', '*']
# ['*U.S. Treasury*', '*Robert*', '*Rubin*', '*Hank Note*', '*Sumitomo Bank*']
# ['*Sakakibara*', '*Sumitomo*', '*Not']
# ['*Sakakibara*', '*Sumitomo*']
# ['*Takao Sakoh*', '*Union Bank of Switzerland*', '*Toky']
# ['*Takao Sakoh*', '*Union Bank of Switzerland*', '*Tokyo*', '*Sakakibara*']
# ['*Mr Yen*', '*Sakakibara*', '*BOJ']
# ['*Mr Yen*', '*Sakakibara*', '*BOJ*', '*Matsushita*']
# ['*Matsushita*', '*Nihon Keizai Shimbun']
# ['*Matsushita*', '*Nihon Keizai Shimbun*']
# ['*BOJ*', '*Yasuhito Kawashima*', '*']
# ['*BOJ*', '*Yasuhito Kawashima*', '*Toyo Trust & Banking Co .*']
# ['*BOJ*', '*Taisuke Tanaka*', '*Credit']
# ['*BOJ*', '*Taisuke Tanaka*', '*Credit Suisse*', '*Tokyo*']
# ['*Antoine Lahd*', '*South Lebanon Army*', '*SLA*', '*']
# ['*Antoine Lahd*', '*South Lebanon Army*', '*SLA*', '*Israel*', '*Lebanon*']
# ['*Lahd*', '*Lebanese*', '*SLA*', '']
# ['*Lahd*', '*Lebanese*', '*SLA*', '*Israel*', '*Lebanon*', '*Israel*']
# ['*Lahd*', '*Israel*', '*Israel*', '*Lebanes']
# ['*Lahd*', '*Israel*', '*Israel*', '*Lebanese*', '*Lebanese*', '*Lebanese*']
# ['*Israel*', '*Lahd*', '*SLA*', '*Christian-Sh']
# ['*Israel*', '*Lahd*', '*SLA*', "*Christian-Shi'ite*", '*Moslem*', '*Jewish*']
# ['*Lebanese*', '*Lebanese*', '*Lah']
# ['*Lebanese*', '*Lebanese*', '*Lahd*']
# ['*Peres*', '*Israeli*', '*Benjamin Netanyahu*', '']
# ['*Peres*', '*Israeli*', '*Benjamin Netanyahu*', '*Lebanon*', '*SLA*']
# ['*Beirut*', '*Etian Saqr*', '*pro-Israeli']
# ['*Beirut*', '*Etian Saqr*', '*pro-Israeli*', '*Guardians of the Cedars*', '*Christian*']
# ['*Saqr*', '*Lahd*', '*Israeli*', '*']
# ['*Saqr*', '*Lahd*', '*Israeli*', '*Israel*', '*Lebanon*']
# ['*Slaughter Steers*', '*Sep and Choice*']
# ['**']
# ['*Slaughter Steers*', '*Sep and Choice*']
# ['**']
# ['*Slaughter Heifers*', '*Select and Choice*']
# ['**']
# ['*Slaughter Heifers*', '*Select and Choice*']
# ['**']
# ['*CATTLE*']
# ['**']
# ['*Last Year*']
# ['**']
# ['*Steer and Heifer Cow and Bull*']
# ['**']
# ['*CITY OF HARTFORD*', '*CONNECTICUT*']
# ['*HARTFORD*', '*CONNECTICUT*']
# ['*$ 25', '000', '000*']
# ['**']
# ['*$ 25', '000', '000*']
# ['**']
# ['*$ 25', '000', '000*']
# ['**']
# ['**']
# ['*Prudential Securities Incorporated*']
# ['*Glenn Lawhon*', '*Florida*', '*Mill']
# ['*Glenn Lawhon*', '*Florida*', '*Mills*', '*GMT*', '*Lester Lawhon*']
# ['*Arabic*', '*Mills*', '*Department of Corrections']
# ['*Arabic*', '*Mills*', '*Department of Corrections*', '*Eugene Morris*']
# ['*God*', '*Allah*', '*Mohammed*', '*']
# ['*God*', '*Allah*', '*Mohammed*', '*God*', '*Mills*']
# ['*Mills*', '*Yuhanna Abdullah Muhammed*', '']
# ['*Mills*', '*Yuhanna Abdullah Muhammed*', '*Islam*']
# ['*Mills*', '*Florida*', '*U.S. Supreme Court']
# ['*Mills*', '*Florida*', '*U.S. Supreme Court*']
# ['*11th Circuit U.S. Court of Appeals*', '*Atlanta']
# ['*Circuit U.S. Court of Appeals*', '*Atlanta*']
# ['*11th Circuit U.S. Court of Appeals*', '*Atlanta']
# ['*Circuit U.S. Court of Appeals*', '*Atlanta*']
# ['*Mills*', '*Michael Frederick*', '*Lester Law']
# ['*Mills*', '*Michael Frederick*', '*Lester Lawhon*']
# ['*Iowa-S Minn*']
# ['*Iowa-S*', '*Minn*', '*sales-USDA*']
# ['*Sep and Choice*']
# ['**']
# ['*Heifers*', '*Select and Choice*']
# ['**']
# ['*Heifers*', '*Select and Choice*']
# ['**']
# ['*Sep and Choice*']
# ['**']
# ['*Holstein*', '*Choice*']
# ['**']
# ['*Holstein*', '*Choice*']
# ['**']
# ['*Holsteins*']
# ['**']
# ['*Heifers*', '*Select and Choice*']
# ['**']
# ['*Heifers*', '*Select and Choice*']
# ['**']
# ['*Darrel Voeks*', '*Outagmie County Circuit Court*', '']
# ['*Darrel Voeks*', '*Outagmie County*', '*Dennis Luebke*']
# ['*Darrel Voeks*', '*Outagmie County Circuit Court*', '']
# ['*Darrel Voeks*', '*Outagmie County*', '*Dennis Luebke*']
# ['*Durum*']
# ['**']
# ['*Oats*']
# ['**']
# ['*Barley*']
# ['**']
# ['*Rye*']
# ['**']
# ['*Flax*']
# ['**']
# ['*Canola*']
# ['**']
# ['*Durum*']
# ['**']
# ['*Oats*']
# ['**']
# ['*Barley*']
# ['**']
# ['*Rye*']
# ['**']
# ['*Flax*']
# ['**']
# ['*Canola*']
# ['**']
# ['*Corn*']
# ['**']
# ['*Oats Rye Flaxseed Canola Corn*']
# ['**']
# ['*NYMEX Henry Hub*', '*National Weather Service*']
# ['*NYMEX*', '*Henry Hub*', '*National Weather Service*']
# ['*NYMEX*', '*Hub*']
# ['*NYMEX*']
# ['*NYMEX Permian*']
# ['*NYMEX*', '*Permian*']
# ['*East*', '*West*', '*NYMEX*']
# ['*NYMEX*']
# ['*East*', '*West*', '*NYMEX*']
# ['*NYMEX*']
# ['*Waha*', '*Southwest*']
# ['*Waha*']
# ['**']
# ['*CBOT*']
# ['*Oats*']
# ['**']
# ['*Action Performance*']
# ['**']
# ['*Action Performance Cos Inc*', '*MotorSport Traditions Ltd*']
# ['*Action Performance Cos Inc*', '*Motorsport Traditions Ltd*', '*Creative Marketing & Promotions Inc*']
# ['*Rottweilers*', '*German*', '*Dalmatians*']
# ['*chow chows*', '*Rottweilers*', '*German shepherds*', '*cocker spaniels*', '*Dalmatians*']
# ['*Iowa-S Minn*', '*USDA*']
# ['*Iowa-S*', '*Minn*', '*USDA*']
# ['*African*', '*U.N.*', '*Boutros Boutros']
# ['*African*', '*U.N.*', '*Boutros Boutros-Ghali*']
# ['*Kofi Annan*', '*Ghana*', '*U.N.']
# ['*Kofi Annan*', '*Ghana*', '*U.N.*', '*Ahmedou Ould Abdallah*', '*Mauritania*', '*U.N.*', '*Burundi*', '*Amara Essy*', '*Ivory Coast*', '*U.N. General Assembly*', '*Hamid Algabid*', '*Niger*', '*Organisation of the Islamic Conference*']
# ['*Joseph Garba*', '*Nigeria*', '*']
# ['*Joseph Garba*', '*Nigeria*', '*U.N. General Assembly*']
# ['*Security Council*', '*General Assembly*', '*Boutros-G']
# ['*Security Council*', '*General Assembly*', '*Boutros-Ghali*']
# ['*Pamplona*', '*Herri Batasuna*', '']
# ['*Pamplona*', '*Herri Batasuna*', '*Basque*', '*ETA*']
# ['*Alessandra Mussolini*', '*Italy*', '*']
# ['*Alessandra Mussolini*', '*Italy*', '*Benito Mussolini*', '*National Alliance*', '*AN*']
# ['*Fini*', '*RAI*', '*Mussolini*', '']
# ['*Fini*', '*RAI*', '*Mussolini*', '*Giuseppe Tatarella*', '*AN*', '*Chamber of Deputies*']
# ['*German Santa*']
# ['*German*', '*Santa*']
# ['*Italian*', '*Senate*', '*Italy*']
# ['*Italian upper house Senate*', '*Italy*']
# ['*Italian*', '*Senate*', '*Italy*']
# ['*Italian upper house Senate*', '*Italy*']
# ['*European Union*', '*Poland*', '*Polish*', '*European']
# ['*European Union*', '*Poland*', '*Polish*', '*European Commission*']
# ['*EU*', '*Polish*', '*Europe Agreement*', '*EU*', '*']
# ['*EU*', '*Polish*', '*Europe Agreement*', '*EU*', '*Poland*']
# ['*Hindu*', '*Bharatiya Janata Party*', '*BJP']
# ['*Hindu*', '*Bharatiya Janata Party*', '*BJP*', '*pro-Hindu*', '*Babri*']
# ['*Indian*', '*Ayodhya*', '*Hindu-']
# ['*Indian*', '*Ayodhya*', '*Hindu-Moslem*']
# ['*BJP*', '*Hindu*', '*Hindus*', '*Rama']
# ['*BJP*', '*Hindu*', '*Hindus*', '*Rama*']
# ['*LUXEMBOURG*', '*WORLD WIDE*']
# ['*LUXEMBOURG*', '*WORLD WIDE WEB*']
# ['*Luxembourg*', '*Christmas*']
# ['*Luxembourg*', '*world wide web*']
# ['*Royal Clipper*', '*Maracaibo*', '*']
# ['*Royal Clipper*', '*Maracaibo*', '*Fos*', '*Coe and Clerici*']
# ['*IMC TBN*', '*Dampier*', '*Kaohs']
# ['*IMC TBN*', '*Dampier*', '*Kaohsiung*', '*China Steel*']
# ['*Italian*', '*Sweden*']
# ['*Italian BTPs*', '*Sweden*']
# ['*Algeria*', '*Saharan Blend*', '*Indone']
# ['*Algeria*', '*Saharan Blend*', '*Indonesia*', '*Minas*', '*Nigeria*', '*Bonny Light*', '*Saudi Arabia*', '*Arabian Light*', '*Dubai*', '*UAE*', '*Venezuela*', '*Tia Juana*', '*Mexico*', '*Isthmus*']
# ['*Ireland*', '*Michigan*', '*Stephenville*', '']
# ['*Ireland*', '*Michigan*', '*Stephenville*', '*Newfoundland*']
# ['*Grand Rapids*', '*Michigan*', '*Stephenville*', '']
# ['*Grand Rapids*', '*Michigan*', '*Stephenville*', '*Shannon*', '*Ireland*']
# ['*PLO*', '*Palestinian*', '*Yasser Arafat']
# ['*PLO*', '*Palestinian*', '*Yasser Arafat*', '*Israeli*', '*Benjamin Netanyahu*', '*Egyptian*', '*Hosni Mubarak*', '*Israel*', '*Hebron*', '*PLO*']
# ['*Rdainah*', '*Arafat*', '*Cairo']
# ['*Rdainah*', '*Arafat*', '*Cairo*', '*Mubarak*']
# ['*Palestine Liberation Organisation*', '*PLO*', '*Israel*', '*']
# ['*Palestine Liberation Organisation*', '*PLO*', '*Israel*', '*Hebron*', '*PLO*', '*Arafat-Netanyahu*']
# ['*Palestinian Authority*', '*Ahmed Abdel-Rah']
# ['*Palestinian Authority*', '*Ahmed Abdel-Rahman*', '*Cairo*']
# ['*Turkey*', '*Kurdish*', '*Syria']
# ['*Turkey*', '*Kurdish*', '*Syria*']
# ['*Turkey*', '*Syria*', '*PKK*', '']
# ['*Turkey*', '*Syria*', '*PKK*', '*Kurdish*', '*Turkey*']
# ['*Kesers*', '*Kabuluts*', '*Kur']
# ['*Kesers*', '*Karabuluts*', '*Kurdish*']
# ['*Kesers*', '*Kabuluts*', '*Kur']
# ['*Kesers*', '*Karabuluts*', '*Kurdish*']
# ['*Kurdish*', '*Kurdistan Workers Party*', '*PK']
# ['*Kurdish*', '*Kurdistan Workers Party*', '*PKK*']
# ['*Slaughter*']
# ['**']
# ['*Slaughter Steers*', '*Pen Select and Choice*']
# ['**']
# ['*Slaughter Steers*', '*Pen Select and Choice*']
# ['**']
# ['*Pen Select*']
# ['**']
# ['*Sep and Choice*']
# ['**']
# ['*Sep and Choice*']
# ['**']
# ['*Dec 5*', '*Dec 5*', '*Delphis Hanover']
# ['*Delphis Hanover*']
# ['*Dec 5*', '*Dec 5*', '*Delphis Hanover']
# ['*Delphis Hanover*']
# ['*Dec 5*', '*Dec 5*', '*Delphis Hanover']
# ['*Delphis Hanover*']
# ['**']
# ['*ACCESS*']
# ['*U.S.*', '*Northeastern*']
# ['*U.S.*', '*NYMEX ACCESS*']
# ['**']
# ['*ACCESS*']
# ['*Mahammad Rashid*', '*Korydallos*', '*']
# ['*Mahammad Rashid*', '*Korydallos*', '*Athens*', '*Olympic Airways*', '*Cairo*', '*Tunis*', '*Palestine Liberation Organisation*']
# ['*Mike Cito*', '*St Pius X High School*', '*']
# ['*Mike Cito*', '*St Pius X High School*', '*Albuquerque*']
# ['*Cyberspace*']
# ['**']
# ['*Cyberspace*']
# ['**']
# ['*Western*']
# ['**']
# ['*James Love*', '*Washington-based Consumer Project on Technology*']
# ['*James Love*', '*Washington-based*', '*Consumer Project on Technology*']
# ['*Mongolia*', '*Gundegma Jargalshai']
# ['*Mongolia*', '*Gundegma Jargalshaihan*', '*Ulan Bator*']
# ['*Internet*', '*Marc Pearl*', '*Information Technology Association of America*', '']
# ['*Internet*', '*Marc Pearl*', '*Information Technology Association of America*', '*U.S.*']
# ['*Italy*', '*Roman Catholic*', '*Zaire*', '*T']
# ['*Italy*', '*Roman Catholic*', '*Zaire*', '*Tutsi*']
# ['*Foreign Ministry*', '*Europeans*', '*Africans*', '*']
# ['*Foreign Ministry*', '*Europeans*', '*Africans*', '*Garamba*', '*Zaire*', '*Ugandan*', '*Kampala*', '*Italian*']
# ['*Italians*', '*Zaireans*', '*Belgium*', '']
# ['*Italians*', '*Zaireans*', '*Belgium*', '*Spain*', '*Zambia*']
# ['*Moroccan*', '*Mohamed Benchaou*', '*Par']
# ['*Moroccan*', '*Mohamed Benchaou*', '*Paris*', '*Moroccan*']
# ['*Benjaou*']
# ['*Benchaou*']
# ['*Benjaou*', '*Moroccan*']
# ['*Benchaou*', '*Moroccan*']
# ['*MANTAU*', '*Italy*']
# ['*MANTUA*', '*Italy*']
# ['*Italian*', '*Oscar Luigi Scalfaro*', '*']
# ['*Italian*', '*Oscar Luigi Scalfaro*', '*Northern League*']
# ['*Italian*', '*Mantua*', '*Scalfaro']
# ['*Italian*', '*Mantua*', '*Scalfaro*', '*League*']
# ['*Italians*', '*Viva Italia*']
# ['*Italians*', '*Italia*']
# ['*Denmark*', '*Radiometer*']
# ['*Denmark*']
# ['*Soeren Linding Jakobsen*', '*Copenhagen']
# ['*Soeren Linding Jakobsen*', '*Copenhagen*']
# ['*Turkish*', '*Turkey*', '*Antwerp']
# ['*Turkish*', '*Turkey*', '*Antwerp*', '*Spain*', '*France*', '*Germany*']
# ['*Belgian Franc*']
# ['*Belgian*']
# ['*Colombia*', '*El Salvador*', '*Indonesia']
# ['*Colombia*', '*El Salvador*', '*Indonesia*', '*Ethiopia*', '*Kenya*']
# ['*John Lewis Partnership*', '*UK*']
# ['*John Lewis*', '*UK*']
# ['*Waitress*']
# ['*Waitrose*']
# ['*PT Tambang Timah*', '*GDR*', '*London*', '']
# ['*PT Tambang Timah*', '*London*', '*GMT*']
# ['*PT Tambang Timah*', '*GDR*', '*London*', '']
# ['*PT Tambang Timah*', '*London*', '*GMT*']
# ['*Global Depository Receipt*']
# ['**']
# ['*Euro-sceptic*', '*Conservative party British*', '*Kenne']
# ['*Euro-sceptic*', '*Conservative*', '*British*', '*Kenneth Clarke*', '*European*']
# ['*Euro-sceptic*', '*Conservative party British*', '*Kenne']
# ['*Euro-sceptic*', '*Conservative*', '*British*', '*Kenneth Clarke*', '*European*']
# ['*Tony Marlow*', '*Conservatives*']
# ['*Tony Marlow*']
# ['*Pro-European*', '*Conservative*', '*Edwina Cur']
# ['*Pro-European*', '*Conservative*', '*Edwina Currie*', '*BBC*', '*Clarke*']
# ['*Paul Crofts*', '*Tony*', '*New South Wales Supreme']
# ['*Paul Crofts*', '*Tony*', '*New South Wales Supreme Court*']
# ['*Crofts*', '*Grover*']
# ['*Crofts*', '*Grove*']
# ['*Grover*', '*Betcher*']
# ['*Grove*', '*Betcher*']
# ['*NZ*', '*Bolger*', '*Nats*', '*']
# ['*NZ*', '*Bolger*', '*Nats*', '*NZ First*']
# ['*New Zealand*', '*Jim Bolger*', '*New Zealand First*', '*']
# ['*New Zealand*', '*Jim Bolger*', '*New Zealand First*', '*National*', '*NZ First*']
# ['*New Zealand First*', '*Winston Peters*', '*National*', '*Lab']
# ['*New Zealand First*', '*Winston Peters*', '*National*', '*Labour*']
# ['*Peters*', '*NZ First*', '*National*', '*Labour']
# ['*Peters*', '*NZ First*', '*National*', '*Labour*', '*Helen Clark*']
# ['*Australian*', '*John Langmore*', '*House of Representatives*', '']
# ['*Australian*', '*John Langmore*', '*House of Representatives*', '*Bob Halverson*']
# ['*Halverson*', '*John Vance Langmore*', '*House of']
# ['*Halverson*', '*John Vance Langmore*', '*House of Representatives*', '*Fraser*', '*Australian Capital Territory*']
# ['*Langmore*', '*Australia*', '*United Nations*', '*New']
# ['*Langmore*', '*Australia*', '*United Nations*', '*New York*']
# ['*U.N.*', '*Copenhagen*', '*U.N.']
# ['*U.N.*', '*Copenhagen*', '*U.N.*', '*Inge Kaul*']
# ['*Canberra Bureau*']
# ['*Canberra*']
# ['*Burmese*', '*Yangon Institute of Technology*', '*YIT']
# ['*Burmese*', '*Yangon Institute of Technology*', '*YIT*', '*Rangoon*', '*University of Yangon*']
# ['*Thai Commerce Ministry*', '*Thai*']
# ['*Thai*', '*Commerce Ministry*', '*Thai*']
# ['*Loine*', '*Philippines*']
# ['*Princess of Loine*', '*Philippines*']
# ['*Ace*', '*Japan*']
# ['*King Ace*', '*Japan*']
# ['*China*', '*Tianjin*', '*Wen Hui Bao']
# ...
# ['*Bre-X*', '*PT Panutan Duta*', '*Panutan Group*', '*Suharto*', '*Sigit Harjojudanto*', '*Panutan*', '*Busang*']
# ['*Barrick*', '*Citra Group*', '*Suharto*', '']
# ['*Barrick*', '*Citra Group*', '*Suharto*', '*Siti Hardianti Rukmana*', '*Barrick*']
# ['*Singapore*', '*WTO*', '*Desmond Supple']
# ['*Singapore*', '*WTO*', '*Desmond Supple*', '*I.D.E.A*']
# ['*Singapore*', '*American*', '*U.S.*', '*']
# ['*Singapore*', '*American*', '*then-U.S.*', '*Mickey Kantor*', '*WTO*']
# ['*Singapore*', '*American*', '*U.S.*', '*']
# ['*Singapore*', '*American*', '*then-U.S.*', '*Mickey Kantor*', '*WTO*']
# ['*Derek da Cunha*', '*Institute of Policy Studies*', '*']
# ['*Derek da Cunha*', '*Institute of Policy Studies*', '*ISEAS*', '*Singapore*']
# ['*Singapore*', '*Tan Kong Yam*', '*Business Policy*']
# ['*Singapore*', '*Tan Kong Yam*', '*National University of Singapore*']
# ['*WTO*', '*Uruguay Round*', '*General Agreement on Tarif']
# ['*WTO*', '*Uruguay Round*', '*General Agreement on Tariffs and Trade*', '*GATT*']
# ['*WTO*', '*Singapore*', '*European Union*', '*']
# ['*WTO*', '*Singapore*', '*European Union*', '*Singapore*']
# ['*Posts and Telecommunications*', '*Hisao Horinouchi*']
# ['*Hisao Horinouchi*', '*NTT*']
# ['*Dutch*', '*Ahold NV*', '*Asian*', '*']
# ['*Dutch*', '*Ahold NV*', '*Asian*', '*BILO*', '*Malaysia*']
# ['*BILO*', '*Malysia*', '*Kuala Lum']
# ['*BILO*', '*Malysia*', '*Kuala Lumpur*', '*Johor Bahru*']
# ['*BILO*', '*Ahold*', '*TOPS*', '*Asi']
# ['*BILO*', '*Ahold*', '*TOPS*', '*Asia*']
# ['*Asia*', '*Dutch*', '*Ahold*', '*']
# ['*Asia*', '*Dutch*', '*Ahold*', '*Europe*', '*U.S.*', '*Brazil*']
# ['*Gladishiva*', '*1994 Lillehammer Winter Olympics*', '*']
# ['*Gladishiva*', '*Lillehammer*', '*Winter Olympics*', '*World Championships*']
# ['*Gladishiva*', '*1994 Lillehammer Winter Olympics*', '*']
# ['*Gladishiva*', '*Lillehammer*', '*Winter Olympics*', '*World Championships*']
# ['*Madlen Brigger-Summermatter*', '*Switz']
# ['*Madlen Brigger-Summermatter*', '*Switzerland*']
# ['*Spella Bracun*', '*Slovenia*']
# ['*Spela Bracun*', '*Slovenia*']
# ['*ALPHINE*', '*WORLD CUP*']
# ['*SKIING-GLADISHIVA*', '*WORLD CUP*']
# ['*Pernilla Wiberg*', '*Sweden*', '*Carole']
# ['*Pernilla Wiberg*', '*Sweden*', '*Carole Montillet*', '*France*']
# ['*GOLF*', '*JCPENNEY CLASSIC*']
# ['*JCPENNEY CLASSIC*']
# ['*PGA*', '*LPGA Tours*']
# ['*PGA*', '*LPGA*']
# ['*Pat Hurst*', '*Scott McCarron*', '*Donna']
# ['*Pat Hurst*', '*Scott McCarron*', '*Donna Andrews*', '*Mike Hulbert*']
# ['*U.S. Amateur*', '*Kelli Kuehne*', '*T']
# ['*U.S.*', '*Kelli Kuehne*', '*Tiger Woods*']
# ['*U.S. Amateur*', '*Kelli Kuehne*', '*T']
# ['*U.S.*', '*Kelli Kuehne*', '*Tiger Woods*']
# ['*ALPHINE*']
# ['**']
# ['*Lillehammer Norway*', '*Flachau*', '*Austri']
# ['*Lillehammer*', '*Norway*', '*Flachau*', '*Austria*']
# ['*Lillehammer Norway*', '*Flachau*', '*Austri']
# ['*Lillehammer*', '*Norway*', '*Flachau*', '*Austria*']
# ['*World Cup*', '*Europa Cup*', '*Goetschl*', '']
# ['*1993 World Cup*', '*Europa Cup*', '*Goetschl*', '*World Cup*']
# ['*Downhill Standings*']
# ['**']
# ['*Alexandra Meissnitzer*', '*Austria*']
# ['*Alexandra Meissnitzer*', '*Austria)118*']
# ['**']
# ['*Super G*']
# ['*Madlen Brigger-Summermatter*', '*Switz']
# ['*Madlen Brigger-Summermatter*', '*Switzerland*']
# ['*Spella Bracun*', '*Slovenia*']
# ['*Spela Bracun*', '*Slovenia*']
# ['*NORDIC*', '*WORLD CUP*']
# ['*SKIING-WORLD CUP*']
# ['*NORDIC*', '*WORLD CUP*']
# ['*SKIING-WORLD CUP*']
# ['*ALPHINE*', '*WORLD CUP*']
# ['*SKIING-GOETCHL*', '*WORLD CUP*']
# ['*Renate Goetschl*', '*Austria*', '*World Cup']
# ['*Renate Goetschl*', '*Austria*', '*World Cup*']
# ['*Katja Seizinger*', '*Germany*', '*Islo']
# ['*Katja Seizinger*', '*Germany*', '*Islode Kostner*', '*Italy*']
# ['*Shimer*', '*Randy Jones*', '*1976*', '*']
# ['*Shimer*', '*Randy Jones*', '*Olympic*']
# ['*Shimer*', '*Randy Jones*', '*1976*', '*']
# ['*Shimer*', '*Randy Jones*', '*Olympic*']
# ['*Canada I*', '*Pierre Lueders*', '*Dave MacE']
# ['*Canada I*', '*Pierre Lueders*', '*Dave MacEachern*', '*World cup*', '*Italians*']
# ['*Canadians*', '*Altenberg*', '*Germany*', '']
# ['*Canadians*', '*Altenberg*', '*Germany*', '*La Plagne*', '*France*', '*World Cup*']
# ['*USA*', '*Jim Herberich*', '*Garrett Hines']
# ['*USA I*', '*Jim Herberich*', '*Garrett Hines*']
# ['*USA*', '*Jim Herberich*', '*Garrett Hines']
# ['*USA I*', '*Jim Herberich*', '*Garrett Hines*']
# ['*Alexis Blanc*', '*Sebastien Foucras*', '*F']
# ['*Alexis Blanc*', '*Sebastien Foucras*', '*France*']
# ['*Blanc*', '*World Cup*', '*Foucras*', '*']
# ['*Blanc*', '*World Cup*', '*Foucras*', '*World Cup*']
# ['*Veronica Brenner*', '*Canada*', '*Tignes*', '*Fre']
# ['*Veronica Brenner*', '*Canada*', '*Tignes*', '*French*']
# ['*United States III*', '*Brian Shimer*', '*Randy']
# ['*United States III*', '*Brian Shimer*', '*Randy Jones*']
# ['*Italy I*', '*Guenther Huber*', '*Anton']
# ['*Italy I*', '*Guenther Huber*', '*Antonio Tartaglia*']
# ['*Canada I*', '*Pierre Lueders*', '*Dave MacE']
# ['*Canada I*', '*Pierre Lueders*', '*Dave MacEachern*']
# ['*German I*', '*Sepp Dostthaler*', '*Tho']
# ['*German I*', '*Sepp Dostthaler*', '*Thomas Lebsa*']
# ['*Switzerland I*', '*Reto Goetschi*', '*Gu']
# ['*Switzerland I*', '*Reto Goetschi*', '*Guido Acklin*']
# ['*Germany III*', '*Dirk Wiese*', '*Jakob']
# ['*Germany III*', '*Dirk Wiese*', '*Jakobs Marco*']
# ['*Czech Republic I*', '*Jiri Dzmura*', '']
# ['*Czech Republic I*', '*Jiri Dzmura*', '*Pavel Polomsky*']
# ['*Austria I*', '*Hubert Schoesser*', '*Erwin Arnold']
# ['*Austria I*', '*Hubert Schoesser*', '*Erwin Arnold*']
# ['*Britain*', '*Sean Olsson*', '*Dean Ward']
# ['*Britain I*', '*Sean Olsson*', '*Dean Ward*']
# ['*Britain*', '*Sean Olsson*', '*Dean Ward']
# ['*Britain I*', '*Sean Olsson*', '*Dean Ward*']
# ['*United States*', '*Jim Herberich*', '*Garret']
# ['*United States I*', '*Jim Herberich*', '*Garrett*']
# ['*United States*', '*Jim Herberich*', '*Garret']
# ['*United States I*', '*Jim Herberich*', '*Garrett*']
# ['*Hines*', '*Austria*']
# ['*Hines*', '*Austria III*']
# ['*WOOLMER*', '*MAKES SENTIMENTAL*', '*KA']
# ['*WOOLMER*', '*KANPUR*']
# ['*WOOLMER*', '*MAKES SENTIMENTAL*', '*KA']
# ['*WOOLMER*', '*KANPUR*']
# ['*South Africa*', '*Kanpur*', '*India*', '*England']
# ['*South Africa*', '*Kanpur*', '*India*', '*England*', '*Bob Woolmer*']
# ['*Clarence Woolmer*', '*United Province*', '*Ut']
# ['*Clarence Woolmer*', '*United Province*', '*Uttar Pradesh*', '*India*', '*Ranji Trophy*']
# ['*WORLD CUP*']
# ['*SKIING-WORLD CUP*']
# ['*Dmitri Dashinski Belarus*']
# ['*Dmitri Dashinski*', '*Belarus*']
# ['*Fung Permadi*', '*Taiwan*', '*Indra Wi']
# ['*Fung Permadi*', '*Taiwan*', '*Indra Wijaya*', '*Indonesia*']
# ['*Susi Susanti*', '*Indonesia*', '*']
# ['*Susi Susanti*', '*Indonesia*', '*Camilla Martin*', '*Denmark*']
# ['*Ye Zhaoying*', '*China*', '*Gong Zhichao']
# ['*Ye Zhaoying*', '*China*', '*Gong Zhichao*', '*China*']
# ['*Grone Njos*', '*Norway*']
# ['*Grunde Njos*', '*Norway*']
# ['*Okaki Tomomi*', '*Japan*']
# ['*Okazaki Tomomi*', '*Japan*']
# ['*Shizoki Kyoko*', '*Japan*']
# ['*Shimazaki Kyoko*', '*Japan*']
# ['*Billy Dodds*', '*Aberdeen*', '*Pierre']
# ['*Billy Dodds*', '*Aberdeen*', '*Pierre Van Hooydonk*', '*Celtic*']
# ['*Paul Wright*', '*Kilmarnock*', '*Ally McCoist']
# ['*Paul Wright*', '*Kilmarnock*', '*Ally McCoist*', '*Rangers*']
# ['*Andreas Thom*', '*Celtic*', '*Dean Wind']
# ['*Andreas Thom*', '*Celtic*', '*Dean Windass*', '*Aberdeen*']
# ['*Peter van Vossen*', '*Rangers*', '*Gerry']
# ['*Peter van Vossen*', '*Rangers*', '*Gerry Britton*']
# ['*Fabrizio Ravanelli*', '*Middlesbrough*', '']
# ['*Fabrizio Ravanelli*', '*Middlesbrough*', '*Alan Shearer*']
# ['*Matthew Le Tissier*', '*Southampton*', '*']
# ['*Matthew Le Tissier*', '*Southampton*', '*Dwight Yorke*', '*Aston*']
# ['*Villa*', '*Les Ferdinand*', '*Newcastle*', '*']
# ['*Villa*', '*Les Ferdinand*', '*Newcastle*', '*Efan Ekoku*', '*Wimbledon*']
# ['*Marcus Gayle*', '*Wimbledon*', '*Gary Speed']
# ['*Marcus Gayle*', '*Wimbledon*', '*Gary Speed*', '*Everton*', '*Chris*']
# ['*Robbie Fowler*', '*Liverpool*', '*Steve McMan']
# ['*Robbie Fowler*', '*Liverpool*', '*Steve McManaman*', '*Liverpool*']
# ['*British*']
# ['*British rugby union*']
# ['*Boroughmuir*', '*Watkins*']
# ['*Boroughmuir*', '*Watsonians*']
# ['*Dunfermline*', '*Millar*', '*Aberdeen']
# ['*Dunfermline*', '*Millar*', '*Aberdeen*', '*Miller*', '*Rowson*', '*Windass*']
# ['*Kilmarnock*', '*Dundee United*', '*Ola']
# ['*Kilmarnock*', '*Dundee United*', '*Olafsson*']
# ['*Wallaby*', '*London*', '*Saracens*', '']
# ['*Wallaby*', '*London*', '*Saracens*', '*Francois Pienaar*', '*Michael Lynagh*', '*Philippe Sella*']
# ['*Wallaby*', '*Nick Farr-Jones*', '*']
# ['*Wallaby*', '*Nick Farr-Jones*', '*Campese*', '*England*']
# ['*Coventry*', '*Whelan*', '*Tottenham*', '']
# ['*Coventry*', '*Whelan*', '*Tottenham*', '*Sheringham*', '*Sinton*']
# ['*Leicester*', '*Marshall*', '*Blackburn*', '*S']
# ['*Leicester*', '*Marshall*', '*Blackburn*', '*Sutton*']
# ['*Sunderland*', '*Melville*', '*Wimbledon']
# ['*Sunderland*', '*Melville*', '*Wimbledon*', '*Ekoku*', '*Holdsworth*']
# ['*VIEIRA SAVES ARSENAL*']
# ['*VIEIRA*', '*ARSENAL*']
# ['*Frenchman*', '*Patrick Vieira*', '*English*', '*']
# ['*Frenchman*', '*Patrick Vieira*', '*English*', '*Arsenal*', '*Derby*']
# ['*London*', '*Dean Sturridge*', '*Darryl Powell*', '']
# ['*London*', '*Dean Sturridge*', '*Darryl Powell*', '*Arsenal*', '*Tony Adams*']
# ['*Liverpool*', '*Guy Whittingham*', '*Sheffield Wednesday']
# ['*Liverpool*', '*Guy Whittingham*', '*Sheffield Wednesday*']
# ['*Efan Ekoku*', '*Dean Holdsworth*', '*Wim']
# ['*Efan Ekoku*', '*Dean Holdsworth*', '*Wimbledon*', '*Arsenal*']
# ['*SCOTTISH LEAGUE*', '*CUP*']
# ['*SCOTTISH*']
# ['*SCOTTISH LEAGUE*', '*CUP*']
# ['*SCOTTISH*']
# ['*Fife*', '*Partick*', '*Stirling*', '']
# ['*Fife*', '*Partick*', '*Stirling*', '*St Mirren*']
# ['*Albion*', '*Forfar*', '*Huntly*', '*']
# ['*Albion*', '*Forfar*', '*Huntly*', '*Clyde*']
# ['*ENGLISH*', '*LEAGUE*', '*CUP*']
# ['*ENGLISH*']
# ['*ENGLISH*', '*LEAGUE*', '*CUP*']
# ['*ENGLISH*']
# ['*RUGBY UNION*', '*CAMPESE*', '*WALLABY']
# ['*RUGBY UNION*', '*CAMPESE*', '*WALLABY*']
# ['*Wallabies*', '*Campese*', '*Wallaby']
# ['*Wallabies*', '*Campese*', '*Wallaby*']
# ['*RUGBY UNION*', '*AUSTRALIA*', '*BARBARI']
# ['*RUGBY UNION*', '*AUSTRALIA*', '*BARBARIANS*']
# ['*Barbarians*', '*Alan Bateman*', '*Scott Quinnell']
# ['*Barbarians*', '*Alan Bateman*', '*Scott Quinnell*']
# ['*Clinton Whitelaw*', '*Mark Cayeux*', '*Zimba']
# ['*Clinton Whitelaw*', '*Mark Cayeux*', '*Zimbabwe*']
# ['*Trevor Dodds*', '*Namibia*', '*Schal']
# ['*Trevor Dodds*', '*Namibia*', '*Schalk van der*']
# ['*Sean Farrell*', '*Zimbabwe*', '*Glen']
# ['*Sean Farrell*', '*Zimbabwe*', '*Glen Cayeux*']
# ['*Albanian*', '*Astrit Hafizi*', '*FIFA']
# ['*Albanian*', '*Astrit Hafizi*', '*FIFA*', "*Saturday'sWorld Cup*", '*Northern Ireland*']
# ['*World soccer*', '*Albania*', '*Balkan*']
# ['*Albania*', '*Balkan*']
# ['*FIFA*', '*Albania*', '*Albanian Football Association*', '*']
# ['*FIFA*', '*Albania*', '*Albanian Football Association*', '*Eduard Dervishi*']
# ['*Artur Lekbello*', '*Hafizi*', '*Bel']
# ['*Artur Lekbello*', '*Hafizi*', '*Belfast*']
# ['*Blenderi Nallbani*', '*Armir Grima*']
# ['*Blendi Nallbani*', '*Armir Grima*']
# ['*Rudi Vata*', '*Saimir Malko*', '']
# ['*Rudi Vata*', '*Saimir Malko*', '*Arjan Xhumba*', '*Ilir Shulku*', '*Afrim Tole*', '*Nevil Dede*', '*Arjan Bellai*']
# ['*Bledar Kola*', '*Altin Haxhi*', '']
# ['*Bledar Kola*', '*Altin Haxhi*', '*Sokol Prenga*', '*Ervin Fakaj*']
# ['*Altin Rraklli*', '*Viktor Paco*', '']
# ['*Altin Rraklli*', '*Viktor Paco*', '*Fatmir Vata*', '*Erjon Bogdani*']
# ['*OBART*', '*Australia*']
# ['*HOBART*', '*Australia*']
# ['*Australia*', '*Dean Jones*', '*Victoria*', '*She']
# ['*Australia*', '*Dean Jones*', '*Victoria*', '*Sheffield Shield*', '*Tasmania*']
# ['*Victoria*', '*Hobart*', '*Bellerive O']
# ['*Victoria*', '*Hobart*', '*Bellerive Oval*']
# ['*Jones*', '*Tasmanian*', '*David Bo']
# ['*Jones*', '*Tasmanian*', '*David Boon*', '*Shaun Young*', '*Michael DiVenuto*']
# ['*Jones*', '*Australia*', '*Shane Warne*', '']
# ['*Jones*', '*Australia*', '*Shane Warne*', '*Laurie Harper*']
# ['*OBART*', '*Australia*']
# ['*HOBART*', '*Australia*']
# ['*Sheffield Shield*', '*Tasmania*', '*Victori']
# ['*Sheffield Shield*', '*Tasmania*', '*Victoria*', '*Bellerive Oval*']
# ['*SOUTH KOREA*', '*BERTH*']
# ['*SOUTH KOREA*']
# ['*Ronny Wabia*', '*Indonesia*', '*Kor']
# ['*Ronny Wabia*', '*Indonesia*', '*Korean*', '*Kim Byung*']
# ['*Indonesian*', '*Hendro Kartiko*', '*Kore']
# ['*Indonesian*', '*Hendro Kartiko*', '*Koreans*']
# ['*Indonesia*', '*Hendro Kartiko*', '*A']
# ['*Indonesia*', '*Hendro Kartiko*', '*Agung Setyabudi*', '*Suwandi Siswoyo*', '*Yeyen Tumera*', '*Aples Tecuari*', '*Sudiriman*', '*Widodo Gahyo Purta*', '*Ronny Wabia*', '*Bima Sakti*', '*Chris Yarangga*', '*Francis Wewengken*', '*Marzuki Badriawan*']
# ['*South Korea*', '*Kim Byung Ji*', '*Kim Pan Keun']
# ['*South Korea*', '*Kim Byung Ji*', '*Kim Pan Keun*', '*Huh Ki Tae*', '*Roh Sang Rae*', '*Sin Tae Yong*', '*Kim Do Hoon*', '*Ko Jeong Woon*', '*Ha Seok Ju*', '*Hwang Sun Hong*', '*Lee Young Jin*', '*Yoo Sang Chul*', '*Kim Joo Sung*']
# ['*Zafririm Holon*', '*Hapoel Petah']
# ['*Zafririm Holon*', '*Hapoel Petah Tikva*']
# ['*Hapoel Kfar Sava*', '*Bnei Yehu']
# ['*Hapoel Kfar Sava*', '*Bnei Yehuda*']
# ['*Ironi Rishon Lezion*', '*Maccabi Herzl']
# ['*Ironi Rishon Lezion*', '*Maccabi Herzliya*']
# ["*Hapoel Beit She'an*", '*Hapoel Beers']
# ["*Hapoel Beit She'an*", '*Hapoel Beersheba*']
# ['*Maccabi Petah Tikva*', '*Hapoel Haif']
# ['*Maccabi Petah Tikva*', '*Hapoel Haifa*']
# ['*UAE*', '*Hassan Ahmed*', '*Adnan']
# ['*UAE*', '*Hassan Ahmed*', '*Adnan Al Talyani*', '*Bakhit Saad*']
# ['*Indonesia*', '*Ronny Wabia*', '*Wi']
# ['*Indonesia*', '*Ronny Wabia*', '*Widodo Putra*']
# ['**']
# ['*National*']
# ['*EASTERN*']
# ['*EASTERN CONFERENCE*']
# ['*ATLANTIC DIVISION*']
# ['*ATLANTIC*']
# ['*WESTERN*']
# ['*WESTERN CONFERENCE*']
# ['*MIDWEST DIVISION*']
# ['**']
# ['*PACIFIC DIVISION*']
# ['*PACIFIC*']
# ['*LA*', '*NEW YORK*']
# ['*LA CLIPPERS*', '*NEW YORK*']
# ['**']
# ['*Association*']
# ['**']
# ['*League*']
# ['*EASTERN*']
# ['*EASTERN CONFERENCE*']
# ['*NORTHEAST DIVISION*']
# ['**']
# ['*ATLANTIC DIVISION*']
# ['*ATLANTIC*']
# ['*WESTERN*']
# ['*WESTERN CONFERENCE*']
# ['*PACIFIC DIVISION*']
# ['*PACIFIC*']
# ['*NY*', '*TORONTO*']
# ['*NY RANGERS*', '*TORONTO*']
# ['**']
# ['*League*']
# ['*NHL*', '*CANUCKS RW*']
# ['*NHL*', '*CANUCKS*', '*BURE*']
# ['*Vancouver Canucks*', '*Pavel Bure*', '*']
# ['*Vancouver Canucks*', '*Pavel Bure*', '*National Hockey League*', '*Buffalo Sabres*', '*Garry Galley*']
# ['*Bure*', '*Vancouver*', '*Galley*', '*']
# ['*Bure*', '*Vancouver*', '*Galley*', '*Buffalo*']
# ['*Bure*', '*Galley*', '*NHL*', '*Brian']
# ['*Bure*', '*Galley*', '*NHL*', '*Brian Burke*']
# ['*German*', '*Axel Schulz*', '*Cuba*', '*']
# ['*German*', '*Axel Schulz*', '*Cuba*', '*Jose Ribalta*', '*International Boxing Federation*']
# ['*Real Madrid*', '*Davor Suker*', '*Predrag Mi']
# ['*Real Madrid*', '*Davor Suker*', '*Predrag Mijatovic*', '*Barcelona*']
# ['*New Year*', '*Real*', '*Christmas*']
# ['*Real*']
# ['*New Year*', '*Real*', '*Christmas*']
# ['*Real*']
# ['*Barcelona*', '*Croatian*', '*Suker']
# ['*Barcelona*', '*Croatian*', '*Suker*', '*Montenegrin*', '*Mijatovic*', '*Clarence Seedorf*']
# ['*Brazilian*', '*Marcelo*', '*Yugoslav*', '']
# ['*Brazilian*', '*Marcelo*', '*Yugoslav*', '*Zeljko Petrovic*', '*Dutch*', '*PSV Eindhoven*', '*Volendam*']
# ['*Feyenoord*', '*Ajax Amsterdam*', '*PS']
# ['*Feyenoord*', '*Ajax Amsterdam*', '*PSV*']
# ['*Ajax*', '*AZ Alkmaar*', '*Feyen']
# ['*Ajax*', '*AZ Alkmaar*', '*Feyenoord*', '*UEFA Cup*', '*Tenerife*', '*De Graafschap Doetinchem*']
# ['*Charlton*', '*Peggy*', '*Ireland Irish*', '']
# ['*Charlton*', '*Peggy*', '*Ireland*', '*Irish*', '*Dick Spring*', '*Charlton*']
# ['*Charlton*', '*Peggy*', '*Ireland Irish*', '']
# ['*Charlton*', '*Peggy*', '*Ireland*', '*Irish*', '*Dick Spring*', '*Charlton*']
# ['*Ireland World Cup European*', '*Germany Irish*', '*Engla']
# ['*Ireland*', '*World Cup*', '*European*', '*Germany*', '*Irish*', '*England*']
# ['*Ireland World Cup European*', '*Germany Irish*', '*Engla']
# ['*Ireland*', '*World Cup*', '*European*', '*Germany*', '*Irish*', '*England*']
# ['*Ireland World Cup European*', '*Germany Irish*', '*Engla']
# ['*Ireland*', '*World Cup*', '*European*', '*Germany*', '*Irish*', '*England*']

# %%
# conell_false_pos
# conell_false_neg
conell_errors
# Out:
# 681

# %%
conell_true_pos/(conell_true_pos+conell_errors)
# Out:
# 0.8797457178174113

# %%
# Precision = TP/TP+FP
conell_true_pos/(conell_true_pos+conell_false_pos+conell_errors)
# Out:
# 0.8610438990667127

# %%
# Recall = TP/TP+FN
conell_true_pos/(conell_true_pos+conell_false_neg+conell_errors)
# Out:
# 0.631752472736495

# %%
# lower_normal = 0.88
conell_true_pos/(conell_true_pos+conell_errors)
# Out:
# 0.8816766890696852

# %%
# lower_normal
# Precision = TP/TP+FP = 0.859
conell_true_pos/(conell_true_pos+conell_false_pos+conell_errors)
# Out:
# 0.8597792342186961

# %%
# lower_normal
# Recall = TP/TP+FN = 0.63
conell_true_pos/(conell_true_pos+conell_false_neg+conell_errors)
# Out:
# 0.633418043202033

# %%
f1_score(conell_target_text, conell_pred_decoded, average='macro')
# Out:
# 0.5511930634811548

# %%
f1_score(conell_target_text, conell_pred_decoded, average='micro')
# Out:
# 0.795592925485648

# %%
f1_score(conell_target_text, conell_pred_decoded, average='weighted')
# Out:
# 0.7995816577656156

# %%
# Out:
# ['*JAPAN*', '*CHINA*']

# %%
target_encodings = []
for text in conell_test_data["target_text"]:
    target_encodings.append(tokenizer('ner: ' + text, return_tensors="pt", padding=True, truncation=True, max_length=512).input_ids)

# %%
len(conell_tokens)
# Out:
# 3449

# %%
len(target_encodings[0][0])
# Out:
# 14

# %%
f1_score(target_encodings[0][0], conell_tokens[0][0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-12e8aea03cb2> in <module>
# ----> 1 f1_score(target_encodings[0][0], conell_tokens[0][0])
#
# ~/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py in f1_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1129         average=average,
#    1130         sample_weight=sample_weight,
# -> 1131         zero_division=zero_division,
#    1132     )
#    1133
#
# ~/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py in fbeta_score(y_true, y_pred, beta, labels, pos_label, average, sample_weight, zero_division)
#    1268         warn_for=("f-score",),
#    1269         sample_weight=sample_weight,
# -> 1270         zero_division=zero_division,
#    1271     )
#    1272     return f
#
# ~/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1542     if beta < 0:
#    1543         raise ValueError("beta should be >=0 in the F-beta score")
# -> 1544     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1545
#    1546     # Calculate tp_sum, pred_sum, true_sum ###
#
# ~/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1346         raise ValueError("average has to be one of " + str(average_options))
#    1347
# -> 1348     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    1349     # Convert to Python primitive type to avoid NumPy type / Python str
#    1350     # comparison. See https://github.com/numpy/numpy/issues/6784
#
# ~/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      82     y_pred : array or indicator matrix
#      83     """
# ---> 84     check_consistent_length(y_true, y_pred)
#      85     type_true = type_of_target(y_true)
#      86     type_pred = type_of_target(y_pred)
#
# ~/miniconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     332         raise ValueError(
#     333             "Found input variables with inconsistent numbers of samples: %r"
# --> 334             % [int(l) for l in lengths]
#     335         )
#     336
#
# ValueError: Found input variables with inconsistent numbers of samples: [14, 34]

# %%
score = 0
for i in range(len(conell_tokens)):
    score += f1_score(target_encodings[i], conell_tokens[i])
score/len(conell_tokens)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-f7c8a369cb2e> in <module>
#       1 score = 0
#       2 for i in range(len(conell_tokens)):
# ----> 3     score += f1_score(target_encodings[i], conell_tokens[i])
#       4 score/len(conell_tokens)
#
# ~/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py in f1_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1129         average=average,
#    1130         sample_weight=sample_weight,
# -> 1131         zero_division=zero_division,
#    1132     )
#    1133
#
# ~/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py in fbeta_score(y_true, y_pred, beta, labels, pos_label, average, sample_weight, zero_division)
#    1268         warn_for=("f-score",),
#    1269         sample_weight=sample_weight,
# -> 1270         zero_division=zero_division,
#    1271     )
#    1272     return f
#
# ~/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1542     if beta < 0:
#    1543         raise ValueError("beta should be >=0 in the F-beta score")
# -> 1544     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1545
#    1546     # Calculate tp_sum, pred_sum, true_sum ###
#
# ~/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1346         raise ValueError("average has to be one of " + str(average_options))
#    1347
# -> 1348     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    1349     # Convert to Python primitive type to avoid NumPy type / Python str
#    1350     # comparison. See https://github.com/numpy/numpy/issues/6784
#
# ~/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#     102     # No metrics support "multiclass-multioutput" format
#     103     if y_type not in ["binary", "multiclass", "multilabel-indicator"]:
# --> 104         raise ValueError("{0} is not supported".format(y_type))
#     105
#     106     if y_type in ["binary", "multiclass"]:
#
# ValueError: multiclass-multioutput is not supported

# %% [markdown]
# ## wikineural test data

# %%
wiki_test_data = read_test_data('./1-NER_Data/1-csv_format/test/wiki_neural_test_data.csv')
wiki_test_data
# Out:
#                                               input_text  \
# 0      On this occasion he failed to gain the support...
# 1      On both these occasions he was backed by the S...
# 2      He also appeared as himself in the 1996 film "...
# 3      The Colorado Rockies were created as an expans...
# 4      He kept busy recording demo tapes at his home ...
# ...                                                  ...
# 11592                                     com , Amazon .
# 11593  In January 2013 , the European Food Safety Aut...
# 11594  All of the games had art true to the series , ...
# 11595  There was also a game made for the Game Boy ba...
# 11596  This system was widely copied in various NATO ...
#
#                                        target_text  word_count  NE_count  \
# 0                *South Wales Miners ' Federation*          20         4
# 1                *South Wales Miners ' Federation*          18         4
# 2                                          *Eddie*          10         1
# 3                 *Colorado Rockies*,*Coors Field*          17         4
# 4                   *La Valencia Hotel*,*La Jolla*          29         5
# ...                                            ...         ...       ...
# 11592                                     *Amazon*           2         1
# 11593  *European Food Safety Authority*,*Monsanto*          27         5
# 11594                                       *Sega*          23         1
# 11595                                   *Game Boy*          20         2
# 11596                                       *NATO*           9         1
#
#        %_NE_in_sentence
# 0                   0.2
# 1                   0.2
# 2                   0.1
# 3                   0.2
# 4                   0.2
# ...                 ...
# 11592               0.5
# 11593               0.2
# 11594               0.0
# 11595               0.1
# 11596               0.1
#
# [11597 rows x 5 columns]

# %%
wiki_tokens = encode_input_as_tokens(wiki_test_data)

# %%
len(wiki_tokens)
# Out:
# 11597

# %%
wiki_pred = predict_ner(model, wiki_tokens)
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500

# %%
wiki_pred_decoded = decode_prediction(wiki_pred)

# %%
wiki_target_text = wiki_test_data['target_text']

# %%
wiki_accuracy = compare_prediction_with_target(wiki_pred_decoded, wiki_target_text)
wiki_accuracy
# Out:
# 0.7992584289040269

# %%
evaluations(predictions=conell_pred_decoded, references=conell_target_text):

# %% [markdown]
# ## onto test data

# %%
onto_test_data = read_test_data('./1-NER_Data/1-csv_format/test/onto_test_data.csv')
onto_test_data
# Out:
#                                               input_text  \
# 0      `` We 're being bombarded by new Treasury and ...
# 1      [buabua] Over these years, our country has bee...
# 2      Sometimes they mixed the ink with glue to prod...
# 3      In over-the-counter trading Friday, Weisfield'...
# 4      Prince William is chasing a polo ball, such of...
# ...                                                  ...
# 11471  Earlier this year, bankers and other investors...
# 11472  When he retired last year, he was the oldest a...
# 11473  At the same time, Westinghouse hopes its ventu...
# 11474                                               yeah
# 11475                                     Finches maybe.
#
#                                              target_text  word_count  \
# 0      *Treasury*,*Dean Witter Reynolds Inc*,*William...          26
# 1                                                     **          30
# 2                                                     **          12
# 3                     *Friday*,*9.50*,*39*,*Weisfield's*          11
# 4                             *British*,*Prince William*          18
# ...                                                  ...         ...
# 11471                    *Earlier this year*,*Rosenthal*          28
# 11472                                        *last year*          16
# 11473  *U.S.*,*European*,*Westinghouse*,*Mitsubishi*,...          36
# 11474                                                 **           1
# 11475                                                 **           2
#
#        NE_count  %_NE_in_sentence
# 0             2               0.1
# 1             0               0.0
# 2             0               0.0
# 3             3               0.3
# 4             2               0.1
# ...         ...               ...
# 11471         2               0.1
# 11472         1               0.1
# 11473         3               0.1
# 11474         0               0.0
# 11475         0               0.0
#
# [11476 rows x 5 columns]

# %%
onto_tokens = encode_input_as_tokens(onto_test_data)

# %%
len(onto_tokens)
# Out:
# 11476

# %%
onto_pred = predict_ner(model, onto_tokens)
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400

# %%
onto_pred_decoded = decode_prediction(onto_pred)

# %%
onto_target_text = onto_test_data['target_text']

# %%
onto_accuracy = compare_prediction_with_target(onto_pred_decoded, onto_target_text)
onto_accuracy
# Out:
# 0.7328337399790867

# %%
evaluations(predictions=conell_pred_decoded, references=conell_target_text):

# %% [markdown]
# ## wnut test data

# %%
wnut_test_data = read_test_data('./1-NER_Data/1-csv_format/test/wnut_test_data.csv')
wnut_test_data
# Out:
#                                             input_text  \
# 0    & gt ; * The soldier was killed when another a...
# 1    & gt ; * Police last week evacuated 80 village...
# 2    The bodies of the soldiers were recovered afte...
# 3    & gt ; * Arrangements are in place to carry th...
# 4      Visuals of the avalanche site in Gurez sector .
# ..                                                 ...
# 810  RT @ marIboros : short girls were born with at...
# 811  A proper # StPatricksDay drink https://t.co/c4...
# 812                       Never Been To Shakers Before
# 813  No Cousins today . . . Pelicans offence could ...
# 814  @ KenyeahMonae It ' s my school fault , girl t...
#
#                         target_text  word_count  NE_count  %_NE_in_sentence
# 0                         *Sonmarg*          27         1               0.0
# 1                   *Waltengoo Nar*          34         2               0.1
# 2    *Avalanche Rescue Teams*,*ART*          32         4               0.1
# 3            *Colonel Rajesh Kalia*          33         3               0.1
# 4                    *Gurez sector*           9         2               0.2
# ..                              ...         ...       ...               ...
# 810                     *marIboros*          11         1               0.1
# 811                              **           6         0               0.0
# 812                       *Shakers*           5         1               0.2
# 813  *Cousins*,*Pelicans*,*Holiday*          22         3               0.1
# 814                *@ KenyeahMonae*          18         1               0.1
#
# [815 rows x 5 columns]

# %%
wnut_tokens = encode_input_as_tokens(wnut_test_data)

# %%
len(wnut_tokens)
# Out:
# 815

# %%
wnut_pred = predict_ner(model, wnut_tokens)
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800

# %%
wnut_pred_decoded = decode_prediction(wnut_pred)

# %%
wnut_target_text = wnut_test_data['target_text']

# %%
wnut_accuracy = compare_prediction_with_target(wnut_pred_decoded, wnut_target_text)
wnut_accuracy
# Out:
# 0.49693251533742333

# %%
evaluations(predictions=wnut_pred_decoded, references=wnut_target_text):
