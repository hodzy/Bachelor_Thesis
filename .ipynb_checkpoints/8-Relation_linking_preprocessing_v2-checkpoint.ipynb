# %%
import json
import pandas as pd
import time

# %%
def get_relation_label(rel_id):
    label = ''
    API_ENDPOINT = "https://www.wikidata.org/w/api.php"
    params = {
        'action': 'wbgetentities',
        'format': 'json',
        'languages': 'en',
        'props': 'labels',
        'ids': ''
    }
      
    params['ids'] = str(rel_id)

    try:
        response = requests.get(API_ENDPOINT, params = params).json()['entities']
        label = response[str(rel_id)]['labels']['en']['value']
    except:
        return (rel_id, label)
    return (rel_id, label)

# %%
import requests
import time

def find_relation_names_and_ids(qid):
    relation_name_id = dict()

    url = 'https://query.wikidata.org/sparql'
    query = '''
    SELECT Distinct ?wd ?wdLabel
    WHERE {
      VALUES (?s) {(wd:entity)}
      # ?s ?wdt ?o .
      # ?wd wikibase:directClaim ?wdt .
      # ?wd rdfs:label ?wdLabel .
      OPTIONAL {
        # ?o rdfs:label ?oLabel .
        FILTER (lang(?oLabel) = "en")
      }
      FILTER (lang(?wdLabel) = "en")
      BIND (COALESCE(?oLabel, ?o) AS ?ooLabel)
     }
    '''
    copy_query = query.replace('entity', qid)
    r = requests.get(url, params = {'format': 'json', 'query': copy_query})
    time.sleep(2)
#     try:
    data = r.json()
    for rel in data['results']['bindings'][:100]:
        if len(rel['wdLabel']['value']) < 35:
            relation_name_id[rel['wdLabel']['value']] = rel['wd']['value'].rsplit('/', 1)[1]
    return relation_name_id
#     except:
#         print(qid)
#         return ''

# %%
# jupyter notebook never finishes processing using multiprocessing python 3
# https://stackoverflow.com/questions/47313732/jupyter-notebook-never-finishes-processing-using-multiprocessing-python-3

from multiprocessing import Pool
from functools import partial
import inspect
import time
import os
import requests


def parallal_task(func, iterable, *params): 
    with open(f'./tmp_func.py', 'w') as file:
        file.write("import requests \n")
        file.write(inspect.getsource(func).replace(func.__name__, 'task'))

    from tmp_func import task
    pool = Pool(processes=15)
    res = pool.map(task, iterable)
    pool.close()
    
    os.remove('./tmp_func.py')
    return res

# %%
from multiprocessing import Pool
from functools import partial
import inspect
import time
import os
import requests


def parallal_task_2(func, iterable, *params): 
    with open(f'./tmp_func_2.py', 'w') as file:
        file.write("import requests \n")
        file.write("import time \n")
        file.write(inspect.getsource(func).replace(func.__name__, 'task'))

    from tmp_func_2 import task
    pool = Pool(processes=15)
    res = pool.map(task, iterable)
    pool.close()
    
    os.remove('./tmp_func_2.py')
    return res

# %%
with open('2-NEL_Data/0-raw_data/simple_questions_v2/annotated_wd_data_train.txt', encoding='utf-8') as file:
    lines = file.readlines()

# print(len(lines))
training_data = []
for line in lines:
    line = line.strip().split('\t', 3)
    del line[2]
    
    training_data.append(line)
    
qids = [line[0] for line in training_data]
target_relation = [line[1].replace('R', 'P') for line in training_data]
questions = [line[2] for line in training_data]

# %%
qids[0]
# Out:
# 'Q126399'

# %%
find_relation_names_and_ids('Q4021138')
# Out:
# {'cast member': 'P161',
#  'country of origin': 'P495',
#  'distribution format': 'P437',
#  'instance of': 'P31',
#  'genre': 'P136',
#  'color': 'P462',
#  'director': 'P57',
#  'CNC film rating (Romania)': 'P3402',
#  'production company': 'P272',
#  'Apple TV movie ID': 'P9586',
#  'title': 'P1476',
#  'Freebase ID': 'P646',
#  'Elonet movie ID': 'P2346',
#  'Vudu video ID': 'P7334',
#  'duration': 'P2047',
#  'PORT film ID': 'P905',
#  'ČSFD film ID': 'P2529',
#  'LdiF ID': 'P3107',
#  'publication date': 'P577',
#  'Kinopoisk film ID': 'P2603',
#  'AllMovie title ID': 'P1562',
#  'Open Media Database film ID': 'P3302',
#  'IMDb ID': 'P345',
#  'MovieMeter film ID': 'P1970',
#  'TV.com ID': 'P2638',
#  'Sratim ID': 'P3145',
#  'Douban film ID': 'P4529',
#  'Moviepilot.de film ID': 'P5786',
#  'Letterboxd film ID': 'P6127',
#  'FilmAffinity ID': 'P480',
#  'elFilm film ID': 'P3143',
#  'OFDb film ID': 'P3138',
#  'Deutsche Synchronkartei film ID': 'P3844',
#  'TMDb movie ID': 'P4947',
#  'iTunes movie ID': 'P6398',
#  'FandangoNow ID': 'P7970'}

# %%
# counter = 0
# for qid in qids[:100]:
# #     print(qid)
#     counter += 1
#     print(counter)
#     if not find_relation_names_and_ids(str(qid)):
#         counter += 1

# %%
# counter

# %%
start = time.time()
relation_id_name = parallal_task_2(find_relation_names_and_ids, qids[:100])
print(time.time() - start)
len(relation_id_name)
# Out:
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/HadyElkady/miniconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/HadyElkady/miniconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/HadyElkady/work/Bachelor_thesis/tmp_func_2.py", line 26, in task
#     data = r.json()
#   File "/home/HadyElkady/miniconda3/lib/python3.7/site-packages/requests/models.py", line 900, in json
#     return complexjson.loads(self.text, **kwargs)
#   File "/home/HadyElkady/miniconda3/lib/python3.7/json/__init__.py", line 348, in loads
#     return _default_decoder.decode(s)
#   File "/home/HadyElkady/miniconda3/lib/python3.7/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/home/HadyElkady/miniconda3/lib/python3.7/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# """
#
# The above exception was the direct cause of the following exception:
#
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-11-d79383b3136b> in <module>
#       1 start = time.time()
# ----> 2 relation_id_name = parallal_task_2(find_relation_names_and_ids, qids[:100])
#       3 print(time.time() - start)
#       4 len(relation_id_name)
#
# <ipython-input-5-d781ab24a7e7> in parallal_task_2(func, iterable, *params)
#      15     from tmp_func_2 import task
#      16     pool = Pool(processes=15)
# ---> 17     res = pool.map(task, iterable)
#      18     pool.close()
#      19
#
# ~/miniconda3/lib/python3.7/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     266         in a list that is returned.
#     267         '''
# --> 268         return self._map_async(func, iterable, mapstar, chunksize).get()
#     269
#     270     def starmap(self, func, iterable, chunksize=None):
#
# ~/miniconda3/lib/python3.7/multiprocessing/pool.py in get(self, timeout)
#     655             return self._value
#     656         else:
# --> 657             raise self._value
#     658
#     659     def _set(self, i, obj):
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
relation_id_name

# %%
ex = {'significant event': 1}
outpput = find_relation_names_and_ids('Q90')
dict(ex, **outpput)
# Out:
# {'significant event': 'P793',
#  'shares border with': 'P47',
#  'continent': 'P30',
#  'contains the administrative territorial entity': 'P150',
#  'official language': 'P37',
#  'language used': 'P2936',
#  'legal form': 'P1454',
#  'instance of': 'P31',
#  'country': 'P17',
#  'capital of': 'P1376',
#  'twinned administrative body': 'P190',
#  'located in or next to body of water': 'P206',
#  'owner of': 'P1830',
#  'located in time zone': 'P421',
#  'category of associated people': 'P1792',
#  'category for people born here': 'P1464',
#  'patron saint': 'P417',
#  'part of': 'P361',
#  'office held by head of government': 'P1313',
#  'award received': 'P166',
#  'category for people who died here': 'P1465',
#  'described by source': 'P1343',
#  'diocese': 'P708',
#  'list of monuments': 'P1456',
#  'highest point': 'P610',
#  'on focus list of Wikimedia project': 'P5008',
#  'economy of topic': 'P8744',
#  "topic's main Wikimedia portal": 'P1151',
#  'category for honorary citizens of entity': 'P10280',
#  'category for films shot at this location': 'P1740',
#  'located in the administrative territorial entity': 'P131',
#  "topic's main template": 'P1424',
#  'geography of topic': 'P2633',
#  "topic's main category": 'P910',
#  'flag': 'P163',
#  'named after': 'P138',
#  'replaces': 'P1365',
#  'has part(s) of the class': 'P2670',
#  'legislative body': 'P194',
#  'industry': 'P452',
#  'foods traditionally associated': 'P868',
#  'open data portal': 'P8402',
#  'category for maps': 'P7867',
#  'district heating grid': 'P9611',
#  'category of people buried here': 'P1791',
#  'history of topic': 'P2184',
#  'coat of arms': 'P237',
#  'demographics of topic': 'P9241',
#  'drainage basin': 'P4614',
#  'authority': 'P797',
#  'head of government': 'P6',
#  'activity policy in this place': 'P5023',
#  'National Gallery of Victoria artist ID': 'P2041',
#  'FAST ID': 'P2163',
#  'Quora topic ID': 'P3417',
#  'FINESS ID': 'P4058',
#  'Klexikon article ID': 'P6573',
#  'Den Store Danske ID': 'P8313',
#  'Jewish Encyclopedia ID': 'P8590',
#  'museum-digital place ID': 'P9957',
#  'Wikisimpsons ID': 'P10291',
#  'Urban Electric Transit city ID': 'P10321',
#  'DPLA subject term': 'P4272',
#  'SBN place ID': 'P10397',
#  'symogih.org ID': 'P10480',
#  'National Library of Israel ID (old)': 'P949',
#  'Moegirlpedia ID': 'P5737',
#  'Encyclopedia of China ID (Second Edition)': 'P9545',
#  'Süddeutsche Zeitung topic ID': 'P10916',
#  'population': 'P1082',
#  'official name': 'P1448',
#  'OmegaWiki Defined Meaning': 'P1245',
#  'Commons gallery': 'P935',
#  'Commons category': 'P373',
#  'photosphere image': 'P4640',
#  'Twitter username': 'P2002',
#  'French Vikidia ID': 'P7818',
#  'KBpedia ID': 'P8408',
#  'social media followers': 'P8687',
#  'Gyldendals Teaterleksikon ID': 'P9466',
#  'Armeniapedia ID': 'P9629',
#  'ISO 3166-2 code': 'P300',
#  'area': 'P2046',
#  'demonym': 'P1549',
#  'inception': 'P571',
#  'postal code': 'P281',
#  'INSEE municipality code': 'P374',
#  'Analysis & Policy Observatory term ID': 'P7870',
#  'RKD thesaurus ID': 'P8519',
#  'local dialing code': 'P473',
#  'official website': 'P856',
#  'native label': 'P1705',
#  'Store norske leksikon ID': 'P4342',
#  'UK Parliament thesaurus ID': 'P4527',
#  'Gynopedia ID': 'P5843',
#  'annual number of weddings': 'P5982',
#  'National Library of Israel J9U ID': 'P8189',
#  'EHESS ID of a French commune': 'P8422',
#  "Enciclopedia dell'Arte Antica ID": 'P9809',
#  'licence plate code': 'P395'}

# %%
total_len = 0
for r in relations[:90]:
    if len(r) < 40:
        total_len += len(r)
total_len
# Out:
# 1519

# %%
qids
# Out:
# ['Q126399',
#  'Q12439',
#  'Q7370831',
#  'Q6817891',
#  'Q1297',
#  'Q193592',
#  'Q19896779',
#  'Q6849115',
#  'Q842256',
#  'Q7273',
#  'Q247643',
#  'Q6135854',
#  'Q4021138',
#  'Q184622',
#  'Q2405480',
#  'Q145410',
#  'Q4921907',
#  'Q1698',
#  'Q237514',
#  'Q3738651',
#  'Q388408',
#  'Q93204',
#  'Q3643721',
#  'Q7063408',
#  'Q707230',
#  'Q590103',
#  'Q384243',
#  'Q71277',
#  'Q2227506',
#  'Q101625',
#  'Q2321544',
#  'Q5667368',
#  'Q25989',
#  'Q734861',
#  'Q55442',
#  'Q3986646',
#  'Q590145',
#  'Q438503',
#  'Q7749083',
#  'Q36322',
#  'Q234472',
#  'Q1530721',
#  'Q43',
#  'Q710600',
#  'Q5327069',
#  'Q1297',
#  'Q6230278',
#  'Q984029',
#  'Q668083',
#  'Q154581',
#  'Q1348496',
#  'Q6687871',
#  'Q5553855',
#  'Q5506118',
#  'Q6836909',
#  'Q56094',
#  'Q1120576',
#  'Q3154598',
#  'Q222052',
#  'Q43343',
#  'Q1219013',
#  'Q6249503',
#  'Q2023740',
#  'Q2138789',
#  'Q7680816',
#  'Q6050048',
#  'Q10280325',
#  'Q7349401',
#  'Q3116899',
#  'Q154194',
#  'Q2605514',
#  'Q1075868',
#  'Q6221698',
#  'Q6285529',
#  'Q13636457',
#  'Q147589',
#  'Q5174096',
#  'Q605186',
#  'Q5466725',
#  'Q29172',
#  'Q6012446',
#  'Q4707525',
#  'Q7741195',
#  'Q532474',
#  'Q66832',
#  'Q215506',
#  'Q11633',
#  'Q336167',
#  'Q132821',
#  'Q93204',
#  'Q580',
#  'Q1090769',
#  'Q128758',
#  'Q5363152',
#  'Q6422107',
#  'Q974466',
#  'Q1342',
#  'Q4906481',
#  'Q17361420',
#  'Q7351133',
#  'Q6607',
#  'Q15378683',
#  'Q7723204',
#  'Q193752',
#  'Q5106113',
#  'Q3088054',
#  'Q980200',
#  'Q710247',
#  'Q2377261',
#  'Q718562',
#  'Q637190',
#  'Q5497332',
#  'Q133032',
#  'Q4374943',
#  'Q16223459',
#  'Q7294392',
#  'Q3728410',
#  'Q13156',
#  'Q724154',
#  'Q206159',
#  'Q12124483',
#  'Q150651',
#  'Q164444',
#  'Q98643',
#  'Q52354',
#  'Q189059',
#  'Q128581',
#  'Q130232',
#  'Q7194357',
#  'Q200092',
#  'Q7605291',
#  'Q5042233',
#  'Q786545',
#  'Q225852',
#  'Q3194914',
#  'Q568123',
#  'Q272076',
#  'Q7914811',
#  'Q82955',
#  'Q195768',
#  'Q18648361',
#  'Q312782',
#  'Q2422991',
#  'Q269585',
#  'Q2662148',
#  'Q2883930',
#  'Q4346512',
#  'Q1143118',
#  'Q7708817',
#  'Q124112',
#  'Q41548',
#  'Q3136453',
#  'Q2577628',
#  'Q598834',
#  'Q4680824',
#  'Q559514',
#  'Q12214',
#  'Q7091435',
#  'Q645928',
#  'Q104994',
#  'Q3294052',
#  'Q428672',
#  'Q7637680',
#  'Q159416',
#  'Q7365833',
#  'Q197281',
#  'Q13582652',
#  'Q2405480',
#  'Q503538',
#  'Q8058931',
#  'Q766445',
#  'Q6656486',
#  'Q6283402',
#  'Q4308215',
#  'Q4729974',
#  'Q956355',
#  'Q5088967',
#  'Q910695',
#  'Q3519134',
#  'Q5389642',
#  'Q153868',
#  'Q20378',
#  'Q1213408',
#  'Q15486802',
#  'Q1572362',
#  'Q3282054',
#  'Q7175853',
#  'Q7328528',
#  'Q4790844',
#  'Q1893261',
#  'Q1041909',
#  'Q202663',
#  'Q36180',
#  'Q8036432',
#  'Q1292432',
#  'Q65',
#  'Q1186280',
#  'Q9503',
#  'Q583470',
#  'Q438503',
#  'Q76579',
#  'Q10535968',
#  'Q7820891',
#  'Q3400887',
#  'Q5429952',
#  'Q7091297',
#  'Q525',
#  'Q4149559',
#  'Q401383',
#  'Q1787206',
#  'Q1296639',
#  'Q228992',
#  'Q7328281',
#  'Q7743116',
#  'Q7932701',
#  'Q1645442',
#  'Q694052',
#  'Q3960677',
#  'Q3038',
#  'Q35765',
#  'Q2964743',
#  'Q3544737',
#  'Q3244733',
#  'Q281404',
#  'Q550265',
#  'Q3634696',
#  'Q1635514',
#  'Q1777268',
#  'Q3569503',
#  'Q146143',
#  'Q74939',
#  'Q7783676',
#  'Q715010',
#  'Q11366',
#  'Q7377158',
#  'Q1052054',
#  'Q4315933',
#  'Q11093',
#  'Q17091147',
#  'Q7049742',
#  'Q7405215',
#  'Q55408',
#  'Q5071149',
#  'Q4126954',
#  'Q390779',
#  'Q6132601',
#  'Q3479672',
#  'Q83440',
#  'Q12078',
#  'Q2623036',
#  'Q7204222',
#  'Q5048515',
#  'Q1054574',
#  'Q603075',
#  'Q749047',
#  'Q4764669',
#  'Q5002178',
#  'Q14950673',
#  'Q11399',
#  'Q828',
#  'Q2415347',
#  'Q1171556',
#  'Q510397',
#  'Q41323',
#  'Q39829',
#  'Q105527',
#  'Q11425',
#  'Q15040737',
#  'Q1007',
#  'Q984634',
#  'Q1053252',
#  'Q333637',
#  'Q262802',
#  'Q4661277',
#  'Q3710055',
#  'Q3434241',
#  'Q208850',
#  'Q678437',
#  'Q2605579',
#  'Q6339891',
#  'Q1157349',
#  'Q3794894',
#  'Q25989',
#  'Q9759',
#  'Q2294674',
#  'Q17417',
#  'Q860750',
#  'Q822413',
#  'Q12706',
#  'Q165691',
#  'Q13595311',
#  'Q1931639',
#  'Q5539359',
#  'Q809118',
#  'Q3259696',
#  'Q504463',
#  'Q1333364',
#  'Q7460805',
#  'Q167986',
#  'Q2274654',
#  'Q592330',
#  'Q2903678',
#  'Q5909549',
#  'Q794148',
#  'Q570545',
#  'Q289',
#  'Q20438283',
#  'Q83440',
#  'Q17023163',
#  'Q494306',
#  'Q2081339',
#  'Q1050571',
#  'Q7993791',
#  'Q335080',
#  'Q512535',
#  'Q37333',
#  'Q1792258',
#  'Q315540',
#  'Q268078',
#  'Q7979149',
#  'Q3505570',
#  'Q3212804',
#  'Q732474',
#  'Q14759972',
#  'Q1230723',
#  'Q25089',
#  'Q41621',
#  'Q15712790',
#  'Q941023',
#  'Q312886',
#  'Q19204627',
#  'Q147921',
#  'Q7732102',
#  'Q11576',
#  'Q6390251',
#  'Q740516',
#  'Q1363729',
#  'Q2621621',
#  'Q650906',
#  'Q1071873',
#  'Q16252651',
#  'Q6895044',
#  'Q6424755',
#  'Q578119',
#  'Q5387709',
#  'Q186360',
#  'Q5333876',
#  'Q668352',
#  'Q557632',
#  'Q7116838',
#  'Q7381049',
#  'Q41782',
#  'Q765783',
#  'Q16196202',
#  'Q2756904',
#  'Q7760093',
#  'Q7267211',
#  'Q6390721',
#  'Q6115262',
#  'Q1325288',
#  'Q1899202',
#  'Q7561122',
#  'Q696557',
#  'Q16832088',
#  'Q1141746',
#  'Q716373',
#  'Q1189689',
#  'Q2965249',
#  'Q7435072',
#  'Q5272822',
#  'Q963426',
#  'Q5416358',
#  'Q149305',
#  'Q2086913',
#  'Q901441',
#  'Q205679',
#  'Q10295500',
#  'Q193592',
#  'Q170270',
#  'Q10956161',
#  'Q2702192',
#  'Q3616',
#  'Q3546604',
#  'Q1474376',
#  'Q16252588',
#  'Q2325234',
#  'Q2701232',
#  'Q923911',
#  'Q5394090',
#  'Q469321',
#  'Q49451',
#  'Q3012576',
#  'Q152232',
#  'Q860626',
#  'Q6147160',
#  'Q1644143',
#  'Q4303000',
#  'Q93204',
#  'Q275314',
#  'Q3718981',
#  'Q3499871',
#  'Q11399',
#  'Q7143125',
#  'Q3458074',
#  'Q3840684',
#  'Q6077027',
#  'Q150169',
#  'Q785267',
#  'Q5542135',
#  'Q7747',
#  'Q483412',
#  'Q11366',
#  'Q915845',
#  'Q5080802',
#  'Q7202044',
#  'Q7290612',
#  'Q929840',
#  'Q508225',
#  'Q239371',
#  'Q3285338',
#  'Q7437205',
#  'Q193',
#  'Q1424273',
#  'Q754474',
#  'Q7184227',
#  'Q220',
#  'Q5235209',
#  'Q4860673',
#  'Q7640082',
#  'Q573159',
#  'Q3708793',
#  'Q7857891',
#  'Q5610650',
#  'Q936976',
#  'Q468826',
#  'Q7775275',
#  'Q7512494',
#  'Q2355741',
#  'Q7718709',
#  'Q6814019',
#  'Q765041',
#  'Q49451',
#  'Q11725',
#  'Q896851',
#  'Q1483675',
#  'Q6373686',
#  'Q7341161',
#  'Q7505974',
#  'Q3548491',
#  'Q2211168',
#  'Q34316',
#  'Q3113510',
#  'Q185846',
#  'Q16146261',
#  'Q3197020',
#  'Q43023',
#  'Q3814935',
#  'Q7608322',
#  'Q37653',
#  'Q7185578',
#  'Q1399967',
#  'Q1292464',
#  'Q212431',
#  'Q7770034',
#  'Q7232362',
#  'Q5532780',
#  'Q2241186',
#  'Q6788577',
#  'Q525',
#  'Q4850077',
#  'Q719766',
#  'Q730490',
#  'Q1043600',
#  'Q584226',
#  'Q6024866',
#  'Q7642979',
#  'Q336286',
#  'Q745238',
#  'Q201330',
#  'Q3711',
#  'Q4160546',
#  'Q11399',
#  'Q855091',
#  'Q1602633',
#  'Q519752',
#  'Q6210897',
#  'Q108597',
#  'Q9358',
#  'Q11817500',
#  'Q1397901',
#  'Q11792043',
#  'Q3282103',
#  'Q6502807',
#  'Q845102',
#  'Q497871',
#  'Q1358540',
#  'Q11399',
#  'Q5692662',
#  'Q4840448',
#  'Q3067976',
#  'Q639301',
#  'Q147739',
#  'Q156622',
#  'Q1579557',
#  'Q2464198',
#  'Q20921',
#  'Q358052',
#  'Q642988',
#  'Q459813',
#  'Q2570790',
#  'Q15971215',
#  'Q865498',
#  'Q625552',
#  'Q5043574',
#  'Q6513474',
#  'Q167856',
#  'Q7774455',
#  'Q7742',
#  'Q251098',
#  'Q5287',
#  'Q313105',
#  'Q5020977',
#  'Q887973',
#  'Q1066019',
#  'Q2256891',
#  'Q772867',
#  'Q1048902',
#  'Q40738',
#  'Q5516790',
#  'Q4965886',
#  'Q2907467',
#  'Q6316446',
#  'Q5671745',
#  'Q130232',
#  'Q3086901',
#  'Q136780',
#  'Q34740',
#  'Q296796',
#  'Q903257',
#  'Q311256',
#  'Q2297364',
#  'Q13526',
#  'Q12054356',
#  'Q6883544',
#  'Q5434617',
#  'Q234216',
#  'Q5432653',
#  'Q4995475',
#  'Q1372074',
#  'Q7253245',
#  'Q183504',
#  'Q647282',
#  'Q25372',
#  'Q2085736',
#  'Q3696310',
#  'Q1763846',
#  'Q2784843',
#  'Q1954478',
#  'Q185029',
#  'Q1332068',
#  'Q9256',
#  'Q32277',
#  'Q3829187',
#  'Q2709864',
#  'Q7080559',
#  'Q11863501',
#  'Q238912',
#  'Q4808260',
#  'Q894846',
#  'Q362',
#  'Q1764292',
#  'Q1324620',
#  'Q71073',
#  'Q1348354',
#  'Q596110',
#  'Q3345812',
#  'Q823107',
#  'Q305191',
#  'Q7069487',
#  'Q7710804',
#  'Q1050571',
#  'Q2467066',
#  'Q817138',
#  'Q4992663',
#  'Q6415432',
#  'Q1782272',
#  'Q5650321',
#  'Q669818',
#  'Q669655',
#  'Q57231',
#  'Q3057306',
#  'Q2301826',
#  'Q7754662',
#  'Q7512963',
#  'Q266473',
#  'Q1792',
#  'Q836269',
#  'Q5510498',
#  'Q606594',
#  'Q1274453',
#  'Q7033389',
#  'Q7865507',
#  'Q5907306',
#  'Q2092920',
#  'Q763858',
#  'Q4004081',
#  'Q7373491',
#  'Q206159',
#  'Q23633',
#  'Q5126643',
#  'Q1513688',
#  'Q10339439',
#  'Q967207',
#  'Q768647',
#  'Q11272426',
#  'Q7757380',
#  'Q2020013',
#  'Q2422421',
#  'Q6428974',
#  'Q1580597',
#  'Q6893603',
#  'Q5011312',
#  'Q6174722',
#  'Q1026685',
#  'Q5671493',
#  'Q1368417',
#  'Q538543',
#  'Q3489435',
#  'Q160778',
#  'Q877473',
#  'Q128708',
#  'Q676538',
#  'Q967492',
#  'Q6516810',
#  'Q11399',
#  'Q16218622',
#  'Q16005865',
#  'Q2150804',
#  'Q831593',
#  'Q486043',
#  'Q525',
#  'Q207544',
#  'Q315346',
#  'Q4974307',
#  'Q538274',
#  'Q457010',
#  'Q585659',
#  'Q2449461',
#  'Q360589',
#  'Q213572',
#  'Q3287722',
#  'Q842073',
#  'Q2438253',
#  'Q29658',
#  'Q7519734',
#  'Q6743971',
#  'Q53713',
#  'Q2305471',
#  'Q2608018',
#  'Q2036006',
#  'Q4020645',
#  'Q448951',
#  'Q7732',
#  'Q286080',
#  'Q1035251',
#  'Q208850',
#  'Q558628',
#  'Q5273475',
#  'Q5539395',
#  'Q313639',
#  'Q5102496',
#  'Q15485701',
#  'Q489939',
#  'Q8024879',
#  'Q10277902',
#  'Q8048112',
#  'Q646980',
#  'Q941662',
#  'Q888203',
#  'Q9372853',
#  'Q7926072',
#  'Q46185',
#  'Q184586',
#  'Q5300655',
#  'Q43845',
#  'Q500612',
#  'Q5404618',
#  'Q248583',
#  'Q30',
#  'Q7304060',
#  'Q7344341',
#  'Q4764786',
#  'Q11767850',
#  'Q10737',
#  'Q12810870',
#  'Q346762',
#  'Q5339617',
#  'Q12178252',
#  'Q4316345',
#  'Q1330582',
#  'Q336286',
#  'Q3545193',
#  'Q7358675',
#  'Q56094',
#  'Q5297369',
#  'Q1122047',
#  'Q12387051',
#  'Q19204627',
#  'Q2464146',
#  'Q201330',
#  'Q222720',
#  'Q5474884',
#  'Q873419',
#  'Q142210',
#  'Q7613840',
#  'Q3953058',
#  'Q711857',
#  'Q71206',
#  'Q10436033',
#  'Q112456',
#  'Q983535',
#  'Q7287403',
#  'Q737861',
#  'Q182015',
#  'Q3518748',
#  'Q8058514',
#  'Q1657667',
#  'Q110434',
#  'Q1395485',
#  'Q587593',
#  'Q1305043',
#  'Q858523',
#  'Q49542',
#  'Q2161266',
#  'Q3044734',
#  'Q4743898',
#  'Q16750562',
#  'Q1614896',
#  'Q5703123',
#  'Q153169',
#  'Q130232',
#  'Q506151',
#  'Q10932820',
#  'Q7619996',
#  'Q11098560',
#  'Q2517358',
#  'Q319773',
#  'Q3882117',
#  'Q6457208',
#  'Q482980',
#  'Q16059141',
#  'Q207536',
#  'Q465087',
#  'Q16859329',
#  'Q1676386',
#  'Q958433',
#  'Q9730',
#  'Q3222554',
#  'Q5006142',
#  'Q2558063',
#  'Q6768622',
#  'Q3879122',
#  'Q1042996',
#  'Q487914',
#  'Q1060160',
#  'Q1524946',
#  'Q2066934',
#  'Q289537',
#  'Q1189205',
#  'Q16996331',
#  'Q7105456',
#  'Q269710',
#  'Q2056045',
#  'Q706296',
#  'Q3281134',
#  'Q6696561',
#  'Q1196554',
#  'Q2455623',
#  'Q1420629',
#  'Q7292446',
#  'Q201788',
#  'Q83440',
#  'Q3299319',
#  'Q4721703',
#  'Q3282483',
#  'Q7325368',
#  'Q12078',
#  'Q2652795',
#  'Q43343',
#  'Q5220818',
#  'Q887566',
#  'Q4359984',
#  'Q5021646',
#  'Q1142927',
#  'Q7732986',
#  'Q484641',
#  'Q4930404',
#  'Q3180167',
#  'Q3622755',
#  'Q3183476',
#  'Q5397016',
#  'Q237235',
#  'Q276130',
#  'Q6173664',
#  'Q52954',
#  'Q3181327',
#  'Q1175457',
#  'Q16216079',
#  'Q11245104',
#  'Q7735129',
#  'Q1451159',
#  'Q5881581',
#  'Q7496995',
#  'Q7424438',
#  'Q3076668',
#  'Q5046809',
#  'Q1176842',
#  'Q240509',
#  'Q5339409',
#  'Q204328',
#  'Q183092',
#  'Q253926',
#  'Q3805702',
#  'Q1168292',
#  'Q853630',
#  'Q6223414',
#  'Q3528518',
#  'Q699062',
#  'Q7953856',
#  'Q121899',
#  'Q7334788',
#  'Q6344346',
#  'Q8053800',
#  'Q375998',
#  'Q296491',
#  'Q8060495',
#  'Q653447',
#  'Q524711',
#  'Q4731007',
#  'Q14317024',
#  'Q7774833',
#  'Q2127397',
#  'Q649615',
#  'Q103917',
#  'Q5189371',
#  'Q11399',
#  'Q609032',
#  'Q3380793',
#  'Q1638488',
#  'Q16734273',
#  'Q133578',
#  'Q336286',
#  'Q804434',
#  'Q2301945',
#  'Q525970',
#  'Q588087',
#  'Q1080701',
#  'Q673641',
#  'Q1107800',
#  'Q442472',
#  'Q6256281',
#  'Q183027',
#  'Q318604',
#  'Q8001650',
#  'Q273199',
#  'Q887716',
#  'Q8341',
#  'Q6837710',
#  'Q6729563',
#  'Q11399',
#  'Q4573',
#  'Q5132635',
#  'Q4916110',
#  'Q468697',
#  'Q1751782',
#  'Q13723965',
#  'Q729315',
#  'Q517',
#  'Q588971',
#  'Q49085',
#  'Q2735971',
#  'Q1347609',
#  'Q8285',
#  'Q6581097',
#  'Q35738',
#  'Q193592',
#  'Q3922166',
#  'Q1050298',
#  'Q5304384',
#  'Q1335201',
#  'Q711370',
#  'Q525',
#  'Q6174834',
#  'Q1348974',
#  'Q5436357',
#  'Q6373984',
#  'Q6943981',
#  'Q543833',
#  'Q54836',
#  'Q162331',
#  'Q698951',
#  'Q1093283',
#  'Q535',
#  'Q3576621',
#  'Q3111799',
#  'Q457060',
#  'Q6780609',
#  'Q17142146',
#  'Q6228508',
#  'Q213812',
#  'Q1016263',
#  'Q1291456',
#  'Q117329',
#  'Q189489',
#  'Q7408091',
#  'Q1620251',
#  'Q6373984',
#  'Q7892643',
#  'Q1129534',
#  'Q9687',
#  'Q6980338',
#  'Q291679',
#  'Q16973923',
#  'Q4932283',
#  'Q12326666',
#  'Q1209671',
#  'Q3824829',
#  'Q4822171',
#  'Q191813',
#  'Q1165071',
#  'Q158438',
#  'Q2386070',
#  'Q12152',
#  'Q491962',
#  'Q6326762',
#  'Q711177',
#  'Q3290990',
#  'Q886597',
#  'Q1794108',
#  'Q551307',
#  'Q87457',
#  'Q628613',
#  'Q6162079',
#  'Q2309994',
#  'Q498390',
#  'Q1094135',
#  'Q651454',
#  'Q17',
#  'Q61887',
#  'Q42448',
#  'Q154821',
#  'Q161400',
#  'Q846544',
#  'Q79867',
#  'Q361661',
#  'Q521188',
#  'Q7617522',
#  'Q6403123',
#  'Q280658',
#  'Q4541116',
#  'Q841963',
#  'Q3210392',
#  'Q1124210',
#  'Q1754902',
#  'Q6023439',
#  'Q2066933',
#  'Q2575299',
#  'Q10297944',
#  'Q2560935',
#  'Q36834',
#  'Q2143665',
#  'Q3987425',
#  'Q45981',
#  'Q6775534',
#  'Q7317178',
#  'Q311760',
#  'Q641242',
#  'Q240212',
#  'Q598160',
#  'Q91645',
#  'Q97817',
#  'Q432102',
#  'Q5271247',
#  'Q6911307',
#  'Q1423551',
#  'Q2341615',
#  'Q3283773',
#  'Q6732642',
#  'Q7955395',
#  'Q450640',
#  'Q1625954',
#  'Q183532',
#  'Q280658',
#  'Q1297',
#  'Q6115520',
#  'Q1492',
#  'Q152110',
#  'Q748754',
#  'Q4932127',
#  'Q5290983',
#  ...]

# %%
len(target_relation)
# Out:
# 34374

# %%
get_relation_label('P272')
# Out:
# ('P272', 'production company')

# %%
start = time.time()
relation_id_name = parallal_task(get_relation_label, target_relation)
print(time.time() - start)
len(relation_id_name)
# Out:
# 714.1416900157928
# 34374

# %%
relation_id_name
# Out:
# [('P272', 'production company'),
#  ('P19', 'place of birth'),
#  ('P162', 'producer'),
#  ('P364', 'original language of film or TV show'),
#  ('P276', 'location'),
#  ('P413', 'position played on team / speciality'),
#  ('P607', 'conflict'),
#  ('P413', 'position played on team / speciality'),
#  ('P136', 'genre'),
#  ('P27', 'country of citizenship'),
#  ('P364', 'original language of film or TV show'),
#  ('P21', 'sex or gender'),
#  ('P136', 'genre'),
#  ('P738', ''),
#  ('P106', 'occupation'),
#  ('P196', 'minor planet group'),
#  ('P175', 'performer'),
#  ('P175', 'performer'),
#  ('P50', 'author'),
#  ('P136', 'genre'),
#  ('P344', 'director of photography'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P641', 'sport'),
#  ('P27', 'country of citizenship'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P19', 'place of birth'),
#  ('P136', 'genre'),
#  ('P421', 'located in time zone'),
#  ('P136', 'genre'),
#  ('P27', 'country of citizenship'),
#  ('P421', 'located in time zone'),
#  ('P21', 'sex or gender'),
#  ('P57', 'director'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P170', 'creator'),
#  ('P50', 'author'),
#  ('P27', 'country of citizenship'),
#  ('P272', 'production company'),
#  ('P17', 'country'),
#  ('P21', 'sex or gender'),
#  ('P364', 'original language of film or TV show'),
#  ('P19', 'place of birth'),
#  ('P136', 'genre'),
#  ('P287', 'designed by'),
#  ('P175', 'performer'),
#  ('P86', 'composer'),
#  ('P21', 'sex or gender'),
#  ('P58', 'screenwriter'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P58', 'screenwriter'),
#  ('P86', 'composer'),
#  ('P1142', 'political ideology'),
#  ('P20', 'place of death'),
#  ('P413', 'position played on team / speciality'),
#  ('P136', 'genre'),
#  ('P58', 'screenwriter'),
#  ('P19', 'place of birth'),
#  ('P21', 'sex or gender'),
#  ('P27', 'country of citizenship'),
#  ('P19', 'place of birth'),
#  ('P19', 'place of birth'),
#  ('P21', 'sex or gender'),
#  ('P136', 'genre'),
#  ('P21', 'sex or gender'),
#  ('P136', 'genre'),
#  ('P264', 'record label'),
#  ('P131', 'located in the administrative territorial entity'),
#  ('P27', 'country of citizenship'),
#  ('P106', 'occupation'),
#  ('P136', 'genre'),
#  ('P172', 'ethnic group'),
#  ('P495', 'country of origin'),
#  ('P27', 'country of citizenship'),
#  ('P136', 'genre'),
#  ('P150', 'contains the administrative territorial entity'),
#  ('P136', 'genre'),
#  ('P21', 'sex or gender'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P27', 'country of citizenship'),
#  ('P738', ''),
#  ('P170', 'creator'),
#  ('P131', 'located in the administrative territorial entity'),
#  ('P509', 'cause of death'),
#  ('P136', 'genre'),
#  ('P19', 'place of birth'),
#  ('P196', 'minor planet group'),
#  ('P136', 'genre'),
#  ('P21', 'sex or gender'),
#  ('P136', 'genre'),
#  ('P119', 'place of burial'),
#  ('P19', 'place of birth'),
#  ('P136', 'genre'),
#  ('P21', 'sex or gender'),
#  ('P413', 'position played on team / speciality'),
#  ('P1303', 'instrument'),
#  ('P136', 'genre'),
#  ('P50', 'author'),
#  ('P40', 'child'),
#  ('P27', 'country of citizenship'),
#  ('P136', 'genre'),
#  ('P1303', 'instrument'),
#  ('P413', 'position played on team / speciality'),
#  ('P364', 'original language of film or TV show'),
#  ('P61', 'discoverer or inventor'),
#  ('P136', 'genre'),
#  ('P27', 'country of citizenship'),
#  ('P172', 'ethnic group'),
#  ('P136', 'genre'),
#  ('P21', 'sex or gender'),
#  ('P264', 'record label'),
#  ('P57', 'director'),
#  ('P19', 'place of birth'),
#  ('P57', 'director'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P140', 'religion or worldview'),
#  ('P136', 'genre'),
#  ('P27', 'country of citizenship'),
#  ('P20', 'place of death'),
#  ('P19', 'place of birth'),
#  ('P509', 'cause of death'),
#  ('P136', 'genre'),
#  ('P179', 'part of the series'),
#  ('P136', 'genre'),
#  ('P495', 'country of origin'),
#  ('P136', 'genre'),
#  ('P19', 'place of birth'),
#  ('P344', 'director of photography'),
#  ('P413', 'position played on team / speciality'),
#  ('P136', 'genre'),
#  ('P58', 'screenwriter'),
#  ('P364', 'original language of film or TV show'),
#  ('P106', 'occupation'),
#  ('P140', 'religion or worldview'),
#  ('P364', 'original language of film or TV show'),
#  ('P40', 'child'),
#  ('P136', 'genre'),
#  ('P57', 'director'),
#  ('P136', 'genre'),
#  ('P19', 'place of birth'),
#  ('P27', 'country of citizenship'),
#  ('P136', 'genre'),
#  ('P1040', 'film editor'),
#  ('P509', 'cause of death'),
#  ('P27', 'country of citizenship'),
#  ('P364', 'original language of film or TV show'),
#  ('P27', 'country of citizenship'),
#  ('P641', 'sport'),
#  ('P21', 'sex or gender'),
#  ('P19', 'place of birth'),
#  ('P509', 'cause of death'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P131', 'located in the administrative territorial entity'),
#  ('P413', 'position played on team / speciality'),
#  ('P19', 'place of birth'),
#  ('P50', 'author'),
#  ('P509', 'cause of death'),
#  ('P20', 'place of death'),
#  ('P509', 'cause of death'),
#  ('P106', 'occupation'),
#  ('P106', 'occupation'),
#  ('P138', 'named after'),
#  ('P495', 'country of origin'),
#  ('P19', 'place of birth'),
#  ('P175', 'performer'),
#  ('P19', 'place of birth'),
#  ('P21', 'sex or gender'),
#  ('P136', 'genre'),
#  ('P19', 'place of birth'),
#  ('P421', 'located in time zone'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P413', 'position played on team / speciality'),
#  ('P397', 'parent astronomical body'),
#  ('P136', 'genre'),
#  ('P21', 'sex or gender'),
#  ('P27', 'country of citizenship'),
#  ('P175', 'performer'),
#  ('P413', 'position played on team / speciality'),
#  ('P344', 'director of photography'),
#  ('P364', 'original language of film or TV show'),
#  ('P27', 'country of citizenship'),
#  ('P413', 'position played on team / speciality'),
#  ('P21', 'sex or gender'),
#  ('P136', 'genre'),
#  ('P106', 'occupation'),
#  ('P136', 'genre'),
#  ('P50', 'author'),
#  ('P19', 'place of birth'),
#  ('P1142', 'political ideology'),
#  ('P136', 'genre'),
#  ('P27', 'country of citizenship'),
#  ('P136', 'genre'),
#  ('P27', 'country of citizenship'),
#  ('P27', 'country of citizenship'),
#  ('P19', 'place of birth'),
#  ('P407', 'language of work or name'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P398', 'child astronomical body'),
#  ('P136', 'genre'),
#  ('P106', 'occupation'),
#  ('P19', 'place of birth'),
#  ('P413', 'position played on team / speciality'),
#  ('P136', 'genre'),
#  ('P106', 'occupation'),
#  ('P272', 'production company'),
#  ('P140', 'religion or worldview'),
#  ('P364', 'original language of film or TV show'),
#  ('P264', 'record label'),
#  ('P509', 'cause of death'),
#  ('P19', 'place of birth'),
#  ('P19', 'place of birth'),
#  ('P106', 'occupation'),
#  ('P19', 'place of birth'),
#  ('P413', 'position played on team / speciality'),
#  ('P20', 'place of death'),
#  ('P397', 'parent astronomical body'),
#  ('P413', 'position played on team / speciality'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P403', 'mouth of the watercourse'),
#  ('P31', 'instance of'),
#  ('P20', 'place of death'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P607', 'conflict'),
#  ('P131', 'located in the administrative territorial entity'),
#  ('P607', 'conflict'),
#  ('P20', 'place of death'),
#  ('P136', 'genre'),
#  ('P495', 'country of origin'),
#  ('P509', 'cause of death'),
#  ('P57', 'director'),
#  ('P106', 'occupation'),
#  ('P364', 'original language of film or TV show'),
#  ('P407', 'language of work or name'),
#  ('P509', 'cause of death'),
#  ('P19', 'place of birth'),
#  ('P136', 'genre'),
#  ('P509', 'cause of death'),
#  ('P31', 'instance of'),
#  ('P136', 'genre'),
#  ('P287', 'designed by'),
#  ('P136', 'genre'),
#  ('P140', 'religion or worldview'),
#  ('P162', 'producer'),
#  ('P162', 'producer'),
#  ('P19', 'place of birth'),
#  ('P21', 'sex or gender'),
#  ('P136', 'genre'),
#  ('P19', 'place of birth'),
#  ('P495', 'country of origin'),
#  ('P344', 'director of photography'),
#  ('P21', 'sex or gender'),
#  ('P641', 'sport'),
#  ('P58', 'screenwriter'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P421', 'located in time zone'),
#  ('P509', 'cause of death'),
#  ('P413', 'position played on team / speciality'),
#  ('P136', 'genre'),
#  ('P19', 'place of birth'),
#  ('P57', 'director'),
#  ('P20', 'place of death'),
#  ('P136', 'genre'),
#  ('P404', 'game mode'),
#  ('P19', 'place of birth'),
#  ('P407', 'language of work or name'),
#  ('P1408', 'licensed to broadcast to'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P421', 'located in time zone'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P421', 'located in time zone'),
#  ('P136', 'genre'),
#  ('P264', 'record label'),
#  ('P738', ''),
#  ('P264', 'record label'),
#  ('P58', 'screenwriter'),
#  ('P136', 'genre'),
#  ('P27', 'country of citizenship'),
#  ('P413', 'position played on team / speciality'),
#  ('P136', 'genre'),
#  ('P172', 'ethnic group'),
#  ('P50', 'author'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P178', 'developer'),
#  ('P136', 'genre'),
#  ('P19', 'place of birth'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P27', 'country of citizenship'),
#  ('P136', 'genre'),
#  ('P86', 'composer'),
#  ('P364', 'original language of film or TV show'),
#  ('P272', 'production company'),
#  ('P413', 'position played on team / speciality'),
#  ('P136', 'genre'),
#  ('P57', 'director'),
#  ('P140', 'religion or worldview'),
#  ('P19', 'place of birth'),
#  ('P20', 'place of death'),
#  ('P607', 'conflict'),
#  ('P136', 'genre'),
#  ('P364', 'original language of film or TV show'),
#  ('P21', 'sex or gender'),
#  ('P136', 'genre'),
#  ('P27', 'country of citizenship'),
#  ('P86', 'composer'),
#  ('P20', 'place of death'),
#  ('P57', 'director'),
#  ('P19', 'place of birth'),
#  ('P27', 'country of citizenship'),
#  ('P421', 'located in time zone'),
#  ('P413', 'position played on team / speciality'),
#  ('P106', 'occupation'),
#  ('P495', 'country of origin'),
#  ('P136', 'genre'),
#  ('P413', 'position played on team / speciality'),
#  ('P20', 'place of death'),
#  ('P136', 'genre'),
#  ('P21', 'sex or gender'),
#  ('P397', 'parent astronomical body'),
#  ('P27', 'country of citizenship'),
#  ('P136', 'genre'),
#  ('P364', 'original language of film or TV show'),
#  ('P404', 'game mode'),
#  ('P136', 'genre'),
#  ('P170', 'creator'),
#  ('P19', 'place of birth'),
#  ('P279', 'subclass of'),
#  ('P272', 'production company'),
#  ('P123', 'publisher'),
#  ('P264', 'record label'),
#  ('P136', 'genre'),
#  ('P27', 'country of citizenship'),
#  ('P136', 'genre'),
#  ('P59', 'constellation'),
#  ('P19', 'place of birth'),
#  ('P495', 'country of origin'),
#  ('P495', 'country of origin'),
#  ('P136', 'genre'),
#  ('P264', 'record label'),
#  ('P20', 'place of death'),
#  ('P40', 'child'),
#  ('P138', 'named after'),
#  ('P136', 'genre'),
#  ('P276', 'location'),
#  ('P21', 'sex or gender'),
#  ('P1431', 'executive producer'),
#  ('P57', 'director'),
#  ('P264', 'record label'),
#  ('P19', 'place of birth'),
#  ('P364', 'original language of film or TV show'),
#  ('P140', 'religion or worldview'),
#  ('P1303', 'instrument'),
#  ('P20', 'place of death'),
#  ('P397', 'parent astronomical body'),
#  ('P421', 'located in time zone'),
#  ('P170', 'creator'),
#  ('P19', 'place of birth'),
#  ('P86', 'composer'),
#  ('P413', 'position played on team / speciality'),
#  ('P106', 'occupation'),
#  ('P86', 'composer'),
#  ('P178', 'developer'),
#  ('P19', 'place of birth'),
#  ('P272', 'production company'),
#  ('P364', 'original language of film or TV show'),
#  ('P495', 'country of origin'),
#  ('P136', 'genre'),
#  ('P21', 'sex or gender'),
#  ('P136', 'genre'),
#  ('P172', 'ethnic group'),
#  ('P106', 'occupation'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P413', 'position played on team / speciality'),
#  ('P27', 'country of citizenship'),
#  ('P136', 'genre'),
#  ('P509', 'cause of death'),
#  ('P413', 'position played on team / speciality'),
#  ('P413', 'position played on team / speciality'),
#  ('P136', 'genre'),
#  ('P364', 'original language of film or TV show'),
#  ('P421', 'located in time zone'),
#  ('P364', 'original language of film or TV show'),
#  ('P21', 'sex or gender'),
#  ('P179', 'part of the series'),
#  ('P136', 'genre'),
#  ('P20', 'place of death'),
#  ('P737', 'influenced by'),
#  ('P179', 'part of the series'),
#  ('P136', 'genre'),
#  ('P495', 'country of origin'),
#  ('P40', 'child'),
#  ('P264', 'record label'),
#  ('P364', 'original language of film or TV show'),
#  ('P364', 'original language of film or TV show'),
#  ('P58', 'screenwriter'),
#  ('P27', 'country of citizenship'),
#  ('P136', 'genre'),
#  ('P19', 'place of birth'),
#  ('P398', 'child astronomical body'),
#  ('P495', 'country of origin'),
#  ('P136', 'genre'),
#  ('P20', 'place of death'),
#  ('P19', 'place of birth'),
#  ('P27', 'country of citizenship'),
#  ('P27', 'country of citizenship'),
#  ('P21', 'sex or gender'),
#  ('P21', 'sex or gender'),
#  ('P421', 'located in time zone'),
#  ('P136', 'genre'),
#  ('P272', 'production company'),
#  ('P40', 'child'),
#  ('P136', 'genre'),
#  ('P495', 'country of origin'),
#  ('P140', 'religion or worldview'),
#  ('P131', 'located in the administrative territorial entity'),
#  ('P264', 'record label'),
#  ('P140', 'religion or worldview'),
#  ('P21', 'sex or gender'),
#  ('P136', 'genre'),
#  ('P17', 'country'),
#  ('P140', 'religion or worldview'),
#  ('P196', 'minor planet group'),
#  ('P136', 'genre'),
#  ('P106', 'occupation'),
#  ('P27', 'country of citizenship'),
#  ('P364', 'original language of film or TV show'),
#  ('P19', 'place of birth'),
#  ('P179', 'part of the series'),
#  ('P172', 'ethnic group'),
#  ('P58', 'screenwriter'),
#  ('P106', 'occupation'),
#  ('P136', 'genre'),
#  ('P421', 'located in time zone'),
#  ('P413', 'position played on team / speciality'),
#  ('P19', 'place of birth'),
#  ('P171', 'parent taxon'),
#  ('P19', 'place of birth'),
#  ('P123', 'publisher'),
#  ('P19', 'place of birth'),
#  ('P170', 'creator'),
#  ('P495', 'country of origin'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P413', 'position played on team / speciality'),
#  ('P27', 'country of citizenship'),
#  ('P398', 'child astronomical body'),
#  ('P57', 'director'),
#  ('P20', 'place of death'),
#  ('P136', 'genre'),
#  ('P264', 'record label'),
#  ('P136', 'genre'),
#  ('P19', 'place of birth'),
#  ('P175', 'performer'),
#  ('P413', 'position played on team / speciality'),
#  ('P20', 'place of death'),
#  ('P413', 'position played on team / speciality'),
#  ('P19', 'place of birth'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P106', 'occupation'),
#  ('P136', 'genre'),
#  ('P170', 'creator'),
#  ('P264', 'record label'),
#  ('P136', 'genre'),
#  ('P738', ''),
#  ('P19', 'place of birth'),
#  ('P264', 'record label'),
#  ('P1303', 'instrument'),
#  ('P136', 'genre'),
#  ('P495', 'country of origin'),
#  ('P144', 'based on'),
#  ('P131', 'located in the administrative territorial entity'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P175', 'performer'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P175', 'performer'),
#  ('P19', 'place of birth'),
#  ('P737', 'influenced by'),
#  ('P21', 'sex or gender'),
#  ('P86', 'composer'),
#  ('P19', 'place of birth'),
#  ('P112', 'founded by'),
#  ('P175', 'performer'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P19', 'place of birth'),
#  ('P136', 'genre'),
#  ('P21', 'sex or gender'),
#  ('P136', 'genre'),
#  ('P413', 'position played on team / speciality'),
#  ('P737', 'influenced by'),
#  ('P364', 'original language of film or TV show'),
#  ('P138', 'named after'),
#  ('P175', 'performer'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P1431', 'executive producer'),
#  ('P170', 'creator'),
#  ('P20', 'place of death'),
#  ('P175', 'performer'),
#  ('P344', 'director of photography'),
#  ('P413', 'position played on team / speciality'),
#  ('P19', 'place of birth'),
#  ('P413', 'position played on team / speciality'),
#  ('P136', 'genre'),
#  ('P21', 'sex or gender'),
#  ('P407', 'language of work or name'),
#  ('P495', 'country of origin'),
#  ('P136', 'genre'),
#  ('P27', 'country of citizenship'),
#  ('P31', 'instance of'),
#  ('P105', 'taxon rank'),
#  ('P162', 'producer'),
#  ('P495', 'country of origin'),
#  ('P676', 'lyrics by'),
#  ('P178', 'developer'),
#  ('P737', 'influenced by'),
#  ('P27', 'country of citizenship'),
#  ('P495', 'country of origin'),
#  ('P175', 'performer'),
#  ('P19', 'place of birth'),
#  ('P136', 'genre'),
#  ('P106', 'occupation'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P57', 'director'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P175', 'performer'),
#  ('P21', 'sex or gender'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P1142', 'political ideology'),
#  ('P59', 'constellation'),
#  ('P113', 'airline hub'),
#  ('P495', 'country of origin'),
#  ('P397', 'parent astronomical body'),
#  ('P175', 'performer'),
#  ('P364', 'original language of film or TV show'),
#  ('P140', 'religion or worldview'),
#  ('P136', 'genre'),
#  ('P57', 'director'),
#  ('P607', 'conflict'),
#  ('P495', 'country of origin'),
#  ('P136', 'genre'),
#  ('P172', 'ethnic group'),
#  ('P136', 'genre'),
#  ('P403', 'mouth of the watercourse'),
#  ('P140', 'religion or worldview'),
#  ('P131', 'located in the administrative territorial entity'),
#  ('P136', 'genre'),
#  ('P364', 'original language of film or TV show'),
#  ('P20', 'place of death'),
#  ('P413', 'position played on team / speciality'),
#  ('P21', 'sex or gender'),
#  ('P136', 'genre'),
#  ('P123', 'publisher'),
#  ('P19', 'place of birth'),
#  ('P495', 'country of origin'),
#  ('P27', 'country of citizenship'),
#  ('P264', 'record label'),
#  ('P31', 'instance of'),
#  ('P162', 'producer'),
#  ('P19', 'place of birth'),
#  ('P364', 'original language of film or TV show'),
#  ('P136', 'genre'),
#  ('P155', 'follows'),
#  ('P20', 'place of death'),
#  ('P19', 'place of birth'),
#  ('P289', 'vessel class'),
#  ('P364', 'original language of film or TV show'),
#  ('P131', 'located in the administrative territorial entity'),
#  ('P57', 'director'),
#  ('P136', 'genre'),
#  ('P178', 'developer'),
#  ('P27', 'country of citizenship'),
#  ('P21', 'sex or gender'),
#  ('P162', 'producer'),
#  ('P495', 'country of origin'),
#  ('P413', 'position played on team / speciality'),
#  ('P136', 'genre'),
#  ('P272', 'production company'),
#  ('P27', 'country of citizenship'),
#  ('P149', 'architectural style'),
#  ('P136', 'genre'),
#  ('P162', 'producer'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P27', 'country of citizenship'),
#  ('P27', 'country of citizenship'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P19', 'place of birth'),
#  ('P1408', 'licensed to broadcast to'),
#  ('P27', 'country of citizenship'),
#  ('P19', 'place of birth'),
#  ('P413', 'position played on team / speciality'),
#  ('P27', 'country of citizenship'),
#  ('P136', 'genre'),
#  ('P86', 'composer'),
#  ('P19', 'place of birth'),
#  ('P413', 'position played on team / speciality'),
#  ('P21', 'sex or gender'),
#  ('P136', 'genre'),
#  ('P421', 'located in time zone'),
#  ('P404', 'game mode'),
#  ('P136', 'genre'),
#  ('P21', 'sex or gender'),
#  ('P27', 'country of citizenship'),
#  ('P21', 'sex or gender'),
#  ('P27', 'country of citizenship'),
#  ('P131', 'located in the administrative territorial entity'),
#  ('P398', 'child astronomical body'),
#  ('P40', 'child'),
#  ('P19', 'place of birth'),
#  ('P172', 'ethnic group'),
#  ('P136', 'genre'),
#  ('P1303', 'instrument'),
#  ('P21', 'sex or gender'),
#  ('P162', 'producer'),
#  ('P140', 'religion or worldview'),
#  ('P136', 'genre'),
#  ('P27', 'country of citizenship'),
#  ('P1040', 'film editor'),
#  ('P710', 'participant'),
#  ('P495', 'country of origin'),
#  ('P27', 'country of citizenship'),
#  ('P136', 'genre'),
#  ('P172', 'ethnic group'),
#  ('P136', 'genre'),
#  ('P710', 'participant'),
#  ('P172', 'ethnic group'),
#  ('P136', 'genre'),
#  ('P413', 'position played on team / speciality'),
#  ('P40', 'child'),
#  ('P136', 'genre'),
#  ('P19', 'place of birth'),
#  ('P404', 'game mode'),
#  ('P196', 'minor planet group'),
#  ('P136', 'genre'),
#  ('P607', 'conflict'),
#  ('P40', 'child'),
#  ('P509', 'cause of death'),
#  ('P19', 'place of birth'),
#  ('P138', 'named after'),
#  ('P136', 'genre'),
#  ('P50', 'author'),
#  ('P136', 'genre'),
#  ('P19', 'place of birth'),
#  ('P264', 'record label'),
#  ('P607', 'conflict'),
#  ('P27', 'country of citizenship'),
#  ('P1303', 'instrument'),
#  ('P1303', 'instrument'),
#  ('P413', 'position played on team / speciality'),
#  ('P27', 'country of citizenship'),
#  ('P106', 'occupation'),
#  ('P57', 'director'),
#  ('P19', 'place of birth'),
#  ('P136', 'genre'),
#  ('P421', 'located in time zone'),
#  ('P136', 'genre'),
#  ('P21', 'sex or gender'),
#  ('P136', 'genre'),
#  ('P27', 'country of citizenship'),
#  ('P509', 'cause of death'),
#  ('P19', 'place of birth'),
#  ('P20', 'place of death'),
#  ('P106', 'occupation'),
#  ('P495', 'country of origin'),
#  ('P495', 'country of origin'),
#  ('P364', 'original language of film or TV show'),
#  ('P413', 'position played on team / speciality'),
#  ('P27', 'country of citizenship'),
#  ('P27', 'country of citizenship'),
#  ('P162', 'producer'),
#  ('P364', 'original language of film or TV show'),
#  ('P364', 'original language of film or TV show'),
#  ('P136', 'genre'),
#  ('P106', 'occupation'),
#  ('P162', 'producer'),
#  ('P413', 'position played on team / speciality'),
#  ('P1040', 'film editor'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P397', 'parent astronomical body'),
#  ('P27', 'country of citizenship'),
#  ('P136', 'genre'),
#  ('P27', 'country of citizenship'),
#  ('P19', 'place of birth'),
#  ('P19', 'place of birth'),
#  ('P131', 'located in the administrative territorial entity'),
#  ('P140', 'religion or worldview'),
#  ('P20', 'place of death'),
#  ('P272', 'production company'),
#  ('P136', 'genre'),
#  ('P495', 'country of origin'),
#  ('P136', 'genre'),
#  ('P421', 'located in time zone'),
#  ('P19', 'place of birth'),
#  ('P136', 'genre'),
#  ('P19', 'place of birth'),
#  ('P50', 'author'),
#  ('P136', 'genre'),
#  ('P172', 'ethnic group'),
#  ('P20', 'place of death'),
#  ('P178', 'developer'),
#  ('P676', 'lyrics by'),
#  ('P19', 'place of birth'),
#  ('P19', 'place of birth'),
#  ('P27', 'country of citizenship'),
#  ('P31', 'instance of'),
#  ('P136', 'genre'),
#  ('P131', 'located in the administrative territorial entity'),
#  ('P509', 'cause of death'),
#  ('P149', 'architectural style'),
#  ('P20', 'place of death'),
#  ('P136', 'genre'),
#  ('P1303', 'instrument'),
#  ('P136', 'genre'),
#  ('P264', 'record label'),
#  ('P106', 'occupation'),
#  ('P21', 'sex or gender'),
#  ('P58', 'screenwriter'),
#  ('P136', 'genre'),
#  ('P21', 'sex or gender'),
#  ('P21', 'sex or gender'),
#  ('P58', 'screenwriter'),
#  ('P136', 'genre'),
#  ('P364', 'original language of film or TV show'),
#  ('P106', 'occupation'),
#  ('P21', 'sex or gender'),
#  ('P1040', 'film editor'),
#  ('P136', 'genre'),
#  ('P31', 'instance of'),
#  ('P136', 'genre'),
#  ('P413', 'position played on team / speciality'),
#  ('P136', 'genre'),
#  ('P1040', 'film editor'),
#  ('P136', 'genre'),
#  ('P413', 'position played on team / speciality'),
#  ('P86', 'composer'),
#  ('P136', 'genre'),
#  ('P177', 'crosses'),
#  ('P136', 'genre'),
#  ('P19', 'place of birth'),
#  ('P136', 'genre'),
#  ('P106', 'occupation'),
#  ('P710', 'participant'),
#  ('P136', 'genre'),
#  ('P264', 'record label'),
#  ('P19', 'place of birth'),
#  ('P106', 'occupation'),
#  ('P136', 'genre'),
#  ('P21', 'sex or gender'),
#  ('P21', 'sex or gender'),
#  ('P136', 'genre'),
#  ('P19', 'place of birth'),
#  ('P509', 'cause of death'),
#  ('P27', 'country of citizenship'),
#  ('P136', 'genre'),
#  ('P413', 'position played on team / speciality'),
#  ('P276', 'location'),
#  ('P19', 'place of birth'),
#  ('P495', 'country of origin'),
#  ('P172', 'ethnic group'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P404', 'game mode'),
#  ('P58', 'screenwriter'),
#  ('P136', 'genre'),
#  ('P413', 'position played on team / speciality'),
#  ('P364', 'original language of film or TV show'),
#  ('P50', 'author'),
#  ('P57', 'director'),
#  ('P27', 'country of citizenship'),
#  ('P1303', 'instrument'),
#  ('P20', 'place of death'),
#  ('P27', 'country of citizenship'),
#  ('P413', 'position played on team / speciality'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P175', 'performer'),
#  ('P19', 'place of birth'),
#  ('P21', 'sex or gender'),
#  ('P20', 'place of death'),
#  ('P495', 'country of origin'),
#  ('P136', 'genre'),
#  ('P178', 'developer'),
#  ('P1303', 'instrument'),
#  ('P19', 'place of birth'),
#  ('P136', 'genre'),
#  ('P175', 'performer'),
#  ('P50', 'author'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P19', 'place of birth'),
#  ('P106', 'occupation'),
#  ('P413', 'position played on team / speciality'),
#  ('P1408', 'licensed to broadcast to'),
#  ('P50', 'author'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P58', 'screenwriter'),
#  ('P20', 'place of death'),
#  ('P509', 'cause of death'),
#  ('P27', 'country of citizenship'),
#  ('P495', 'country of origin'),
#  ('P58', 'screenwriter'),
#  ('P19', 'place of birth'),
#  ('P495', 'country of origin'),
#  ('P136', 'genre'),
#  ('P58', 'screenwriter'),
#  ('P20', 'place of death'),
#  ('P57', 'director'),
#  ('P119', 'place of burial'),
#  ('P136', 'genre'),
#  ('P1303', 'instrument'),
#  ('P136', 'genre'),
#  ('P607', 'conflict'),
#  ('P27', 'country of citizenship'),
#  ('P20', 'place of death'),
#  ('P413', 'position played on team / speciality'),
#  ('P495', 'country of origin'),
#  ('P136', 'genre'),
#  ('P738', ''),
#  ('P19', 'place of birth'),
#  ('P58', 'screenwriter'),
#  ('P710', 'participant'),
#  ('P364', 'original language of film or TV show'),
#  ('P19', 'place of birth'),
#  ('P737', 'influenced by'),
#  ('P138', 'named after'),
#  ('P737', 'influenced by'),
#  ('P19', 'place of birth'),
#  ('P413', 'position played on team / speciality'),
#  ('P19', 'place of birth'),
#  ('P136', 'genre'),
#  ('P641', 'sport'),
#  ('P21', 'sex or gender'),
#  ('P136', 'genre'),
#  ('P40', 'child'),
#  ('P413', 'position played on team / speciality'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P175', 'performer'),
#  ('P19', 'place of birth'),
#  ('P40', 'child'),
#  ('P136', 'genre'),
#  ('P172', 'ethnic group'),
#  ('P279', 'subclass of'),
#  ('P58', 'screenwriter'),
#  ('P509', 'cause of death'),
#  ('P21', 'sex or gender'),
#  ('P58', 'screenwriter'),
#  ('P413', 'position played on team / speciality'),
#  ('P57', 'director'),
#  ('P136', 'genre'),
#  ('P162', 'producer'),
#  ('P119', 'place of burial'),
#  ('P1040', 'film editor'),
#  ('P398', 'child astronomical body'),
#  ('P19', 'place of birth'),
#  ('P136', 'genre'),
#  ('P21', 'sex or gender'),
#  ('P136', 'genre'),
#  ('P21', 'sex or gender'),
#  ('P1303', 'instrument'),
#  ('P264', 'record label'),
#  ('P136', 'genre'),
#  ('P57', 'director'),
#  ('P58', 'screenwriter'),
#  ('P737', 'influenced by'),
#  ('P58', 'screenwriter'),
#  ('P136', 'genre'),
#  ('P264', 'record label'),
#  ('P19', 'place of birth'),
#  ('P136', 'genre'),
#  ('P40', 'child'),
#  ('P509', 'cause of death'),
#  ('P19', 'place of birth'),
#  ('P364', 'original language of film or TV show'),
#  ('P509', 'cause of death'),
#  ('P264', 'record label'),
#  ('P112', 'founded by'),
#  ('P123', 'publisher'),
#  ('P136', 'genre'),
#  ('P276', 'location'),
#  ('P58', 'screenwriter'),
#  ('P509', 'cause of death'),
#  ('P264', 'record label'),
#  ('P264', 'record label'),
#  ('P495', 'country of origin'),
#  ('P19', 'place of birth'),
#  ('P19', 'place of birth'),
#  ('P27', 'country of citizenship'),
#  ('P364', 'original language of film or TV show'),
#  ('P136', 'genre'),
#  ('P131', 'located in the administrative territorial entity'),
#  ('P136', 'genre'),
#  ('P31', 'instance of'),
#  ('P264', 'record label'),
#  ('P509', 'cause of death'),
#  ('P364', 'original language of film or TV show'),
#  ('P364', 'original language of film or TV show'),
#  ('P413', 'position played on team / speciality'),
#  ('P19', 'place of birth'),
#  ('P86', 'composer'),
#  ('P178', 'developer'),
#  ('P27', 'country of citizenship'),
#  ('P19', 'place of birth'),
#  ('P19', 'place of birth'),
#  ('P413', 'position played on team / speciality'),
#  ('P495', 'country of origin'),
#  ('P1303', 'instrument'),
#  ('P364', 'original language of film or TV show'),
#  ('P272', 'production company'),
#  ('P17', 'country'),
#  ('P509', 'cause of death'),
#  ('P19', 'place of birth'),
#  ('P196', 'minor planet group'),
#  ('P495', 'country of origin'),
#  ('P136', 'genre'),
#  ('P276', 'location'),
#  ('P175', 'performer'),
#  ('P136', 'genre'),
#  ('P264', 'record label'),
#  ('P140', 'religion or worldview'),
#  ('P413', 'position played on team / speciality'),
#  ('P196', 'minor planet group'),
#  ('P136', 'genre'),
#  ('P495', 'country of origin'),
#  ('P172', 'ethnic group'),
#  ('P175', 'performer'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P27', 'country of citizenship'),
#  ('P136', 'genre'),
#  ('P86', 'composer'),
#  ('P106', 'occupation'),
#  ('P136', 'genre'),
#  ('P364', 'original language of film or TV show'),
#  ('P136', 'genre'),
#  ('P27', 'country of citizenship'),
#  ('P155', 'follows'),
#  ('P737', 'influenced by'),
#  ('P106', 'occupation'),
#  ('P58', 'screenwriter'),
#  ('P404', 'game mode'),
#  ('P27', 'country of citizenship'),
#  ('P20', 'place of death'),
#  ('P136', 'genre'),
#  ('P19', 'place of birth'),
#  ('P136', 'genre'),
#  ('P57', 'director'),
#  ('P495', 'country of origin'),
#  ('P136', 'genre'),
#  ('P136', 'genre'),
#  ('P1408', 'licensed to broadcast to'),
#  ('P27', 'country of citizenship'),
#  ('P20', 'place of death'),
#  ('P140', 'religion or worldview'),
#  ('P413', 'position played on team / speciality'),
#  ('P19', 'place of birth'),
#  ('P19', 'place of birth'),
#  ('P19', 'place of birth'),
#  ('P31', 'instance of'),
#  ('P179', 'part of the series'),
#  ('P19', 'place of birth'),
#  ('P413', 'position played on team / speciality'),
#  ...]

# %%
df = pd.DataFrame(relation_id_name, columns=['id', 'name'])
df['length'] = df["name"].apply(lambda x:len(x))
df
# Out:
#          id                                  name  length
# 0      P272                    production company      18
# 1       P19                        place of birth      14
# 2      P162                              producer       8
# 3      P364  original language of film or TV show      36
# 4      P276                              location       8
# ...     ...                                   ...     ...
# 34369   P27                country of citizenship      22
# 34370  P737                         influenced by      13
# 34371  P136                                 genre       5
# 34372   P21                         sex or gender      13
# 34373  P413  position played on team / speciality      36
#
# [34374 rows x 3 columns]

# %%
len(df)
# Out:
# 34374

# %%
df['length'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
df['length'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
len(df[df['length'] > 35])*100/len(df)
# Out:
# 9.233723162855647

# %%
len(df[df['length'] > 40])*100/len(df)
# Out:
# 0.8291150288008379

# %%
len('category for people who died here')
# Out:
# 33
