# %%
import json
import pandas as pd
import time

# refer to this paper
# https://arxiv.org/pdf/2108.07337.pdf

# %%
def get_relation_label(rel_id):
    label = ''
    API_ENDPOINT = "https://www.wikidata.org/w/api.php"
    params = {
        'action': 'wbgetentities',
        'format': 'json',
        'languages': 'en',
        'props': 'labels',
        'ids': ''
    }
      
    params['ids'] = str(rel_id)

    try:
        response = requests.get(API_ENDPOINT, params = params).json()['entities']
        label = response[str(rel_id)]['labels']['en']['value']
    except:
        return (rel_id, label)
    return (rel_id, label)

# %%
def get_entity_relation_ids(ent_id):
    relations = []
    API_ENDPOINT = "https://www.wikidata.org/w/api.php"
    params = {
        'action': 'wbgetentities',
        'format': 'json',
        'languages': 'en',
        'props': 'claims',
        'ids': ''
    }
        
    params['ids'] = str(ent_id)
    try:
        response = requests.get(API_ENDPOINT, params = params).json()['entities']
        relations = list(response[str(ent_id)]['claims'].keys())
    except:
        return (ent_id, relations)
    return (ent_id, relations)

# %%
def get_entity_labels_and_aliases(ent_id):
    labels = []
    API_ENDPOINT = "https://www.wikidata.org/w/api.php"
    params = {
        'action': 'wbgetentities',
        'format': 'json',
        'languages': 'en',
        'props': 'labels|aliases',    
        'ids': ''
    }

        
    params['ids'] = str(ent_id)
    try:
        response = requests.get(API_ENDPOINT, params = params).json()['entities']
        labels.append(response[str(ent_id)]['labels']['en']['value'])
        
        for alias in response[str(ent_id)]['aliases']['en']:
            labels.append(alias['value'])
    except:
        return (ent_id, labels)
    return (ent_id, labels)

# %%
from fuzzywuzzy import fuzz

# when creating a function the arguments are (questions and the results wikidata api after lower())
def find_nearest_word_in_question(questions, lower_wikidata_replies):
    entities_list = []
    found_match = False
    counter = 0
    for i in range(len(questions)):
        found_match = False
        for label in lower_wikidata_replies[i][1]:
            if label in questions[i].lower(): 
                found_match = True
                index = questions[i].lower().find(label)
                entities_list.append(questions[i][index : len(label)+index])
                break
        if not found_match:
            split_tokens = questions[i][1].split()
            list_of_comb = []
            list_of_comb.extend(split_tokens)
            scores = []
            for j in range(len(split_tokens)-1):
                list_of_comb.append(split_tokens[j] + ' ' + split_tokens[j+1])
            for j in range(len(split_tokens)-2):
                list_of_comb.append(split_tokens[j] + ' ' + split_tokens[j+1] + ' ' + split_tokens[j+2])
            for j in range(len(split_tokens)-3):
                list_of_comb.append(split_tokens[j] + ' ' + split_tokens[j+1] + ' ' + split_tokens[j+2] + ' ' + split_tokens[j+3])

            for label in lower_wikidata_replies[i][1]:
                for token in list_of_comb: 
                    scores.append((fuzz.ratio(label, token.lower()), token, label))
            scores = sorted(scores, key=lambda x: x[0], reverse=True)

            if len(scores) and scores[0][0] < 85:
                counter += 1
                entities_list.append('')
            elif not(len(scores)):
                counter += 1
                entities_list.append('')
            elif scores[0][0] >= 85:
                entities_list.append(scores[0][1])
    return (entities_list, counter)

# %%
# jupyter notebook never finishes processing using multiprocessing python 3
# https://stackoverflow.com/questions/47313732/jupyter-notebook-never-finishes-processing-using-multiprocessing-python-3

from multiprocessing import Pool
from functools import partial
import inspect
import time
import os
import requests


def parallal_task(func, iterable, *params): 
    with open(f'./tmp_func.py', 'w') as file:
        file.write("import requests \n")
        file.write(inspect.getsource(func).replace(func.__name__, 'task'))

    from tmp_func import task
    pool = Pool(processes=15)
    res = pool.map(task, iterable)
    pool.close()
    
    os.remove('./tmp_func.py')
    return res
#     else:
#         raise "Not in Jupyter Notebook"

# %%
from multiprocessing import Pool
from functools import partial
import inspect
import time
import os
import requests


def parallal_task_2(func, iterable, *params): 
    with open(f'./tmp_func_2.py', 'w') as file:
        file.write("import requests \n")
        file.write(inspect.getsource(func).replace(func.__name__, 'task'))

    from tmp_func_2 import task
    pool = Pool(processes=15)
    res = pool.map(task, iterable)
    pool.close()
    
    os.remove('./tmp_func_2.py')
    return res

# %%
from multiprocessing import Pool
from functools import partial
import inspect
import time
import os
import requests


def parallal_task_3(func, iterable, *params): 
    with open(f'./tmp_func_3.py', 'w') as file:
        file.write("import requests \n")
        file.write(inspect.getsource(func).replace(func.__name__, 'task'))

    from tmp_func_2 import task
    pool = Pool(processes=15)
    res = pool.map(task, iterable)
    pool.close()
    
    os.remove('./tmp_func_3.py')
    return res

# %% [markdown]
# ## Simple_questions Training Data

# %%
with open('2-NEL_Data/0-raw_data/simple_questions_v2/annotated_wd_data_train.txt', encoding='utf-8') as file:
    lines = file.readlines()

# print(len(lines))
training_data = []
for line in lines:
    line = line.strip().split('\t', 3)
    del line[2]
    
    training_data.append(line)
    
qids = [line[0] for line in training_data]
target_relation = [line[1].replace('R', 'P') for line in training_data]
questions = [line[2] for line in training_data]
# print(len(training_data))
# print(training_data[0])
# print(qids[0])
# print(questions[0])

# %%
print(target_relation[0])
len(target_relation)
# Out:
# P272
# 34374

# %%
get_entity_relation_ids('Q126399')[1]
# Out:
# ['P373',
#  'P31',
#  'P112',
#  'P749',
#  'P856',
#  'P966',
#  'P646',
#  'P159',
#  'P910',
#  'P1711',
#  'P18',
#  'P214',
#  'P571',
#  'P2002',
#  'P345',
#  'P2531',
#  'P740',
#  'P154',
#  'P452',
#  'P3221',
#  'P2013',
#  'P1278',
#  'P3417',
#  'P3762',
#  'P1220',
#  'P1056',
#  'P166',
#  'P169',
#  'P1417',
#  'P2581',
#  'P3347',
#  'P17',
#  'P3219',
#  'P2011',
#  'P1424',
#  'P1830',
#  'P6150',
#  'P691',
#  'P244',
#  'P463',
#  'P1296',
#  'P7632',
#  'P2003',
#  'P3836',
#  'P355',
#  'P7859',
#  'P2627',
#  'P138',
#  'P2088',
#  'P1889',
#  'P8317',
#  'P10297',
#  'P8313',
#  'P2388',
#  'P460',
#  'P213',
#  'P7293',
#  'P8179',
#  'P409',
#  'P1375',
#  'P2163',
#  'P8189',
#  'P3630',
#  'P1207',
#  'P1695',
#  'P3553',
#  'P9885',
#  'P1955',
#  'P3943',
#  'P7708',
#  'P9807',
#  'P7502',
#  'P4264',
#  'P6839',
#  'P8895',
#  'P1320',
#  'P8687',
#  'P648',
#  'P3847',
#  'P3222',
#  'P4272',
#  'P4342',
#  'P6683',
#  'P7982',
#  'P6058',
#  'P6760',
#  'P10225',
#  'P10804',
#  'P8168',
#  'P3185']

# %%
# qids[0]


target_relation[0]
# target_relation[0] in get_entity_relation_ids('Q126399')[1]
# Out:
# 'P272'

# %%
start = time.time()
relation_ids_results = parallal_task(get_entity_relation_ids, qids)
print(time.time() - start)
len(relation_ids_results)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-b2ff9a5ec3b7> in <module>
#       1 start = time.time()
# ----> 2 relation_ids_results = parallal_task(get_entity_relation_ids, qids)
#       3 print(time.time() - start)
#       4 len(relation_ids_results)
#
# <ipython-input-6-6544e55ec804> in parallal_task(func, iterable, *params)
#      17     from tmp_func import task
#      18     pool = Pool(processes=15)
# ---> 19     res = pool.map(task, iterable)
#      20     pool.close()
#      21
#
# ~/miniconda3/lib/python3.7/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     266         in a list that is returned.
#     267         '''
# --> 268         return self._map_async(func, iterable, mapstar, chunksize).get()
#     269
#     270     def starmap(self, func, iterable, chunksize=None):
#
# ~/miniconda3/lib/python3.7/multiprocessing/pool.py in get(self, timeout)
#     649
#     650     def get(self, timeout=None):
# --> 651         self.wait(timeout)
#     652         if not self.ready():
#     653             raise TimeoutError
#
# ~/miniconda3/lib/python3.7/multiprocessing/pool.py in wait(self, timeout)
#     646
#     647     def wait(self, timeout=None):
# --> 648         self._event.wait(timeout)
#     649
#     650     def get(self, timeout=None):
#
# ~/miniconda3/lib/python3.7/threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# ~/miniconda3/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %%
relation_ids_results[:2]

# %%
unique_relation_ids = set()
all_test = []
for couple in relation_ids_results:
    unique_relation_ids.update(couple[1])

# %%
len(unique_relation_ids)

# %%
start = time.time()
result_relation_labels = parallal_task_2(get_relation_label, unique_relation_ids)
print(time.time() - start)

# %%
relation_dict = dict()
for (relation_id, label) in result_relation_labels:
    relation_dict[relation_id] = label

# %%
# target_relation

# %%
target_relation_labels = []
for id in target_relation:
    if id in relation_dict.keys():
        target_relation_labels.append(relation_dict[id])

# %%
len(target_relation_labels)*100/len(target_relation)

# %%
relation_strs = pd.DataFrame(target_relation_labels, columns=['label'])
relation_strs.head()

# %%
relation_strs['label'].str.len().hist(bins=30)

# %%
f'{len(relation_strs[relation_strs["label"].str.len()> 40])*100/len(relation_strs)}%'

# %%
entities_with_relation_labels = []
for (entity_id, relation_ids) in relation_ids_results:
    relation_labels = ''
    for relation_id in relation_ids:
        if len(relation_dict[relation_id]) < 40:
            relation_labels += f' {relation_dict[relation_id]} , '
    
    relation_labels = f'[{relation_labels[:-2]}]'
    entities_with_relation_labels.append([entity_id, relation_labels])

# %%
entities_with_relation_labels

# %%
get_entity_labels_and_aliases(qids[0])

# %%
start = time.time()
entity_labels_and_aliases = parallal_task_3(get_entity_labels_and_aliases, qids)
# entity_labels_and_aliases = [get_entity_labels_and_aliases(qid) for qid in qids]
print(time.time() - start)

# %%
lower_results = []
for result in entity_labels_and_aliases:
    results_for_one = [label.lower() for label in result]
    lower_results.append((result[0], results_for_one))
lower_results[:2]

# %%
(entities_list, counter) = find_nearest_word_in_question(questions, lower_results)

# %%
rows = []
for i in range(len(questions)):
    rows.append([questions[i], entities_list[i], entities_with_relation_labels[i][1], target_relation[i]])

# %%
# training_data_results = pd.DataFrame([questions[:10], entities_with_relation_labels, columns= ['entity id', 'relation labels'])
training_data_results = pd.DataFrame(rows, columns=['question', 'entity label', 'relation labels', 'target relation id'])
training_data_results

# %%
training_data_results.to_csv('./3-Relation_Linking_Data/1-csv_format/training_data.csv', index=False)

# %% [markdown]
# ## Simple_questions Validation set

# %%
with open('2-NEL_Data/0-raw_data/simple_questions_v2/annotated_wd_data_valid.txt', encoding='utf-8') as file:
    lines = file.readlines()

# print(len(lines))
validation_data = []
for line in lines:
    line = line.strip().split('\t', 3)
    del line[2]
    validation_data.append(line)
    
qids = [line[0] for line in validation_data]
target_relation = [line[1].replace('R', 'P') for line in validation_data]
questions = [line[2] for line in validation_data]

# %%
start = time.time()
relation_ids_results = parallal_task(get_entity_relation_ids, qids)
print(time.time() - start)
len(relation_ids_results)

# %%
unique_relation_ids = set()
all_test = []
for couple in relation_ids_results:
    unique_relation_ids.update(couple[1])

# %%
start = time.time()
result_relation_labels = parallal_task_2(get_relation_label, unique_relation_ids)
print(time.time() - start)

# %%
relation_dict = dict()
for (relation_id, label) in result_relation_labels:
    relation_dict[relation_id] = label

# %%
entities_with_relation_labels = []
for (entity_id, relation_ids) in relation_ids_results:
    relation_labels = ''
    for relation_id in relation_ids:
        if len(relation_dict[relation_id]) < 40:
            relation_labels += f' {relation_dict[relation_id]} , '
    
    relation_labels = f'[{relation_labels[:-2]}]'
    entities_with_relation_labels.append([entity_id, relation_labels])

# %%
start = time.time()
entity_labels_and_aliases = parallal_task_3(get_entity_labels_and_aliases, qids)
# entity_labels_and_aliases = [get_entity_labels_and_aliases(qid) for qid in qids]
print(time.time() - start)

# %%
lower_results = []
for result in entity_labels_and_aliases:
    results_for_one = [label.lower() for label in result]
    lower_results.append((result[0], results_for_one))
lower_results[:2]

# %%
(entities_list, counter) = find_nearest_word_in_question(questions, lower_results)

# %%
rows = []
for i in range(len(questions)):
    rows.append([questions[i], entities_list[i], entities_with_relation_labels[i][1], target_relation[i]])

# %%
validation_data_results = pd.DataFrame(rows, columns=['question', 'entity label', 'relation labels', 'target relation id'])
validation_data_results.head(10)

# %%
validation_data_results.to_csv('./3-Relation_Linking_Data/1-csv_format/validation_data.csv', index=False)

# %% [markdown]
# ## Simple_questions Testing Data

# %%
with open('2-NEL_Data/0-raw_data/simple_questions_v2/annotated_wd_data_test.txt', encoding='utf-8') as file:
    lines = file.readlines()

# print(len(lines))
test_data = []
for line in lines:
    line = line.strip().split('\t', 3)
    del line[2]
    test_data.append(line)

    
qids = [line[0] for line in test_data]
target_relation = [line[1].replace('R', 'P') for line in test_data]
questions = [line[2] for line in test_data]

# %%
len(qids)
# Out:
# 9961

# %%
start = time.time()
relation_ids_results = parallal_task(get_entity_relation_ids, qids)
print(time.time() - start)
len(relation_ids_results)
# Out:
# 2190.7412259578705
# 9961

# %%
# relation_ids_results

# %%
unique_relation_ids = set()
all_test = []
for couple in relation_ids_results:
    unique_relation_ids.update(couple[1])

# %%
start = time.time()
result_relation_labels = parallal_task_2(get_relation_label, unique_relation_ids)
print(time.time() - start)
# Out:
# 888.3796243667603

# %%
relation_dict = dict()
for (relation_id, label) in result_relation_labels:
    relation_dict[relation_id] = label

# %%
target_relation
# Out:
# ['P136',
#  'P19',
#  'P58',
#  'P20',
#  'P509',
#  'P19',
#  'P136',
#  'P172',
#  'P413',
#  'P21',
#  'P413',
#  'P509',
#  'P136',
#  'P20',
#  'P364',
#  'P737',
#  'P19',
#  'P710',
#  'P264',
#  'P149',
#  'P123',
#  'P136',
#  'P136',
#  'P19',
#  'P106',
#  'P413',
#  'P20',
#  'P112',
#  'P136',
#  'P57',
#  'P19',
#  'P276',
#  'P86',
#  'P19',
#  'P421',
#  'P136',
#  'P19',
#  'P19',
#  'P136',
#  'P149',
#  'P19',
#  'P27',
#  'P136',
#  'P136',
#  'P136',
#  'P175',
#  'P136',
#  'P495',
#  'P84',
#  'P175',
#  'P136',
#  'P31',
#  'P115',
#  'P19',
#  'P404',
#  'P136',
#  'P737',
#  'P19',
#  'P27',
#  'P421',
#  'P737',
#  'P170',
#  'P19',
#  'P136',
#  'P19',
#  'P21',
#  'P136',
#  'P495',
#  'P136',
#  'P17',
#  'P421',
#  'P136',
#  'P57',
#  'P131',
#  'P136',
#  'P136',
#  'P276',
#  'P264',
#  'P136',
#  'P136',
#  'P175',
#  'P404',
#  'P136',
#  'P136',
#  'P58',
#  'P136',
#  'P509',
#  'P112',
#  'P21',
#  'P136',
#  'P106',
#  'P397',
#  'P19',
#  'P136',
#  'P179',
#  'P58',
#  'P19',
#  'P509',
#  'P738',
#  'P403',
#  'P364',
#  'P112',
#  'P136',
#  'P136',
#  'P136',
#  'P509',
#  'P413',
#  'P19',
#  'P61',
#  'P106',
#  'P19',
#  'P676',
#  'P136',
#  'P123',
#  'P27',
#  'P136',
#  'P58',
#  'P136',
#  'P162',
#  'P175',
#  'P495',
#  'P136',
#  'P131',
#  'P149',
#  'P264',
#  'P136',
#  'P495',
#  'P170',
#  'P27',
#  'P509',
#  'P21',
#  'P136',
#  'P676',
#  'P136',
#  'P21',
#  'P364',
#  'P21',
#  'P19',
#  'P175',
#  'P136',
#  'P264',
#  'P607',
#  'P50',
#  'P21',
#  'P397',
#  'P136',
#  'P140',
#  'P495',
#  'P136',
#  'P136',
#  'P58',
#  'P136',
#  'P413',
#  'P710',
#  'P136',
#  'P272',
#  'P364',
#  'P136',
#  'P106',
#  'P20',
#  'P123',
#  'P27',
#  'P136',
#  'P509',
#  'P136',
#  'P123',
#  'P509',
#  'P136',
#  'P264',
#  'P149',
#  'P162',
#  'P1040',
#  'P31',
#  'P397',
#  'P162',
#  'P58',
#  'P136',
#  'P495',
#  'P149',
#  'P1431',
#  'P397',
#  'P31',
#  'P403',
#  'P136',
#  'P86',
#  'P136',
#  'P136',
#  'P21',
#  'P57',
#  'P136',
#  'P1303',
#  'P170',
#  'P136',
#  'P175',
#  'P21',
#  'P136',
#  'P31',
#  'P27',
#  'P136',
#  'P364',
#  'P19',
#  'P136',
#  'P19',
#  'P19',
#  'P264',
#  'P58',
#  'P106',
#  'P136',
#  'P21',
#  'P136',
#  'P57',
#  'P144',
#  'P136',
#  'P136',
#  'P1303',
#  'P106',
#  'P86',
#  'P495',
#  'P136',
#  'P106',
#  'P710',
#  'P179',
#  'P407',
#  'P136',
#  'P86',
#  'P19',
#  'P172',
#  'P364',
#  'P138',
#  'P136',
#  'P40',
#  'P57',
#  'P123',
#  'P264',
#  'P136',
#  'P50',
#  'P19',
#  'P136',
#  'P136',
#  'P31',
#  'P170',
#  'P19',
#  'P136',
#  'P136',
#  'P404',
#  'P57',
#  'P136',
#  'P19',
#  'P495',
#  'P27',
#  'P106',
#  'P136',
#  'P495',
#  'P27',
#  'P58',
#  'P136',
#  'P20',
#  'P136',
#  'P19',
#  'P1303',
#  'P364',
#  'P50',
#  'P20',
#  'P27',
#  'P175',
#  'P21',
#  'P1040',
#  'P19',
#  'P136',
#  'P1431',
#  'P58',
#  'P21',
#  'P136',
#  'P17',
#  'P19',
#  'P21',
#  'P136',
#  'P1303',
#  'P413',
#  'P272',
#  'P607',
#  'P136',
#  'P27',
#  'P364',
#  'P495',
#  'P21',
#  'P136',
#  'P1303',
#  'P21',
#  'P364',
#  'P404',
#  'P136',
#  'P58',
#  'P106',
#  'P19',
#  'P1303',
#  'P136',
#  'P170',
#  'P179',
#  'P364',
#  'P136',
#  'P136',
#  'P170',
#  'P27',
#  'P1303',
#  'P136',
#  'P178',
#  'P20',
#  'P170',
#  'P57',
#  'P27',
#  'P136',
#  'P31',
#  'P136',
#  'P413',
#  'P19',
#  'P264',
#  'P21',
#  'P413',
#  'P27',
#  'P19',
#  'P27',
#  'P136',
#  'P136',
#  'P178',
#  'P364',
#  'P58',
#  'P131',
#  'P19',
#  'P404',
#  'P495',
#  'P19',
#  'P27',
#  'P136',
#  'P21',
#  'P413',
#  'P19',
#  'P364',
#  'P509',
#  'P136',
#  'P138',
#  'P136',
#  'P136',
#  'P136',
#  'P19',
#  'P178',
#  'P27',
#  'P150',
#  'P50',
#  'P86',
#  'P413',
#  'P364',
#  'P149',
#  'P170',
#  'P19',
#  'P413',
#  'P20',
#  'P106',
#  'P106',
#  'P86',
#  'P61',
#  'P172',
#  'P710',
#  'P57',
#  'P397',
#  'P264',
#  'P20',
#  'P19',
#  'P404',
#  'P136',
#  'P19',
#  'P19',
#  'P172',
#  'P136',
#  'P19',
#  'P136',
#  'P21',
#  'P106',
#  'P17',
#  'P404',
#  'P136',
#  'P136',
#  'P50',
#  'P413',
#  'P175',
#  'P19',
#  'P136',
#  'P196',
#  'P364',
#  'P136',
#  'P172',
#  'P27',
#  'P57',
#  'P17',
#  'P20',
#  'P413',
#  'P19',
#  'P136',
#  'P364',
#  'P136',
#  'P40',
#  'P272',
#  'P1303',
#  'P364',
#  'P175',
#  'P19',
#  'P27',
#  'P19',
#  'P495',
#  'P57',
#  'P27',
#  'P175',
#  'P162',
#  'P21',
#  'P17',
#  'P57',
#  'P21',
#  'P106',
#  'P136',
#  'P509',
#  'P175',
#  'P19',
#  'P136',
#  'P136',
#  'P136',
#  'P20',
#  'P136',
#  'P136',
#  'P136',
#  'P19',
#  'P19',
#  'P413',
#  'P21',
#  'P364',
#  'P404',
#  'P495',
#  'P413',
#  'P136',
#  'P136',
#  'P140',
#  'P175',
#  'P58',
#  'P136',
#  'P738',
#  'P136',
#  'P17',
#  'P1303',
#  'P17',
#  'P170',
#  'P136',
#  'P136',
#  'P27',
#  'P136',
#  'P136',
#  'P136',
#  'P27',
#  'P276',
#  'P676',
#  'P136',
#  'P19',
#  'P20',
#  'P413',
#  'P413',
#  'P19',
#  'P413',
#  'P144',
#  'P21',
#  'P264',
#  'P1303',
#  'P17',
#  'P136',
#  'P413',
#  'P509',
#  'P272',
#  'P19',
#  'P495',
#  'P1303',
#  'P136',
#  'P738',
#  'P172',
#  'P136',
#  'P1303',
#  'P19',
#  'P21',
#  'P136',
#  'P162',
#  'P1431',
#  'P170',
#  'P106',
#  'P276',
#  'P57',
#  'P136',
#  'P136',
#  'P413',
#  'P136',
#  'P27',
#  'P175',
#  'P136',
#  'P272',
#  'P106',
#  'P31',
#  'P136',
#  'P86',
#  'P136',
#  'P413',
#  'P136',
#  'P364',
#  'P20',
#  'P140',
#  'P136',
#  'P404',
#  'P1431',
#  'P289',
#  'P57',
#  'P641',
#  'P495',
#  'P58',
#  'P136',
#  'P140',
#  'P27',
#  'P136',
#  'P413',
#  'P86',
#  'P19',
#  'P264',
#  'P19',
#  'P136',
#  'P495',
#  'P31',
#  'P19',
#  'P19',
#  'P53',
#  'P364',
#  'P19',
#  'P136',
#  'P172',
#  'P58',
#  'P264',
#  'P106',
#  'P272',
#  'P106',
#  'P136',
#  'P106',
#  'P21',
#  'P364',
#  'P20',
#  'P40',
#  'P136',
#  'P421',
#  'P136',
#  'P136',
#  'P19',
#  'P136',
#  'P57',
#  'P106',
#  'P19',
#  'P1303',
#  'P264',
#  'P131',
#  'P136',
#  'P800',
#  'P607',
#  'P136',
#  'P136',
#  'P50',
#  'P19',
#  'P495',
#  'P20',
#  'P136',
#  'P20',
#  'P136',
#  'P27',
#  'P50',
#  'P172',
#  'P17',
#  'P113',
#  'P19',
#  'P136',
#  'P179',
#  'P136',
#  'P136',
#  'P136',
#  'P136',
#  'P175',
#  'P136',
#  'P136',
#  'P19',
#  'P264',
#  'P136',
#  'P136',
#  'P20',
#  'P495',
#  'P171',
#  'P264',
#  'P19',
#  'P136',
#  'P19',
#  'P131',
#  'P136',
#  'P27',
#  'P509',
#  'P17',
#  'P19',
#  'P264',
#  'P20',
#  'P27',
#  'P27',
#  'P136',
#  'P106',
#  'P1303',
#  'P413',
#  'P710',
#  'P272',
#  'P27',
#  'P21',
#  'P177',
#  'P136',
#  'P404',
#  'P21',
#  'P21',
#  'P413',
#  'P421',
#  'P105',
#  'P136',
#  'P607',
#  'P106',
#  'P140',
#  'P1142',
#  'P136',
#  'P19',
#  'P136',
#  'P136',
#  'P40',
#  'P27',
#  'P58',
#  'P1303',
#  'P421',
#  'P364',
#  'P138',
#  'P57',
#  'P86',
#  'P136',
#  'P136',
#  'P50',
#  'P136',
#  'P364',
#  'P136',
#  'P136',
#  'P57',
#  'P264',
#  'P27',
#  'P136',
#  'P27',
#  'P136',
#  'P140',
#  'P413',
#  'P170',
#  'P136',
#  'P31',
#  'P413',
#  'P509',
#  'P397',
#  'P136',
#  'P276',
#  'P21',
#  'P413',
#  'P20',
#  'P178',
#  'P21',
#  'P58',
#  'P495',
#  'P136',
#  'P106',
#  'P1431',
#  'P136',
#  'P20',
#  'P136',
#  'P31',
#  'P27',
#  'P364',
#  'P364',
#  'P131',
#  'P19',
#  'P19',
#  'P20',
#  'P19',
#  'P20',
#  'P172',
#  'P19',
#  'P19',
#  'P509',
#  'P264',
#  'P27',
#  'P136',
#  'P413',
#  'P509',
#  'P136',
#  'P136',
#  'P144',
#  'P170',
#  'P136',
#  'P136',
#  'P495',
#  'P279',
#  'P175',
#  'P413',
#  'P58',
#  'P19',
#  'P86',
#  'P364',
#  'P19',
#  'P119',
#  'P1431',
#  'P136',
#  'P50',
#  'P397',
#  'P175',
#  'P136',
#  'P136',
#  'P21',
#  'P364',
#  'P413',
#  'P136',
#  'P676',
#  'P21',
#  'P162',
#  'P364',
#  'P19',
#  'P19',
#  'P19',
#  'P136',
#  'P27',
#  'P19',
#  'P136',
#  'P136',
#  'P413',
#  'P172',
#  'P136',
#  'P115',
#  'P276',
#  'P136',
#  'P136',
#  'P136',
#  'P136',
#  'P20',
#  'P20',
#  'P27',
#  'P495',
#  'P421',
#  'P19',
#  'P136',
#  'P404',
#  'P19',
#  'P136',
#  'P19',
#  'P136',
#  'P272',
#  'P19',
#  'P19',
#  'P136',
#  'P21',
#  'P21',
#  'P59',
#  'P19',
#  'P106',
#  'P495',
#  'P140',
#  'P106',
#  'P19',
#  'P136',
#  'P364',
#  'P404',
#  'P413',
#  'P136',
#  'P19',
#  'P404',
#  'P27',
#  'P19',
#  'P57',
#  'P136',
#  'P136',
#  'P21',
#  'P136',
#  'P20',
#  'P19',
#  'P58',
#  'P364',
#  'P136',
#  'P413',
#  'P19',
#  'P407',
#  'P17',
#  'P509',
#  'P398',
#  'P276',
#  'P421',
#  'P136',
#  'P27',
#  'P404',
#  'P19',
#  'P27',
#  'P27',
#  'P413',
#  'P509',
#  'P509',
#  'P19',
#  'P112',
#  'P509',
#  'P21',
#  'P136',
#  'P421',
#  'P175',
#  'P136',
#  'P1303',
#  'P136',
#  'P19',
#  'P17',
#  'P19',
#  'P413',
#  'P19',
#  'P364',
#  'P21',
#  'P1142',
#  'P364',
#  'P272',
#  'P136',
#  'P40',
#  'P27',
#  'P264',
#  'P20',
#  'P136',
#  'P27',
#  'P20',
#  'P676',
#  'P407',
#  'P162',
#  'P21',
#  'P19',
#  'P20',
#  'P57',
#  'P495',
#  'P136',
#  'P738',
#  'P175',
#  'P364',
#  'P607',
#  'P138',
#  'P106',
#  'P20',
#  'P131',
#  'P421',
#  'P136',
#  'P27',
#  'P509',
#  'P413',
#  'P495',
#  'P21',
#  'P20',
#  'P1303',
#  'P19',
#  'P136',
#  'P19',
#  'P27',
#  'P58',
#  'P272',
#  'P364',
#  'P170',
#  'P495',
#  'P136',
#  'P86',
#  'P21',
#  'P364',
#  'P364',
#  'P27',
#  'P31',
#  'P21',
#  'P27',
#  'P19',
#  'P509',
#  'P65',
#  'P136',
#  'P264',
#  'P27',
#  'P175',
#  'P175',
#  'P172',
#  'P136',
#  'P136',
#  'P171',
#  'P40',
#  'P136',
#  'P136',
#  'P136',
#  'P421',
#  'P397',
#  'P170',
#  'P19',
#  'P264',
#  'P738',
#  'P19',
#  'P136',
#  'P58',
#  'P136',
#  'P136',
#  'P413',
#  'P1303',
#  'P495',
#  'P20',
#  'P140',
#  'P364',
#  'P19',
#  'P136',
#  'P136',
#  'P397',
#  'P20',
#  'P136',
#  'P509',
#  'P175',
#  'P413',
#  'P421',
#  'P170',
#  'P123',
#  'P136',
#  'P86',
#  'P162',
#  'P106',
#  'P136',
#  'P136',
#  'P272',
#  'P27',
#  'P19',
#  'P149',
#  'P1303',
#  'P136',
#  'P86',
#  'P136',
#  'P364',
#  'P178',
#  'P136',
#  'P123',
#  'P131',
#  'P397',
#  'P495',
#  'P178',
#  'P20',
#  'P40',
#  'P136',
#  'P136',
#  'P20',
#  'P413',
#  'P106',
#  'P175',
#  'P364',
#  'P136',
#  'P136',
#  'P19',
#  'P710',
#  'P21',
#  'P21',
#  'P136',
#  'P136',
#  'P21',
#  'P136',
#  'P20',
#  'P136',
#  'P172',
#  'P407',
#  'P172',
#  'P20',
#  'P175',
#  'P364',
#  'P364',
#  'P364',
#  'P106',
#  'P136',
#  'P21',
#  'P404',
#  'P495',
#  'P136',
#  'P170',
#  'P509',
#  'P113',
#  'P136',
#  'P136',
#  'P58',
#  'P27',
#  'P136',
#  'P106',
#  'P140',
#  'P421',
#  'P20',
#  'P31',
#  'P19',
#  'P413',
#  'P27',
#  'P136',
#  'P136',
#  'P86',
#  'P19',
#  'P19',
#  ...]

# %%
# target_relation_labels = []
# for id in target_relation:
#     if id in relation_dict.keys():
#         target_relation_labels.append(relation_dict[id])

# %%
# len(target_relation_labels)
# Out:
# 9902

# %%
entities_with_relation_labels = []
for (entity_id, relation_ids) in relation_ids_results:
    relation_labels = ''
    for relation_id in relation_ids:
        if len(relation_dict[relation_id]) < 40:
            relation_labels += f' {relation_dict[relation_id]} , '
    
    relation_labels = f'[{relation_labels[:-2]}]'
    entities_with_relation_labels.append([entity_id, relation_labels])

# %%
start = time.time()
entity_labels_and_aliases = parallal_task_3(get_entity_labels_and_aliases, qids)
# entity_labels_and_aliases = [get_entity_labels_and_aliases(qid) for qid in qids]
print(time.time() - start)
# Out:
# 2180.26535654068

# %%
lower_results = []
for result in entity_labels_and_aliases:
    results_for_one = [label.lower() for label in result]
    lower_results.append((result[0], results_for_one))
lower_results[:2]
# Out:
# [('Q5487302', ['q5487302', 'harder ... faster']),
#  ('Q16330302', ['q16330302', 'alex golfis'])]

# %%
(entities_list, counter) = find_nearest_word_in_question(questions, lower_results)

# %%
c_empty = 0
for e in entities_list:
    if e == '':
        c_empty += 1
print(c_empty)
print(c_empty*100/len(entities_list))
# Out:
# 909
# 9.125589800220862

# %%
len(questions)
# Out:
# 9961

# %%
target_relation_labels = []
for id in target_relation:
    if id in relation_dict.keys():
        target_relation_labels.append(relation_dict[id])
    else:
        print(id)
        target_relation_labels.append('')
# Out:
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738
# P738

# %%
get_relation_label('P738')
# Out:
# ('P738', '')

# %%
len(target_relation_labels)
# Out:
# 9961

# %%
rows = []
for i in range(len(questions)):
    rows.append([questions[i], entities_list[i], entities_with_relation_labels[i][1], target_relation[i], target_relation_labels[i]])

# %%
test_data_results = pd.DataFrame(rows, columns=['question', 'entity label', 'relation labels', 'target relation id', 'target relation labels'])
test_data_results.head(10)
# Out:
#                                      question       entity label  \
# 0  Which genre of album is harder.....faster?
# 1           what city was alex golfis born in        alex golfis
# 2        what film is by the writer phil hay?           phil hay
# 3                 Where did roger marquis die      roger marquis
# 4   what was the cause of death of yves klein         yves klein
# 5        Which equestrian was born in dublin?             dublin
# 6                   What is a tv action show?
# 7           what's akbar tandjung's ethnicity
# 8       What position does carlos gomez play?
# 9         how does engelbert zaschka identify  engelbert zaschka
#
#                                      relation labels target relation id  \
# 0  [ record label ,  instance of ,  follows ,  fo...               P136
# 1  [ instance of ,  sex or gender ,  occupation ,...                P19
# 2  [ instance of ,  sex or gender ,  country of c...                P58
# 3  [ date of birth ,  date of death ,  instance o...                P20
# 4  [ sex or gender ,  place of birth ,  VIAF ID ,...               P509
# 5  [ category for people born here ,  Dewey Decim...                P19
# 6  [ coordinate location ,  country ,  instance o...               P136
# 7  [ VIAF ID ,  ISNI ,  member of political party...               P172
# 8  [ Commons category ,  date of birth ,  instanc...               P413
# 9  [ sex or gender ,  Commons category ,  VIAF ID...                P21
#
#                  target relation labels
# 0                                 genre
# 1                        place of birth
# 2                          screenwriter
# 3                        place of death
# 4                        cause of death
# 5                        place of birth
# 6                                 genre
# 7                          ethnic group
# 8  position played on team / speciality
# 9                         sex or gender

# %%
test_data_results
# Out:
#                                                question  \
# 0            Which genre of album is harder.....faster?
# 1                     what city was alex golfis born in
# 2                  what film is by the writer phil hay?
# 3                           Where did roger marquis die
# 4             what was the cause of death of yves klein
# ...                                                 ...
# 9956  who was the creator of the fictional character...
# 9957  what's a college sporting event that took plac...
# 9958               what celestial object is 2974 holden
# 9959  what is the film genre for snow falling on ced...
# 9960               what nationality is lucille clifton?
#
#                 entity label  \
# 0
# 1                alex golfis
# 2                   phil hay
# 3              roger marquis
# 4                 yves klein
# ...                      ...
# 9956          doctor faustus
# 9957           oklahoma city
# 9958             2974 holden
# 9959  snow falling on cedars
# 9960         lucille clifton
#
#                                         relation labels target relation id  \
# 0     [ record label ,  instance of ,  follows ,  fo...               P136
# 1     [ instance of ,  sex or gender ,  occupation ,...                P19
# 2     [ instance of ,  sex or gender ,  country of c...                P58
# 3     [ date of birth ,  date of death ,  instance o...                P20
# 4     [ sex or gender ,  place of birth ,  VIAF ID ,...               P509
# ...                                                 ...                ...
# 9956  [ from narrative universe ,  Freebase ID ,  co...               P170
# 9957  [ topic's main category ,  Dewey Decimal Class...               P276
# 9958  [ named after ,  discoverer or inventor ,  fol...                P31
# 9959  [ instance of ,  IMDb ID ,  director ,  cast m...               P136
# 9960  [ VIAF ID ,  ISNI ,  MusicBrainz artist ID ,  ...                P27
#
#       target relation labels
# 0                      genre
# 1             place of birth
# 2               screenwriter
# 3             place of death
# 4             cause of death
# ...                      ...
# 9956                 creator
# 9957                location
# 9958             instance of
# 9959                   genre
# 9960  country of citizenship
#
# [9961 rows x 5 columns]

# %%
test_data_results.to_csv('./3-Relation_Linking_Data/1-csv_format/test_data.csv', index=False)
