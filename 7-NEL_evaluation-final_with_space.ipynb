# %%
# https://towardsdatascience.com/calculating-string-similarity-in-python-276e18a7d33a
# https://pypi.org/project/fuzzywuzzy/
# https://www.adamsmith.haus/python/answers/how-to-find-a-similarity-metric-between-two-strings-in-python


from transformers import T5TokenizerFast, T5ForConditionalGeneration 
from transformers import Trainer

import os

os.environ["CUDA_VISIBLE_DEVICES"] = "2" 


from concurrent.futures import ThreadPoolExecutor, as_completed

import pandas as pd
import numpy as np
import torch
import torchvision
import Levenshtein
from fuzzywuzzy import fuzz
import time

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
# device = torch.device("cuda:2") if torch.cuda.is_available() else torch.device("cpu")

# %%
def get_levenshtein_dis(str_1, str_2):
    return Levenshtein.distance(str_1, str_2)

# %%
def get_fuzzy_ration(str_1, str_2):
    return fuzz.ratio(str_1, str_2)

# %%
max_source_length = 1024
max_target_length = 128

# %%
tokenizer = T5TokenizerFast.from_pretrained("t5-base")
model_path = "./NEL_model_shuffled_add_spaces_in_input/checkpoint-20000"
model = T5ForConditionalGeneration.from_pretrained(model_path).to(device)
# model = T5ForConditionalGeneration.from_pretrained(model_path)

# %% [markdown]
# ## testing with the simple test data

# %%
simple_test_data = pd.read_csv('./2-NEL_Data/2-csv_format_2/simple_test_shuffled.csv')
# simple_test_data = simple_test_data.sample(frac=1, random_state=1)
simple_test_data
# Out:
#             qid                                           question  \
# 0      Q5487302   ** Which genre of album is harder.....faster? **
# 1     Q16330302            ** what city was alex golfis born in **
# 2     Q16225521         ** what film is by the writer phil hay? **
# 3      Q7358590                  ** Where did roger marquis die **
# 4       Q154335    ** what was the cause of death of yves klein **
# ...         ...                                                ...
# 9956   Q1447249  ** who was the creator of the fictional charac...
# 9957     Q34863  ** what's a college sporting event that took p...
# 9958    Q582715         ** what celestial object is 2974 holden **
# 9959    Q582147  ** what is the film genre for snow falling on ...
# 9960    Q458750         ** what nationality is lucille clifton? **
#
#                               entity  \
# 0                           **    **
# 1                **  alex golfis  **
# 2                   **  phil hay  **
# 3              **  roger marquis  **
# 4                 **  yves klein  **
# ...                              ...
# 9956          **  doctor faustus  **
# 9957           **  oklahoma city  **
# 9958             **  2974 holden  **
# 9959  **  snow falling on cedars  **
# 9960         **  lucille clifton  **
#
#                                          wikidata_reply  qid_in_reply  \
# 0                                                **  **         False
# 1     ** [[ Q16330302 , Alex Golfis , Greek actor (1...          True
# 2     ** [[ Q16225521 , Phil Hay , screenwriter ], [...          True
# 3     ** [[ Q7358590 , Roger Marquis , American base...          True
# 4     ** [[ Q8062325 , Yves Klein Blue , Australian ...          True
# ...                                                 ...           ...
# 9956  ** [[ Q386431 , Doctor Faustus , novel written...          True
# 9957  ** [[ Q15256873 , OKC Energy FC , football clu...          True
# 9958       ** [[ Q582715 , 2974 Holden , asteroid ]] **          True
# 9959  ** [[ Q582147 , Snow Falling on Cedars , 1999 ...          True
# 9960  ** [[ Q65048350 , Lucille Clifton , Laxsgiik  ...          True
#
#       input_len
# 0            64
# 1           121
# 2           419
# 3           209
# 4           553
# ...         ...
# 9956        549
# 9957        636
# 9958        107
# 9959        229
# 9960        184
#
# [9961 rows x 6 columns]

# %%
input_text = list(simple_test_data['question'] + ',' + simple_test_data['entity'] + ',' + simple_test_data['wikidata_reply'])
input_text[0]
# Out:
# '** Which genre of album is harder.....faster? **,**    **,**  **'

# %%
target_text = list(simple_test_data['qid'])
target_text[0]
# Out:
# 'Q5487302'

# %%
counter_empty = 0
for s in simple_test_data['entity']:
    if s == '****':
        counter_empty += 1
counter_empty
# Out:
# 0

# %%
X_test_tokenized = tokenizer(['nel: ' + sequence for sequence in input_text], 
                              padding=True, 
                              truncation=True, 
                              max_length=max_source_length)

y_test_tokenized = tokenizer(target_text, 
                              padding=True, 
                              truncation=True, 
                              max_length=max_target_length)

print(len(simple_test_data))
# Out:
# 9961

# %%
tokens = []
for text in input_text:
    tokens.append(tokenizer('nel: ' + text, return_tensors="pt", padding=True, truncation=True, max_length=512).input_ids)

# %%
tokens[0]
# Out:
# tensor([[    3,    29,    15,    40,    10, 14011,  4073,  5349,    13,  2306,
#             19,  7501,  9374, 11584,    49,    58, 14011,     6, 19844, 14011,
#              6, 19844, 14011,     1]])

# %%
# results = []
# # model = model.to(device)

# for token in tokens:
#     results.append(model.generate(token.to(device)))

# %%
start = time.time()
counter = 0
simple_predictions = []
for token in tokens:
    if counter%100 == 0:
        print(counter)
    counter += 1
    prediction = model.generate(token.to(device))
    simple_predictions.append(prediction)
    
print(time.time() - start)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 1271.919031381607

# %%
# tokenizer.decode(simple_predictions[0][0], skip_special_tokens=True)

# %%
final_ouput_2 = []
for result in simple_predictions:
    final_ouput_2.append(tokenizer.decode(result[0], skip_special_tokens=True))

# %%
final_ouput_2[0]
# Out:
# 'Q71616'

# %%
# counter = 0
# for i in range(len(final_ouput_2)):
#     if final_ouput_2[i] != predicitons[i]:
#         print(target_text[i] + "    " + final_ouput_2[i] + "    " + predicitons[i])
#         counter += 1
# counter

# %%
# counter = 0
# for i in range(len(final_ouput_2)):
#     if predicitons[i] != target_text[i]:
#         counter += 1
# 1- counter/len(predicitons)

# %%
counter = 0
for i in range(len(final_ouput_2)):
    if final_ouput_2[i] == target_text[i]:
        counter += 1
counter*100/len(final_ouput_2)
# Out:
# 84.98142756751331

# %%
counter = 0
for i in range(len(final_ouput_2)):
    if final_ouput_2[i] == target_text[i]:
        counter += 1
counter*100/len(final_ouput_2)
# Out:
# 84.98142756751331

# %%
counter = 0
for i in range(len(final_ouput_2)):
    if final_ouput_2[i] != target_text[i] and simple_test_data['entity'][i] != '****':
        counter += 1
#         print(final_ouput_2[i] + '    ' + target_text[i])
1- counter/len(final_ouput_2)
# Out:
# 0.849814275675133

# %% [markdown]
# ## disamb_test_data

# %%
disamb_test_data = pd.read_csv('./2-NEL_Data/2-csv_format_2/wikidata_disambig_test_shuffled.csv')
disamb_test_data
# Out:
#            qid                                           question  \
# 0        Q3918  ** The University of Nanking (金陵大学) was a priv...
# 1       Q16666  **  private university in Nanjing, China which...
# 2        Q1860  **  first school officially named University (...
# 3       Q81982  **  to the German-speaking nations. Silbermann...
# 4     Q3758482  **  Bart van Oort and Gary Cooper. Opinions. O...
# ...        ...                                                ...
# 9995    Q81292  **  = 100 sq ft). ≈0.00002295684 acres. 92 903...
# 9996      Q190  **  that all beings are expressions of and par...
# 9997   Q193291  **  idealistic and panentheistic philosophies....
# 9998     Q1845  **  as Religious Science or Science of Mind. U...
# 9999   Q132196  **  water, comes back to you". The Law of Attr...
#
#                    entity                                     wikidata_reply  \
# 0      **  University  **  ** [[ Q13371 , Harvard University , private un...
# 1         **  Nanjing  **  ** [[ Q19851992 , Nanjing , direct-administere...
# 2         **  English  **  ** [[ Q1062280 , Channel 5 , British TV statio...
# 3     **  harpsichord  **  ** [[ Q29385649 , Harpsichord , chordophone-zi...
# 4     **  Gary Cooper  **  ** [[ Q3758482 , Gary Cooper , British musicia...
# ...                   ...                                                ...
# 9995         **  acre  **  ** [[ Q126084 , Acre , city in Israel ], [ Q15...
# 9996          **  God  **  ** [[ Q604258 , Göd , town in Hungary ], [ Q17...
# 9997       **  Spirit  **  ** [[ Q256616 , Spirit , 2007 album by Leona L...
# 9998        **  Bible  **  ** [[ Q1845 , Bible , collection of sacred boo...
# 9999        **  karma  **  ** [[ Q21066819 , Karma , female Bhutanese rec...
#
#       qid_in_reply  input_len
# 0             True        743
# 1             True        707
# 2             True        688
# 3             True        682
# 4             True        649
# ...            ...        ...
# 9995          True        702
# 9996          True        711
# 9997          True        712
# 9998          True        620
# 9999          True        568
#
# [10000 rows x 6 columns]

# %%
disamb_input_text = list(disamb_test_data['question'] + ',' + disamb_test_data['entity'] + ',' + disamb_test_data['wikidata_reply'])
disamb_input_text[0]
# Out:
# '** The University of Nanking (金陵大学) was a private university in Nanjing, China  **,**  University  **,** [[ Q13371 , Harvard University , private university in Cambridge, Massachusetts ], [ Q3918 , university , academic institution for further education ], [ Q21028957 , Hochschule , German term for "higher schooling", i.e. institutions of tertiary education (such as Universities), which may or may not include vocational or professional schools ], [ Q2463874 , University , Hillsborough County, Florida, USA ], [ Q7894478 , University , Orange County, Florida, USA ], [ Q34433 , University of Oxford , collegiate research university in Oxford, England ], [ Q3612349 , University , census-designated place in Mississippi, United States ]] **'

# %%
disamb_target_text = list(disamb_test_data['qid'])
disamb_target_text[0]
# Out:
# 'Q3918'

# %%
counter_empty = 0
for s in disamb_test_data['entity']:
    if s == '****':
        counter_empty += 1
counter_empty
# Out:
# 0

# %%
disamb_tokens = []
for text in disamb_input_text:
    disamb_tokens.append(tokenizer('nel: ' + text, return_tensors="pt", padding=True, truncation=True, max_length=512).input_ids)

# %%
start = time.time()
counter = 0
disamb_predictions = []
for token in disamb_tokens:
    if counter%100 == 0:
        print(counter)
    counter += 1
    prediction = model.generate(token.to(device))
    disamb_predictions.append(prediction)
    
print(time.time() - start)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 1248.0933773517609

# %%
disamb_final_ouput_2 = []
for result in disamb_predictions:
    disamb_final_ouput_2.append(tokenizer.decode(result[0], skip_special_tokens=True))

# %%
disamb_counter = 0
for i in range(len(disamb_final_ouput_2)):
    if disamb_final_ouput_2[i] == disamb_target_text[i]:
        disamb_counter += 1
disamb_counter*100/len(disamb_final_ouput_2)
# Out:
# 93.01

# %%
disamb_counter = 0
for i in range(len(disamb_final_ouput_2)):
    if disamb_final_ouput_2[i] == disamb_target_text[i]:
        disamb_counter += 1
disamb_counter*100/len(disamb_final_ouput_2)
# Out:
# 92.02

# %%
disamb_counter = 0
for i in range(len(disamb_final_ouput_2)):
    if disamb_final_ouput_2[i] != disamb_target_text[i] and disamb_test_data['entity'][i] != '****':
        disamb_counter += 1
#         print(final_ouput_2[i] + '    ' + target_text[i])
1- disamb_counter/len(disamb_final_ouput_2)
# Out:
# 0.9202

# %% [markdown]
# ###########################

# %%
import re
entities = []
for wiki_reply in wikidata_data:
    entities.append(re.findall(r'\[+(Q.*?),', wiki_reply))
len(entities)

# %%
final_copy = final_ouput_2.copy()
for i in range(len(final_copy)):
    min_value = 10000
    value_to_add = ''
    for entity in entities[i]:
        if get_levenshtein_dis(entity, final_ouput_2[i]) < min_value:
            min_value =  get_levenshtein_dis(entity, final_ouput_2[i])
            value_to_add = entity
    final_copy[i] = value_to_add

# %%
counter = 0
for i in range(len(final_copy)):
    if final_copy[i] != target_text[i]:
        counter += 1
1- counter/len(final_copy)

# %%
final_copy_3 = final_ouput_2.copy()
for i in range(len(final_copy)):
    diff = 10000
    value_to_add = ''
    for entity in entities[i]:
        try:
            if abs(int(entity[1:]) -  int(final_ouput_2[i][1:])) < diff:
                diff =  abs(int(entity[1:]) -  int(final_ouput_2[i][1:]))
                value_to_add = entity
        except:
            pass
    final_copy_3[i] = value_to_add

# %%
counter = 0
for i in range(len(final_copy_3)):
    if final_copy_3[i] != target_text[i]:
        counter += 1
1- counter/len(final_copy_3)

# %%
final_copy_2 = final_ouput_2.copy()
for i in range(len(final_copy_2)):
    max_value = -10000
    value_to_add = ''
    for entity in entities[i]:
        if get_levenshtein_dis(entity, final_ouput_2[i]) > max_value:
            max_value =  get_fuzzy_ration(entity, final_ouput_2[i])
            value_to_add = entity
    final_copy_2[i] = value_to_add
    print(max_value)
# Out:
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 36
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 24
# 100
# 100
# 100
# 100
# 57
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 36
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 36
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 57
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 50
# 50
# 100
# 100
# 100
# 46
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 62
# 100
# 100
# 36
# 100
# 50
# 100
# 50
# 25
# 100
# 100
# 59
# 33
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 71
# 100
# 35
# 100
# 100
# 100
# 100
# 27
# 100
# 100
# 88
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 36
# 100
# 100
# 57
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 46
# 100
# 100
# 53
# 100
# 47
# 29
# 100
# 100
# 100
# 86
# 100
# 88
# 27
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 57
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 44
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 33
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 94
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 67
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 25
# 43
# 24
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 31
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 88
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 62
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 25
# 100
# 33
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 40
# 43
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 88
# 100
# 100
# 40
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 33
# 100
# 62
# 100
# 62
# 100
# 100
# 100
# 100
# 50
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 12
# 22
# 100
# 100
# 100
# 100
# 100
# 50
# 36
# 100
# 100
# 100
# 100
# 59
# 100
# 100
# 100
# 100
# 100
# 100
# 60
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 57
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 31
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 33
# 100
# 100
# 100
# 33
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 40
# 38
# 100
# 100
# 100
# 100
# 88
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 24
# 100
# 40
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 44
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 27
# 100
# 100
# 100
# 100
# 100
# 100
# 56
# 100
# 100
# 100
# 100
# 100
# 100
# 57
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 35
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 53
# 100
# 100
# 27
# 40
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 46
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 46
# 100
# 40
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 47
# 100
# 38
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 50
# 100
# 100
# 43
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 86
# 100
# 100
# 100
# 36
# 100
# 100
# 100
# 100
# 50
# 100
# 67
# 100
# 62
# 100
# 27
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 38
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 86
# 100
# 44
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 27
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 25
# 100
# 47
# 50
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 67
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 56
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 40
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 44
# 100
# 100
# 100
# 100
# 100
# 100
# 59
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 67
# 100
# 100
# 100
# 100
# 100
# 57
# 100
# 100
# 100
# 35
# 17
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 31
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 31
# 100
# 100
# 100
# 27
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 88
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 40
# 100
# 100
# 100
# 100
# 53
# 100
# 57
# 40
# 100
# 100
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 20
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 40
# 100
# 100
# 100
# 100
# 100
# 86
# 35
# 27
# 100
# 100
# 100
# 88
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 44
# 100
# 83
# 100
# 29
# 100
# 46
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 46
# 100
# 31
# 100
# 100
# 25
# 33
# 43
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 27
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 62
# 100
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 62
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 62
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 24
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 57
# 100
# 100
# 100
# 100
# 100
# 50
# 27
# 100
# 100
# 100
# 100
# 100
# 62
# 27
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 13
# 100
# 100
# 100
# 100
# 44
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 44
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 67
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 88
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 22
# 35
# 57
# 88
# 100
# 100
# 62
# 35
# 100
# 100
# 100
# 100
# 31
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 35
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 24
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 53
# 100
# 100
# 100
# 38
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 88
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 38
# 25
# 35
# 100
# 100
# 100
# 100
# 100
# 40
# 43
# 100
# 35
# 29
# 100
# 38
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 57
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 46
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 46
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 31
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 36
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 33
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 33
# 100
# 100
# 53
# 100
# 50
# 50
# 100
# 100
# 29
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 44
# 100
# 100
# 53
# 100
# 100
# 43
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 53
# 100
# 100
# 47
# 100
# 100
# 100
# 88
# 40
# 31
# 100
# 100
# 100
# 40
# 100
# 100
# 31
# 100
# 100
# 50
# 100
# 100
# 35
# 33
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 57
# 100
# 46
# 100
# 100
# 27
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 88
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 29
# 47
# 100
# 38
# 100
# 62
# 100
# 100
# 100
# 100
# 93
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 88
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 40
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 27
# 43
# 100
# 100
# 100
# 46
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 31
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 31
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 25
# 100
# 100
# 43
# 40
# 100
# 88
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 27
# 100
# 27
# 100
# 100
# 29
# 35
# 100
# 100
# 100
# 100
# 46
# 100
# 22
# 24
# 57
# 25
# 100
# 100
# 100
# 59
# 100
# 100
# 100
# 59
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 27
# 53
# 40
# 100
# 33
# 100
# 47
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 24
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 27
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 31
# 100
# 100
# 100
# 100
# 43
# 100
# 31
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 14
# 100
# 100
# 56
# 100
# 40
# 100
# 100
# 100
# 100
# 33
# 100
# 100
# 100
# 88
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 93
# 57
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 62
# 100
# 67
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 57
# 100
# 100
# 100
# 88
# 59
# 100
# 100
# 100
# 93
# 100
# 100
# 25
# 100
# 100
# 57
# 100
# 100
# 100
# 100
# 100
# 100
# 36
# 100
# 100
# 40
# 100
# 33
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 31
# 46
# 100
# 100
# 62
# 40
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 67
# 35
# 100
# 100
# 50
# 27
# 100
# 100
# 100
# 33
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 31
# 100
# 100
# 100
# 100
# 100
# 100
# 75
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 59
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 27
# 100
# 100
# 22
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 75
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 31
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 59
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 88
# 100
# 100
# 100
# 100
# 100
# 43
# 62
# 100
# 67
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 86
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 43
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 29
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 67
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 46
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 55
# 100
# 100
# 100
# 31
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 43
# 50
# 100
# 100
# 100
# 100
# 57
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 46
# 100
# 100
# 100
# 27
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 27
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 27
# 50
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 40
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 62
# 100
# 40
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 24
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 33
# 27
# 100
# 100
# 100
# 100
# 100
# 100
# 56
# 31
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 50
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 27
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 20
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 33
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 47
# 100
# 100
# 57
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 62
# 100
# 53
# 31
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 75
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 31
# 100
# 53
# 88
# 100
# 22
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 59
# 36
# 100
# 29
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 88
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 22
# 57
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 57
# 100
# 100
# 100
# 100
# 60
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 31
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 31
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 59
# 100
# 100
# 100
# 100
# 27
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 35
# 27
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 93
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 38
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 29
# 47
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 33
# 100
# 100
# 100
# 100
# 27
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 94
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 25
# 100
# 46
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 43
# 100
# 100
# 100
# 40
# 100
# 100
# 88
# 12
# 100
# 27
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 38
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 38
# 100
# 62
# 100
# 100
# 100
# 100
# 100
# 31
# 31
# 100
# 100
# 100
# 100
# 46
# 100
# 33
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 31
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 62
# 100
# 40
# 40
# 46
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 47
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 13
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 88
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 88
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 31
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 40
# 38
# 100
# 100
# 100
# 100
# 47
# 100
# 57
# 40
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 36
# 100
# 100
# 100
# 100
# 100
# 57
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 31
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 67
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 88
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 50
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 47
# 100
# 100
# 27
# 100
# 46
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 50
# 100
# 100
# 100
# 100
# 94
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 24
# 100
# 100
# 100
# 24
# 100
# 100
# 100
# 100
# 40
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 88
# 50
# 100
# 100
# 38
# 100
# 100
# 24
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 46
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 46
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 67
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 18
# 100
# 43
# 100
# 100
# 62
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 62
# 100
# 33
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 62
# 100
# 100
# 43
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 47
# 40
# 100
# 100
# 100
# 100
# 25
# 57
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 42
# 100
# 86
# 88
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 31
# 100
# 100
# 47
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 57
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 88
# 25
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 62
# 100
# 100
# 100
# 100
# 38
# 40
# 100
# 100
# 100
# 100
# 100
# 27
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 25
# 100
# 38
# 100
# 100
# 40
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 47
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 27
# 100
# 100
# 100
# 100
# 100
# 100
# 88
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 33
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 88
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 50
# 43
# 100
# 100
# 100
# 100
# 29
# 100
# 88
# 100
# 100
# 57
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 44
# 38
# 100
# 100
# 100
# 53
# 100
# 100
# 40
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 44
# 100
# 100
# 35
# 100
# 100
# 100
# 88
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 46
# 100
# 100
# 100
# 40
# 38
# 27
# 100
# 100
# 100
# 40
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 62
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 24
# 100
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 38
# 100
# 100
# 88
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 57
# 100
# 62
# 100
# 22
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 75
# 24
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 18
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 36
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 40
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 33
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 67
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 59
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 57
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 27
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 31
# 100
# 100
# 29
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 25
# 100
# 100
# 29
# 100
# 50
# 100
# 44
# 53
# 100
# 100
# 100
# 100
# 100
# 35
# 33
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 25
# 100
# 100
# 53
# 100
# 31
# 100
# 100
# 38
# 100
# 38
# 100
# 100
# 31
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 46
# 100
# 100
# 47
# 47
# 38
# 100
# 43
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 29
# 100
# 100
# 43
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 44
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 25
# 22
# 100
# 43
# 40
# 100
# 100
# 83
# 33
# 100
# 100
# 36
# 100
# 100
# 100
# 100
# 100
# 100
# 33
# 100
# 100
# 100
# 38
# 100
# 100
# 38
# 100
# 47
# 100
# 100
# 100
# 40
# 43
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 71
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 14
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 38
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 67
# 50
# 100
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 25
# 43
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 57
# 47
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 25
# 88
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 29
# 100
# 27
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 71
# 46
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 24
# 100
# 100
# 100
# 100
# 100
# 88
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 27
# 25
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 88
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 88
# 100
# 100
# 100
# 100
# 75
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 46
# 100
# 100
# 33
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 27
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 25
# 100
# 40
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 38
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 38
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 67
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 44
# 53
# 100
# 100
# 31
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 47
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 55
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 31
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 33
# 100
# 100
# 62
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 59
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 36
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 46
# 67
# 100
# 100
# 100
# 100
# 100
# 100
# 22
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 88
# 46
# 100
# 100
# 57
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 31
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 14
# 100
# 40
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 44
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 35
# 100
# 47
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 46
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 27
# 100
# 100
# 100
# 100
# 100
# 40
# 88
# 100
# 100
# 50
# 100
# 100
# 47
# 100
# 100
# 100
# 47
# 100
# 27
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 56
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 40
# 100
# 40
# 100
# 100
# 31
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 88
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 57
# 100
# 100
# 100
# 40
# 55
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 86
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 59
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 50
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 50
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 24
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 71
# 40
# 35
# 71
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 17
# 100
# 100
# 100
# 100
# 62
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 46
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 36
# 100
# 100
# 38
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 27
# 36
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 36
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 62
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 57
# 100
# 100
# 50
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 27
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 31
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 46
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 33
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 31
# 100
# 100
# 100
# 100
# 100
# 100
# 27
# 100
# 57
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 31
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 93
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 62
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 38
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 59
# 59
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 22
# 100
# 100
# 100
# 27
# 35
# 100
# 53
# 100
# 100
# 100
# 38
# 100
# 62
# 100
# 100
# 100
# 33
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 44
# 100
# 100
# 100
# 100
# 100
# 100
# 56
# 100
# 100
# 100
# 31
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 82
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 31
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 44
# 100
# 100
# 40
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 44
# 100
# 100
# 100
# 100
# 100
# 25
# 62
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 59
# 40
# 100
# 100
# 100
# 59
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 13
# 100
# 33
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 31
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 24
# 100
# 35
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 40
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 27
# 100
# 100
# 100
# 100
# 15
# 100
# 35
# 38
# 100
# 100
# 33
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 40
# 33
# 27
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 15
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 100
# 24
# 100
# 100
# 100
# 100
# 100
# 38
# 24
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 43
# 12
# 22
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 27
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 57
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 33
# 53
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 25
# 100
# 50
# 100
# 100
# 100
# 100
# 27
# 100
# 100
# 46
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 44
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 40
# 33
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 22
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 33
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 47
# 100
# 38
# 40
# 100
# 100
# 100
# 100
# 38
# 40
# 100
# 100
# 100
# 100
# 100
# 50
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 33
# 100
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 31
# 100
# 27
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 47
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 15
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 94
# 100
# 100
# 40
# 40
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 86
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 95
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 75
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 25
# 47
# 62
# 100
# 100
# 100
# 100
# 100
# 100
# 31
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 59
# 100
# 100
# 100
# 100
# 100
# 77
# 100
# 100
# 25
# 100
# 100
# 47
# 100
# 100
# 31
# 38
# 100
# 67
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 33
# 100
# 100
# 47
# 100
# 50
# 100
# 100
# 100
# 62
# 27
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 43
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 29
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 36
# 100
# 100
# 100
# 100
# 100
# 100
# 62
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 27
# 100
# 100
# 100
# 88
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 15
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 27
# 100
# 100
# 38
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 38
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 27
# 100
# 100
# 100
# 100
# 100
# 38
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 27
# 100
# 100
# 100
# 50
# 100
# 40
# 50
# 100
# 100
# 46
# 100
# 38
# 86
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 33
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 57
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 33
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 14
# 100
# 40
# 100
# 100
# 29
# 43
# 100
# 100
# 100
# 29
# 88
# 100
# 100
# 100
# 100
# 59
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 75
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 46
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 27
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 50
# 20
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 55
# 100
# 100
# 27
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 88
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 27
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 38
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 24
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 44
# 100
# 100
# 100
# 100
# 100
# 47
# 38
# 100
# 100
# 100
# 27
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 36
# 62
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 56
# 47
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 57
# 50
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 38
# 100
# 100
# 100
# 50
# 100
# 100
# 31
# 100
# 18
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 36
# 100
# 100
# 57
# 47
# 100
# 100
# 100
# 100
# 100
# 24
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 31
# 100
# 43
# 31
# 100
# 100
# 100
# 100
# 100
# 62
# 44
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 59
# 100
# 53
# 100
# 38
# 100
# 100
# 100
# 57
# 35
# 35
# 100
# 100
# 17
# 100
# 47
# 33
# 100
# 100
# 100
# 100
# 100
# 40
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 14
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 24
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 67
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 33
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 27
# 100
# 100
# 40
# 100
# 100
# 100
# 57
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 43
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 62
# 100
# 100
# 100
# 100
# 100
# 100
# 88
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 40
# 100
# 100
# 100
# 27
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 57
# 100
# 100
# 100
# 100
# 100
# 25
# 100
# 100
# 75
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 20
# 100
# 100
# 100
# 31
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 46
# 43
# 100
# 100
# 100
# 88
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 31
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 18
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 40
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 46
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 55
# 100
# 100
# 43
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 33
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 46
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 38
# 43
# 100
# 62
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 100
# 44
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 62
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 88
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 62
# 100
# 43
# 100
# 14
# 100
# 100
# 13
# 27
# 100
# 100
# 100
# 59
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 86
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 46
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 36
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 33
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 88
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 60
# 100
# 100
# 100
# 100
# 57
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 25
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 50
# 31
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 14
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 36
# 88
# 100
# 100
# 35
# 100
# 53
# 100
# 100
# 93
# 35
# 43
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 13
# 100
# 100
# 100
# 100
# 100
# 100
# 44
# 100
# 100
# 100
# 62
# 100
# 50
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 18
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 57
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 25
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 88
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 44
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 94
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 50
# 100
# 27
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 27
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 33
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 62
# 100
# 47
# 24
# 100
# 100
# 100
# 100
# 100
# 100
# 33
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 46
# 50
# 100
# 100
# 100
# 100
# 100
# 35
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 93
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 24
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 36
# 100
# 100
# 100
# 15
# 100
# 100
# 100
# 100
# 100
# 24
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 44
# 100
# 100
# 57
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 44
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 53
# 100
# 44
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 31
# 100
# 27
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 25
# 62
# 100
# 100
# 100
# 100
# 100
# 14
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 13
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 14
# 100
# 100
# 40
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 75
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 38
# 53
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 47
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 27
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 44
# 100
# 53
# 100
# 100
# 100
# 100
# 27
# 100
# 47
# 50
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 40
# 100
# 57
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 43
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 38
# 100
# 40
# 100
# 100
# 100
# 100
# 38
# 100
# 100
# 100
# 25
# 100
# 100
# 100
# 100
# 100
# 100
# 40
# 44
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 57
# 100
# 100
# 88
# 100
# 100
# 38
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 88
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 29
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100

# %%
counter = 0
for i in range(len(final_copy_2)):
    if final_copy_2[i] != target_text[i]:
        counter += 1
1- counter/len(final_copy_2)
# Out:
# 0.8339390268524127

# %% [markdown]
# ## testing with the unshuffled data

# %%
test_data = pd.read_csv('./2-NEL_Data/2-csv_format_2/test_data.csv')
test_data = test_data.sample(frac=1, random_state=1)
test_data
# Out:
#             qid                                           question  \
# 8687    Q183862                **what album has metalcore music?**
# 7972   Q1641839               **Name an experimental rock album.**
# 1628  Q17285413                    **Where is joy sengupta from?**
# 8699    Q513674             **What is the sex of matthew breeze?**
# 5648   Q7333580               **what country is  tuxbury pond in**
# ...         ...                                                ...
# 2895    Q200092  **What is the name of a horror movie on netflix**
# 7813   Q7038198        **what kind of film is ninaithen vandhai?**
# 905     Q534599                    **Where did damon knight die?**
# 5192     Q21077   **what artist is signed to warner music group?**
# 235     Q507984         **which country is andrew thorndike from**
#
#                       entity  \
# 8687           **metalcore**
# 7972   **experimental rock**
# 1628        **joy sengupta**
# 8699      **matthew breeze**
# 5648        **tuxbury pond**
# ...                      ...
# 2895        **horror movie**
# 7813   **ninaithen vandhai**
# 905         **damon knight**
# 5192  **warner music group**
# 235     **andrew thorndike**
#
#                                          wikidata_reply
# 8687  **[[Q183862, metalcore, fusion genre of heavy ...
# 7972  **[[Q1641839, experimental rock, type of music...
# 1628  **[[Q17285413, Joy Sengupta, Indian actor and ...
# 8699  **[[Q513674, Matthew Breeze, Australian soccer...
# 5648  **[[Q7333580, Tuxbury Pond, lake in Rockingham...
# ...                                                 ...
# 2895  **[[Q200092, horror film, film genre], [Q59051...
# 7813  **[[Q7038198, Ninaithen Vandhai, 1998 film by ...
# 905   **[[Q534599, Damon Knight, American science fi...
# 5192  **[[Q21077, Warner Music Group, American multi...
# 235   **[[Q507984, Andrew Thorndike, Film director, ...
#
# [9906 rows x 4 columns]

# %%
input_text = list(test_data['question'] + ',' + test_data['entity'] + ',' + test_data['wikidata_reply'])
input_text[0]
# Out:
# '**what album has metalcore music?**,**metalcore**,**[[Q183862, metalcore, fusion genre of heavy metal and hardcore punk], [Q108940567, Metalcore Superstars, album by One Morning Left], [Q4490718, melodic metalcore, subgenre of metalcore], [Q30587784, progressive metalcore, subgenre of metalcore], [Q3501147, gabber metal, fusion of gabber and metal], [Q1965804, Metalcore-bändide loend, Wikimedia list article]]**'

# %%
target_text = list(test_data['qid'])
target_text[0]
# Out:
# 'Q183862'

# %%
X_test_tokenized = tokenizer(['nel: ' + sequence for sequence in input_text], 
                              padding=True, 
                              truncation=True, 
                              max_length=max_source_length)

y_test_tokenized = tokenizer(target_text, 
                              padding=True, 
                              truncation=True, 
                              max_length=max_target_length)

print(len(test_data))
# Out:
# 9906

# %%
from transformers import Seq2SeqTrainingArguments

test_args = Seq2SeqTrainingArguments(
    "test_trainer",
    per_device_train_batch_size = 2,
    per_device_eval_batch_size = 2,
    eval_accumulation_steps = 50,  # VIP
    predict_with_generate=True
)
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
from transformers import Seq2SeqTrainer

trainer = Seq2SeqTrainer(
    model=model, 
    args=test_args
#     train_dataset= train_dataset, 
#     eval_dataset= eval_dataset
)

# %%
test_dataset = Dataset(X_test_tokenized, y_test_tokenized)

# %%
tokens = []
for text in input_text:
    tokens.append(tokenizer('nel: ' + text, return_tensors="pt", padding=True, truncation=True, max_length=512).input_ids)

# %%
results = []
model = model.to(device)

for token in tokens:
    results.append(model.generate(token.to(device)))

# %%
final_ouput_2 = []
for result in results:
    final_ouput_2.append(tokenizer.decode(result[0], skip_special_tokens=True))

# %%
counter = 0
for i in range(len(final_ouput_2)):
    if final_ouput_2[i] != target_text[i]:
        counter += 1
1- counter/len(final_ouput_2)
# Out:
# 0.8921865536038764

# %%
wikidata_data = list(test_data['wikidata_reply'])

# %%
import re
entities = []
for wiki_reply in wikidata_data:
    entities.append(re.findall(r'\[+(Q.*?),', wiki_reply))
len(entities)
# Out:
# 9906

# %%
final_copy = final_ouput_2.copy()
for i in range(len(final_copy)):
    min_value = 10000
    value_to_add = ''
    for entity in entities[i]:
        if get_levenshtein_dis(entity, final_ouput_2[i]) < min_value:
            min_value =  get_levenshtein_dis(entity, final_ouput_2[i])
            value_to_add = entity
    final_copy[i] = value_to_add

# %%
counter = 0
for i in range(len(final_copy)):
    if final_copy[i] != target_text[i]:
        counter += 1
1- counter/len(final_copy)
# Out:
# 0.8924894003634161
