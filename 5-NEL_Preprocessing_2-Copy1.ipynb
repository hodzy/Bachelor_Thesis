# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
def remove_quotes(value):
    value = value.replace("['", "[")
    value = value.replace("']", "]")
    value = value.replace(", '", ", ")
    value = value.replace("',", ",")
    return value

# %%
def remove_outer_bracket(value):
    return value[1:-1]

# %%
def add_asterisks(value):
    return '**' + value + '**'

# %%
# split the data set into 70% train,  20% test, 10% valid
complete_dataset = pd.read_csv('./2-NEL_Data/1-csv_format_1/webqsp_dataset.csv')
len(complete_dataset)
# Out:
# 2990

# %%
train_val = complete_dataset.sample(frac=0.8,random_state=42) #random state is a seed value
web_test = complete_dataset.drop(train_val.index)

# %%
web_val = train_val.sample(frac=0.125,random_state=42)
web_train = train_val.drop(web_val.index)

# %%
web_train = web_train.reset_index(drop=True)
web_test = web_test.reset_index(drop=True)
web_val = web_val.reset_index(drop=True)

# %%
# print(len(web_train))
# print(len(web_train) / len(complete_dataset))
# print(len(web_test))
# print(len(web_test) / len(complete_dataset))
# print(len(web_val))
# print(len(web_val) / len(complete_dataset))

# %%
simple_train = pd.read_csv('./2-NEL_Data/1-csv_format_1/simple_questions_training_dataset.csv')

# %%
training_data = pd.concat([simple_train, web_train])

# %%
training_data['entity'] = training_data['entity'].apply(remove_quotes)
training_data['wikidata_reply'] = training_data['wikidata_reply'].apply(remove_quotes)

# %%
training_data['entity'] = training_data['entity'].apply(remove_outer_bracket)
training_data['wikidata_reply'] = training_data['wikidata_reply'].apply(remove_outer_bracket)

# %%
training_data.reset_index(inplace=True,drop=True)
training_data
# Out:
#             qid                                           question  \
# 0       Q126399             what movie is produced by warner bros.
# 1        Q12439                  who is a musician born in detroit
# 2      Q7370831            who produced the film rough house rosie
# 3      Q6817891  what is the language in which mera shikar was ...
# 4         Q1297  Whats the name of a battle that happened in ch...
# ...         ...                                                ...
# 36462   Q169982           what films has gerard butler starred in?
# 36463      Q717     what are the major sports played in venezuela?
# 36464   Q193695       who played dorothy in the film wizard of oz?
# 36465  Q1024426                                 where is usc from?
# 36466    Q16471  where did the massive allied invasion of north...
#
#                   entity                                     wikidata_reply
# 0           warner bros.  [[Q126399, Warner Bros., American producer of ...
# 1                detroit  [[Q12439, Detroit, city in and county seat of ...
# 2      rough house rosie  [[Q4421558, Rough House Rosie, 1927 film by Fr...
# 3            mera shikar  [[Q6817891, Mera Shikar, 1988 film by Keshu Ra...
# 4                chicago  [[Q1297, Chicago, city and county seat of Cook...
# ...                  ...                                                ...
# 36462      gerard butler  [[Q169982, Gerard Butler, Scottish actor], [Q1...
# 36463          venezuela  [[Q717, Venezuela, sovereign state in northern...
# 36464       wizard of oz  [[Q193695, The Wizard of Oz, 1939 movie based ...
# 36465                usc  [[Q4614, University of Southern California, pr...
# 36466    allied invasion  [[Q217981, Allied invasion of Sicily, 1943 mil...
#
# [36467 rows x 4 columns]

# %%
len(training_data[training_data['wikidata_reply'].str.len() <= 2].index)
# Out:
# 2226

# %%
training_data = training_data.drop(training_data[training_data['wikidata_reply'].str.len() <= 2].index)
training_data.reset_index(inplace=True,drop=True)
training_data
# Out:
#             qid                                           question  \
# 0       Q126399             what movie is produced by warner bros.
# 1        Q12439                  who is a musician born in detroit
# 2      Q7370831            who produced the film rough house rosie
# 3      Q6817891  what is the language in which mera shikar was ...
# 4         Q1297  Whats the name of a battle that happened in ch...
# ...         ...                                                ...
# 34236   Q169982           what films has gerard butler starred in?
# 34237      Q717     what are the major sports played in venezuela?
# 34238   Q193695       who played dorothy in the film wizard of oz?
# 34239  Q1024426                                 where is usc from?
# 34240    Q16471  where did the massive allied invasion of north...
#
#                   entity                                     wikidata_reply
# 0           warner bros.  [[Q126399, Warner Bros., American producer of ...
# 1                detroit  [[Q12439, Detroit, city in and county seat of ...
# 2      rough house rosie  [[Q4421558, Rough House Rosie, 1927 film by Fr...
# 3            mera shikar  [[Q6817891, Mera Shikar, 1988 film by Keshu Ra...
# 4                chicago  [[Q1297, Chicago, city and county seat of Cook...
# ...                  ...                                                ...
# 34236      gerard butler  [[Q169982, Gerard Butler, Scottish actor], [Q1...
# 34237          venezuela  [[Q717, Venezuela, sovereign state in northern...
# 34238       wizard of oz  [[Q193695, The Wizard of Oz, 1939 movie based ...
# 34239                usc  [[Q4614, University of Southern California, pr...
# 34240    allied invasion  [[Q217981, Allied invasion of Sicily, 1943 mil...
#
# [34241 rows x 4 columns]

# %%
training_data['question'] = training_data['question'].apply(add_asterisks)
training_data['entity'] = training_data['entity'].apply(add_asterisks)
training_data['wikidata_reply'] = training_data['wikidata_reply'].apply(add_asterisks)
training_data
# Out:
#             qid                                           question  \
# 0       Q126399         **what movie is produced by warner bros.**
# 1        Q12439              **who is a musician born in detroit**
# 2      Q7370831        **who produced the film rough house rosie**
# 3      Q6817891  **what is the language in which mera shikar wa...
# 4         Q1297  **Whats the name of a battle that happened in ...
# ...         ...                                                ...
# 34236   Q169982       **what films has gerard butler starred in?**
# 34237      Q717  **what are the major sports played in venezuel...
# 34238   Q193695   **who played dorothy in the film wizard of oz?**
# 34239  Q1024426                             **where is usc from?**
# 34240    Q16471  **where did the massive allied invasion of nor...
#
#                       entity  \
# 0           **warner bros.**
# 1                **detroit**
# 2      **rough house rosie**
# 3            **mera shikar**
# 4                **chicago**
# ...                      ...
# 34236      **gerard butler**
# 34237          **venezuela**
# 34238       **wizard of oz**
# 34239                **usc**
# 34240    **allied invasion**
#
#                                           wikidata_reply
# 0      **[[Q126399, Warner Bros., American producer o...
# 1      **[[Q12439, Detroit, city in and county seat o...
# 2      **[[Q4421558, Rough House Rosie, 1927 film by ...
# 3      **[[Q6817891, Mera Shikar, 1988 film by Keshu ...
# 4      **[[Q1297, Chicago, city and county seat of Co...
# ...                                                  ...
# 34236  **[[Q169982, Gerard Butler, Scottish actor], [...
# 34237  **[[Q717, Venezuela, sovereign state in northe...
# 34238  **[[Q193695, The Wizard of Oz, 1939 movie base...
# 34239  **[[Q4614, University of Southern California, ...
# 34240  **[[Q217981, Allied invasion of Sicily, 1943 m...
#
# [34241 rows x 4 columns]

# %%
training_data.to_csv('./2-NEL_Data/2-csv_format_2/training_data.csv', index=False)

# %%
simple_val = pd.read_csv('./2-NEL_Data/1-csv_format_1/simple_questions_val_dataset.csv')

# %%
val_data = pd.concat([simple_val, web_val])

# %%
val_data['entity'] = val_data['entity'].apply(remove_quotes)
val_data['wikidata_reply'] = val_data['wikidata_reply'].apply(remove_quotes)

# %%
val_data['entity'] = val_data['entity'].apply(remove_outer_bracket)
val_data['wikidata_reply'] = val_data['wikidata_reply'].apply(remove_outer_bracket)

# %%
val_data.reset_index(inplace=True,drop=True)
val_data
# Out:
#            qid                                           question  \
# 0     Q3541144  Who was the trump ocean club international hot...
# 1      Q318926                       where was sasha vujačić born
# 2     Q2568216  What is a film directed by wiebke von carolsfeld?
# 3     Q2275923      What was Seymour Parker Gilbert's profession?
# 4     Q2856873       in what french city did antoine de févin die
# ...        ...                                                ...
# 5161   Q325374            where did phil mickelson go to college?
# 5162    Q49542                 what do ethnic russians look like?
# 5163       Q39       what other languages does switzerland speak?
# 5164    Q40715  when did jennifer lopez start on in living color?
# 5165   Q179167                  where did henry hudson come from?
#
#                       entity  \
# 0           trump ocean club
# 1              sasha vujačić
# 2      wiebke von carolsfeld
# 3     Seymour Parker Gilbert
# 4           antoine de févin
# ...                      ...
# 5161          phil mickelson
# 5162                russians
# 5163             switzerland
# 5164          jennifer lopez
# 5165            henry hudson
#
#                                          wikidata_reply
# 0     [[Q3541144, JW Marriott Panama, hotel in Panama]]
# 1     [[Q318926, Sasha Vujačić, Slovenian basketball...
# 2     [[Q2568216, Wiebke Carolsfeld, German film edi...
# 3     [[Q2275923, Seymour Parker Gilbert, American d...
# 4       [[Q2856873, Antoine de Févin, French composer]]
# ...                                                 ...
# 5161  [[Q325374, Phil Mickelson, American profession...
# 5162  [[Q49542, Russians, East Slavic ethnic group, ...
# 5163  [[Q39, Switzerland, country in Central Europe]...
# 5164  [[Q40715, Jennifer Lopez, American artist and ...
# 5165  [[Q179167, Henry Hudson, English explorer b156...
#
# [5166 rows x 4 columns]

# %%
len(val_data[val_data['wikidata_reply'].str.len() <= 2].index)
# Out:
# 329

# %%
val_data=val_data.drop(val_data[val_data['wikidata_reply'].str.len() <= 2].index)
val_data.reset_index(inplace=True,drop=True)
val_data
# Out:
#            qid                                           question  \
# 0     Q3541144  Who was the trump ocean club international hot...
# 1      Q318926                       where was sasha vujačić born
# 2     Q2568216  What is a film directed by wiebke von carolsfeld?
# 3     Q2275923      What was Seymour Parker Gilbert's profession?
# 4     Q2856873       in what french city did antoine de févin die
# ...        ...                                                ...
# 4832   Q325374            where did phil mickelson go to college?
# 4833    Q49542                 what do ethnic russians look like?
# 4834       Q39       what other languages does switzerland speak?
# 4835    Q40715  when did jennifer lopez start on in living color?
# 4836   Q179167                  where did henry hudson come from?
#
#                       entity  \
# 0           trump ocean club
# 1              sasha vujačić
# 2      wiebke von carolsfeld
# 3     Seymour Parker Gilbert
# 4           antoine de févin
# ...                      ...
# 4832          phil mickelson
# 4833                russians
# 4834             switzerland
# 4835          jennifer lopez
# 4836            henry hudson
#
#                                          wikidata_reply
# 0     [[Q3541144, JW Marriott Panama, hotel in Panama]]
# 1     [[Q318926, Sasha Vujačić, Slovenian basketball...
# 2     [[Q2568216, Wiebke Carolsfeld, German film edi...
# 3     [[Q2275923, Seymour Parker Gilbert, American d...
# 4       [[Q2856873, Antoine de Févin, French composer]]
# ...                                                 ...
# 4832  [[Q325374, Phil Mickelson, American profession...
# 4833  [[Q49542, Russians, East Slavic ethnic group, ...
# 4834  [[Q39, Switzerland, country in Central Europe]...
# 4835  [[Q40715, Jennifer Lopez, American artist and ...
# 4836  [[Q179167, Henry Hudson, English explorer b156...
#
# [4837 rows x 4 columns]

# %%
val_data['question'] = val_data['question'].apply(add_asterisks)
val_data['entity'] = val_data['entity'].apply(add_asterisks)
val_data['wikidata_reply'] = val_data['wikidata_reply'].apply(add_asterisks)
val_data
# Out:
#            qid                                           question  \
# 0     Q3541144  **Who was the trump ocean club international h...
# 1      Q318926                   **where was sasha vujačić born**
# 2     Q2568216  **What is a film directed by wiebke von carols...
# 3     Q2275923  **What was Seymour Parker Gilbert's profession?**
# 4     Q2856873   **in what french city did antoine de févin die**
# ...        ...                                                ...
# 4832   Q325374        **where did phil mickelson go to college?**
# 4833    Q49542             **what do ethnic russians look like?**
# 4834       Q39   **what other languages does switzerland speak?**
# 4835    Q40715  **when did jennifer lopez start on in living c...
# 4836   Q179167              **where did henry hudson come from?**
#
#                           entity  \
# 0           **trump ocean club**
# 1              **sasha vujačić**
# 2      **wiebke von carolsfeld**
# 3     **Seymour Parker Gilbert**
# 4           **antoine de févin**
# ...                          ...
# 4832          **phil mickelson**
# 4833                **russians**
# 4834             **switzerland**
# 4835          **jennifer lopez**
# 4836            **henry hudson**
#
#                                          wikidata_reply
# 0     **[[Q3541144, JW Marriott Panama, hotel in Pan...
# 1     **[[Q318926, Sasha Vujačić, Slovenian basketba...
# 2     **[[Q2568216, Wiebke Carolsfeld, German film e...
# 3     **[[Q2275923, Seymour Parker Gilbert, American...
# 4     **[[Q2856873, Antoine de Févin, French compose...
# ...                                                 ...
# 4832  **[[Q325374, Phil Mickelson, American professi...
# 4833  **[[Q49542, Russians, East Slavic ethnic group...
# 4834  **[[Q39, Switzerland, country in Central Europ...
# 4835  **[[Q40715, Jennifer Lopez, American artist an...
# 4836  **[[Q179167, Henry Hudson, English explorer b1...
#
# [4837 rows x 4 columns]

# %%
val_data.to_csv('./2-NEL_Data/2-csv_format_2/val_data.csv', index=False)

# %%
simple_test = pd.read_csv('./2-NEL_Data/1-csv_format_1/simple_questions_test_dataset.csv')

# %%
test_data = pd.concat([simple_test, web_test])

# %%
test_data['entity'] = test_data['entity'].apply(remove_quotes)
test_data['wikidata_reply'] = test_data['wikidata_reply'].apply(remove_quotes)

# %%
test_data['entity'] = test_data['entity'].apply(remove_outer_bracket)
test_data['wikidata_reply'] = test_data['wikidata_reply'].apply(remove_outer_bracket)

# %%
test_data.reset_index(inplace=True,drop=True)
test_data
# Out:
#              qid                                    question           entity  \
# 0       Q5487302  Which genre of album is harder.....faster?
# 1      Q16330302           what city was alex golfis born in      alex golfis
# 2      Q16225521        what film is by the writer phil hay?         phil hay
# 3       Q7358590                 Where did roger marquis die    roger marquis
# 4        Q154335   what was the cause of death of yves klein       yves klein
# ...          ...                                         ...              ...
# 10554     Q74394              where is fresno texas located?     fresno texas
# 10555        Q96    what type of government does mexico use?           mexico
# 10556    Q270975                  what team rasheed wallace?  rasheed wallace
# 10557    Q706908    what team does pudge rodriguez play for?  pudge rodriguez
# 10558    Q126599     what movies did kristen stewart act in?  kristen stewart
#
#                                           wikidata_reply
# 0
# 1      [[Q16330302, Alex Golfis, Greek actor (1948-20...
# 2      [[Q16225521, Phil Hay, screenwriter], [Q718198...
# 3      [[Q7358592, Roger Marquis, 2nd Earl of Woolton...
# 4      [[Q154335, Yves Klein, 20th century French vis...
# ...                                                  ...
# 10554                                                 []
# 10555  [[Q96, Mexico, sovereign state in North Americ...
# 10556  [[Q270975, Rasheed Wallace, American basketbal...
# 10557  [[Q706908, Iván Rodríguez, Puerto Rican Hall o...
# 10558  [[Q126599, Kristen Stewart, American actress a...
#
# [10559 rows x 4 columns]

# %%
len(test_data[test_data['wikidata_reply'].str.len() <= 2].index)
# Out:
# 653

# %%
test_data=test_data.drop(test_data[test_data['wikidata_reply'].str.len() <= 2].index)
test_data.reset_index(inplace=True,drop=True)

# %%
test_data['question'] = test_data['question'].apply(add_asterisks)
test_data['entity'] = test_data['entity'].apply(add_asterisks)
test_data['wikidata_reply'] = test_data['wikidata_reply'].apply(add_asterisks)

# %%
test_data
# Out:
#             qid                                       question  \
# 0     Q16330302          **what city was alex golfis born in**
# 1     Q16225521       **what film is by the writer phil hay?**
# 2      Q7358590                **Where did roger marquis die**
# 3       Q154335  **what was the cause of death of yves klein**
# 4         Q1761       **Which equestrian was born in dublin?**
# ...         ...                                            ...
# 9901    Q242654     **what party did paul keating belong to?**
# 9902        Q96   **what type of government does mexico use?**
# 9903    Q270975                 **what team rasheed wallace?**
# 9904    Q706908   **what team does pudge rodriguez play for?**
# 9905    Q126599    **what movies did kristen stewart act in?**
#
#                    entity                                     wikidata_reply
# 0         **alex golfis**  **[[Q16330302, Alex Golfis, Greek actor (1948-...
# 1            **phil hay**  **[[Q16225521, Phil Hay, screenwriter], [Q7181...
# 2       **roger marquis**  **[[Q7358592, Roger Marquis, 2nd Earl of Woolt...
# 3          **yves klein**  **[[Q154335, Yves Klein, 20th century French v...
# 4              **dublin**  **[[Q1761, Dublin, capital city of Ireland], [...
# ...                   ...                                                ...
# 9901     **paul keating**  **[[Q242654, Paul Keating, Australian politici...
# 9902           **mexico**  **[[Q96, Mexico, sovereign state in North Amer...
# 9903  **rasheed wallace**  **[[Q270975, Rasheed Wallace, American basketb...
# 9904  **pudge rodriguez**  **[[Q706908, Iván Rodríguez, Puerto Rican Hall...
# 9905  **kristen stewart**  **[[Q126599, Kristen Stewart, American actress...
#
# [9906 rows x 4 columns]

# %%
test_data.to_csv('./2-NEL_Data/2-csv_format_2/test_data.csv', index=False)
