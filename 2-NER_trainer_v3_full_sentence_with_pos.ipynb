# %%
# !pip install wandb
# !pip install transformers
# !pip install sentencepiece

import os
# os.environ['CUDA_LAUNCH_BLOCKING'] = '1' 
# os.environ["CUDA_VISIBLE_DEVICES"] = "0,1,3" 

import pandas as pd
import numpy as np
import re
import torch
import torchvision
from torch.utils.data import Dataset, DataLoader
import math
import torch.optim as optim
import wandb
from sklearn.metrics import accuracy_score, precision_recall_fscore_support


wandb.login()
# %env WANDB_PROJECT= NER_full_sentence

# os.environ["WANDB_DISABLED"] = "true"

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
# Out:
# env: WANDB_PROJECT=NER_full_sentence

# %%
# Create torch dataset
# https://towardsdatascience.com/fine-tuning-pretrained-nlp-models-with-huggingfaces-trainer-6326a4456e7b

class Dataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels=None):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        if self.labels:
            item["labels"] = torch.tensor(self.labels['input_ids'][idx])
        return item

    def __len__(self):
        return len(self.encodings["input_ids"])

# %%
def compute_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)
    precision, recall, f1, _ = precision_recall_fscore_support(labels, preds, average='micro')
#     _, _, f1, _ = precision_recall_fscore_support(labels, preds, average='binary')
    return {
        'f1': f1,
        'precision': precision,
        'recall': recall
    }

# %%
max_source_length = 512
max_target_length = 512

# %%
from transformers import T5TokenizerFast, T5ForConditionalGeneration 
from transformers import EarlyStoppingCallback

tokenizer = T5TokenizerFast.from_pretrained("t5-base")
model = T5ForConditionalGeneration.from_pretrained("t5-base").to(device)

# %%
# training_sample = training_data.sample(frac=0.4, random_state=1)

training_data = pd.read_csv('./1-NER_Data/1-csv_format/train/training_data_full_sentence_with_pos.csv')
# training_data = pd.read_csv('./1-NER_Data/1-csv_format/train/lower_normal_training.csv')

training_data = training_data.sample(frac=1, random_state=1).reset_index(drop=True)
training_data['target_text_length'] = training_data['target_text'].apply(lambda x: len(x))
training_data
# Out:
#                                                input_text  \
# 0       Often the Lao will refer to themselves as " lu...
# 1       Discrepancies go unexplained in `` Confidentia...
# 2       Since 1987 an illustration of the castle has b...
# 3       The Cibola National Forest conserves large nat...
# 4       At the 1984 Summer Olympics in Los Angeles he ...
# ...                                                   ...
# 152545  The annual Grand National horse race takes pla...
# 152546  [bingladen] Poster : bingladen-LRB-sssssr-RRB-...
# 152547  Other disease-causing bacteria in this family ...
# 152548                        Cercle Brugge 4 0 3 1 4 5 3
# 152549  Any settlement is also expected to exclude Mr....
#
#                                               target_text  word_count  \
# 0       Often the *s* Lao | MISC *e* will refer to the...          22
# 1       Discrepancies go unexplained in `` *s* Confide...          57
# 2       Since 1987 an illustration of the castle has b...          24
# 3       The *s* Cibola National Forest | LOC *e* conse...          17
# 4       At the *s* 1984 Summer Olympics | MISC *e* in ...          19
# ...                                                   ...         ...
# 152545  The annual *s* Grand National | MISC *e* horse...          11
# 152546  [bingladen] Poster : bingladen-LRB-sssssr-RRB-...           7
# 152547  Other disease-causing bacteria in this family ...          10
# 152548          *s* Cercle Brugge | ORG *e* 4 0 3 1 4 5 3           9
# 152549  Any settlement is also expected to exclude Mr....          23
#
#         NE_count  %_NE_in_sentence  target_text_length
# 0              1               0.0                 148
# 1              3               0.1                 395
# 2              4               0.2                 146
# 3              3               0.2                 132
# 4              5               0.3                 127
# ...          ...               ...                 ...
# 152545         4               0.4                 101
# 152546         0               0.0                  65
# 152547         2               0.2                 122
# 152548         2               0.2                  41
# 152549         3               0.1                 166
#
# [152550 rows x 6 columns]

# %%
training_data[training_data['input_text'].str.contains('Cercle Brugge')]
# Out:
#                                                input_text  \
# 54325   Cup Winners ' Cup x-Cercle Brugge ( Belgium ) ...
# 143147                         Cercle Brugge 2 Mouscron 2
# 152548                        Cercle Brugge 4 0 3 1 4 5 3
#
#                                               target_text  word_count  \
# 54325   *s* Cup Winners ' Cup | MISC *e* *s* x-Cercle ...          10
# 143147  *s* Cercle Brugge | ORG *e* 2 *s* Mouscron | O...           5
# 152548          *s* Cercle Brugge | ORG *e* 4 0 3 1 4 5 3           9
#
#         NE_count  %_NE_in_sentence  target_text_length
# 54325          9               0.9                 142
# 143147         3               0.6                  54
# 152548         2               0.2                  41

# %%
len(training_data[training_data['target_text_length']> 512])
# Out:
# 300

# %%
len(training_data[training_data['target_text_length']> 512])*100/len(training_data)
# Out:
# 0.19665683382497542

# %%
training_data = training_data.drop(training_data[training_data['target_text_length']> 512].index)
training_data
# Out:
#                                                input_text  \
# 0       Often the Lao will refer to themselves as " lu...
# 1       Discrepancies go unexplained in `` Confidentia...
# 2       Since 1987 an illustration of the castle has b...
# 3       The Cibola National Forest conserves large nat...
# 4       At the 1984 Summer Olympics in Los Angeles he ...
# ...                                                   ...
# 152545  The annual Grand National horse race takes pla...
# 152546  [bingladen] Poster : bingladen-LRB-sssssr-RRB-...
# 152547  Other disease-causing bacteria in this family ...
# 152548                        Cercle Brugge 4 0 3 1 4 5 3
# 152549  Any settlement is also expected to exclude Mr....
#
#                                               target_text  word_count  \
# 0       Often the *s* Lao | MISC *e* will refer to the...          22
# 1       Discrepancies go unexplained in `` *s* Confide...          57
# 2       Since 1987 an illustration of the castle has b...          24
# 3       The *s* Cibola National Forest | LOC *e* conse...          17
# 4       At the *s* 1984 Summer Olympics | MISC *e* in ...          19
# ...                                                   ...         ...
# 152545  The annual *s* Grand National | MISC *e* horse...          11
# 152546  [bingladen] Poster : bingladen-LRB-sssssr-RRB-...           7
# 152547  Other disease-causing bacteria in this family ...          10
# 152548          *s* Cercle Brugge | ORG *e* 4 0 3 1 4 5 3           9
# 152549  Any settlement is also expected to exclude Mr....          23
#
#         NE_count  %_NE_in_sentence  target_text_length
# 0              1               0.0                 148
# 1              3               0.1                 395
# 2              4               0.2                 146
# 3              3               0.2                 132
# 4              5               0.3                 127
# ...          ...               ...                 ...
# 152545         4               0.4                 101
# 152546         0               0.0                  65
# 152547         2               0.2                 122
# 152548         2               0.2                  41
# 152549         3               0.1                 166
#
# [152250 rows x 6 columns]

# %%
X_train_tokenized = tokenizer(['ner: ' + sequence for sequence in training_data["input_text"]], 
                              padding=True, 
                              truncation=True, 
                              max_length=max_source_length)

y_train_tokenized = tokenizer(list(training_data["target_text"]), 
                              padding=True, 
                              truncation=True, 
                              max_length=max_target_length)

print(len(training_data))
# print(len(training_sample))
# Out:
# 152250

# %%
validation_data = pd.read_csv('./1-NER_Data/1-csv_format/val/val_data_full_sentence_with_pos.csv')
validation_data = validation_data.sample(frac=1, random_state=1).reset_index(drop=True)
validation_data['target_text_length'] = validation_data['target_text'].apply(lambda x: len(x))
validation_data
# Out:
#                                               input_text  \
# 0      In about 1837 the orangery was replaced by a l...
# 1      It has been also noted for its visibly irrever...
# 2      For example , Nikolai Durov has introduced com...
# 3      Its wildlife includes Persian leopards , brown...
# 4                     I would view it as a net positive.
# ...                                                  ...
# 24822  In March 2012 , he was fined for parking illeg...
# 24823  This is a potential problem for the developmen...
# 24824  None of them would , so he became another pres...
# 24825  The three American jumpers had been easily the...
# 24826                               CHICAGO 65 66 .496 5
#
#                                              target_text  word_count  \
# 0      In about 1837 the orangery was replaced by a l...          15
# 1      It has been also noted for its visibly irrever...          26
# 2      For example , *s* Nikolai Durov | PER *e* has ...          20
# 3      Its wildlife includes *s* Persian | MISC *e* l...          15
# 4                     I would view it as a net positive.           8
# ...                                                  ...         ...
# 24822  In March 2012 , he was fined for parking illeg...          14
# 24823  This is a potential problem for the developmen...          14
# 24824  None of them would , so he became another pres...          21
# 24825  The three *s* American | MISC *e* jumpers had ...          13
# 24826                 *s* CHICAGO | ORG *e* 65 66 .496 5           5
#
#        NE_count  %_NE_in_sentence  target_text_length
# 0             2               0.1                 105
# 1             1               0.0                 172
# 2             2               0.1                 160
# 3             1               0.1                 128
# 4             0               0.0                  34
# ...         ...               ...                 ...
# 24822         1               0.1                  94
# 24823         1               0.1                 104
# 24824         1               0.0                 163
# 24825         1               0.1                  95
# 24826         1               0.2                  34
#
# [24827 rows x 6 columns]

# %%
validation_data = validation_data.drop(validation_data[validation_data['target_text_length']> 512].index)
validation_data
# Out:
#                                               input_text  \
# 0      In about 1837 the orangery was replaced by a l...
# 1      It has been also noted for its visibly irrever...
# 2      For example , Nikolai Durov has introduced com...
# 3      Its wildlife includes Persian leopards , brown...
# 4                     I would view it as a net positive.
# ...                                                  ...
# 24822  In March 2012 , he was fined for parking illeg...
# 24823  This is a potential problem for the developmen...
# 24824  None of them would , so he became another pres...
# 24825  The three American jumpers had been easily the...
# 24826                               CHICAGO 65 66 .496 5
#
#                                              target_text  word_count  \
# 0      In about 1837 the orangery was replaced by a l...          15
# 1      It has been also noted for its visibly irrever...          26
# 2      For example , *s* Nikolai Durov | PER *e* has ...          20
# 3      Its wildlife includes *s* Persian | MISC *e* l...          15
# 4                     I would view it as a net positive.           8
# ...                                                  ...         ...
# 24822  In March 2012 , he was fined for parking illeg...          14
# 24823  This is a potential problem for the developmen...          14
# 24824  None of them would , so he became another pres...          21
# 24825  The three *s* American | MISC *e* jumpers had ...          13
# 24826                 *s* CHICAGO | ORG *e* 65 66 .496 5           5
#
#        NE_count  %_NE_in_sentence  target_text_length
# 0             2               0.1                 105
# 1             1               0.0                 172
# 2             2               0.1                 160
# 3             1               0.1                 128
# 4             0               0.0                  34
# ...         ...               ...                 ...
# 24822         1               0.1                  94
# 24823         1               0.1                 104
# 24824         1               0.0                 163
# 24825         1               0.1                  95
# 24826         1               0.2                  34
#
# [24779 rows x 6 columns]

# %%
X_val_tokenized = tokenizer(['ner: ' + sequence for sequence in validation_data["input_text"]], 
                              padding=True, 
                              truncation=True, 
                              max_length=max_source_length)

y_val_tokenized = tokenizer(list(validation_data["target_text"]), 
                              padding=True, 
                              truncation=True, 
                              max_length=max_target_length)

print(len(validation_data))
# print(len(training_sample))
# Out:
# 24779

# %%
train_dataset = Dataset(X_train_tokenized, y_train_tokenized)

# %%
val_dataset = Dataset(X_val_tokenized, y_val_tokenized)

# %%
from transformers import Seq2SeqTrainingArguments

# training_args = Seq2SeqTrainingArguments(
#     "NER_lower",
#     evaluation_strategy ='steps',
#     eval_steps = 500, # Evaluation and Save happens every 500 steps
#     save_total_limit = 5, # Only last 5 models are saved. Older ones are deleted.
#     per_device_train_batch_size = 8,
#     per_device_eval_batch_size = 8,
#     learning_rate = 1e-3,
#     adam_epsilon = 1e-8,
#     num_train_epochs = 6,
#     report_to="wandb",
# #     metric_for_best_model = 'f1',
#     load_best_model_at_end=True
# )


training_args = Seq2SeqTrainingArguments(
    "NER_full_sent_with_pos_add_space_before_bracket_diff_seperators_v3",
#     evaluation_strategy ='epoch',
    evaluation_strategy ='steps',
    eval_steps = 2380, # Evaluation and Save happens every 3743 steps (steps/(num of epochs*2))
    logging_steps = 500,
    save_steps = 2380,
    save_total_limit = 5, # Only last 5 models are saved. Older ones are deleted.
    per_device_train_batch_size = 4,
    per_device_eval_batch_size = 4,
    
    gradient_accumulation_steps =2,
    
    learning_rate = 1e-3,
    adam_epsilon = 1e-8,
    num_train_epochs = 10,
    report_to="wandb",
#     metric_for_best_model = 'f1',
    load_best_model_at_end=True
)

# %%
from transformers import Seq2SeqTrainer

trainer = Seq2SeqTrainer(
    model=model, 
    args=training_args, 
#     compute_metrics=compute_metrics,
    train_dataset= train_dataset,
    eval_dataset = val_dataset,
    callbacks = [EarlyStoppingCallback(early_stopping_patience=5)]
)

# %%
trainer.train()
# Out:
# /home/HadyElkady/miniconda3/lib/python3.7/site-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use thePyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 152250
#   Num Epochs = 10
#   Instantaneous batch size per device = 4
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 2
#   Total optimization steps = 47580
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href="https://wandb.me/wandb-init" target="_blank">the W&B docs</a>.
# Tracking run with wandb version 0.12.17
# Run data is saved locally in <code>/home/HadyElkady/work/Bachelor_thesis/wandb/run-20220827_224625-14aqitbo</code>
# Syncing run <strong><a href="https://wandb.ai/hodz199/NER_full_sentence/runs/14aqitbo" target="_blank">NER_full_sent_with_pos_add_space_before_bracket_diff_seperators_v3</a></strong> to <a href="https://wandb.ai/hodz199/NER_full_sentence" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# /home/HadyElkady/miniconda3/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#     <div>
#
#       <progress value='7141' max='47580' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 7141/47580 2:53:24 < 16:22:17, 0.69 it/s, Epoch 1.50/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>2380</td>
#       <td>0.006100</td>
#       <td>0.004330</td>
#     </tr>
#     <tr>
#       <td>4760</td>
#       <td>0.005200</td>
#       <td>0.003689</td>
#     </tr>
#     <tr>
#       <td>7140</td>
#       <td>0.004100</td>
#       <td>0.003873</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 24779
#   Batch size = 16
# Saving model checkpoint to NER_full_sent_with_pos_add_space_before_bracket_diff_seperators_v3/checkpoint-2380
# Configuration saved in NER_full_sent_with_pos_add_space_before_bracket_diff_seperators_v3/checkpoint-2380/config.json
# Model weights saved in NER_full_sent_with_pos_add_space_before_bracket_diff_seperators_v3/checkpoint-2380/pytorch_model.bin
# /home/HadyElkady/miniconda3/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 24779
#   Batch size = 16
# Saving model checkpoint to NER_full_sent_with_pos_add_space_before_bracket_diff_seperators_v3/checkpoint-4760
# Configuration saved in NER_full_sent_with_pos_add_space_before_bracket_diff_seperators_v3/checkpoint-4760/config.json
# Model weights saved in NER_full_sent_with_pos_add_space_before_bracket_diff_seperators_v3/checkpoint-4760/pytorch_model.bin
# /home/HadyElkady/miniconda3/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# ***** Running Evaluation *****
#   Num examples = 24779
#   Batch size = 16
# Saving model checkpoint to NER_full_sent_with_pos_add_space_before_bracket_diff_seperators_v3/checkpoint-7140
# Configuration saved in NER_full_sent_with_pos_add_space_before_bracket_diff_seperators_v3/checkpoint-7140/config.json
# Model weights saved in NER_full_sent_with_pos_add_space_before_bracket_diff_seperators_v3/checkpoint-7140/pytorch_model.bin
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/miniconda3/lib/python3.7/site-packages/torch/serialization.py in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization)
#     378             with _open_zipfile_writer(opened_file) as opened_zipfile:
# --> 379                 _save(obj, opened_zipfile, pickle_module, pickle_protocol)
#     380                 return
#
# ~/miniconda3/lib/python3.7/site-packages/torch/serialization.py in _save(obj, zip_file, pickle_module, pickle_protocol)
#     498         num_bytes = storage.size() * storage.element_size()
# --> 499         zip_file.write_record(name, storage.data_ptr(), num_bytes)
#     500
#
# OSError: [Errno 28] No space left on device
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-25-3435b262f1ae> in <module>
# ----> 1 trainer.train()
#
# ~/miniconda3/lib/python3.7/site-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1438                     self.control = self.callback_handler.on_step_end(args, self.state, self.control)
#    1439
# -> 1440                     self._maybe_log_save_evaluate(tr_loss, model, trial, epoch, ignore_keys_for_eval)
#    1441                 else:
#    1442                     self.control = self.callback_handler.on_substep_end(args, self.state, self.control)
#
# ~/miniconda3/lib/python3.7/site-packages/transformers/trainer.py in _maybe_log_save_evaluate(self, tr_loss, model, trial, epoch, ignore_keys_for_eval)
#    1567
#    1568         if self.control.should_save:
# -> 1569             self._save_checkpoint(model, trial, metrics=metrics)
#    1570             self.control = self.callback_handler.on_save(self.args, self.state, self.control)
#    1571
#
# ~/miniconda3/lib/python3.7/site-packages/transformers/trainer.py in _save_checkpoint(self, model, trial, metrics)
#    1665         elif self.args.should_save and not self.deepspeed:
#    1666             # deepspeed.save_checkpoint above saves model/optim/sched
# -> 1667             torch.save(self.optimizer.state_dict(), os.path.join(output_dir, OPTIMIZER_NAME))
#    1668             with warnings.catch_warnings(record=True) as caught_warnings:
#    1669                 torch.save(self.lr_scheduler.state_dict(), os.path.join(output_dir, SCHEDULER_NAME))
#
# ~/miniconda3/lib/python3.7/site-packages/torch/serialization.py in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization)
#     378             with _open_zipfile_writer(opened_file) as opened_zipfile:
#     379                 _save(obj, opened_zipfile, pickle_module, pickle_protocol)
# --> 380                 return
#     381         _legacy_save(obj, opened_file, pickle_module, pickle_protocol)
#     382
#
# ~/miniconda3/lib/python3.7/site-packages/torch/serialization.py in __exit__(self, *args)
#     257
#     258     def __exit__(self, *args) -> None:
# --> 259         self.file_like.write_end_of_file()
#     260         self.buffer.flush()
#     261
#
# RuntimeError: [enforce fail at inline_container.cc:300] . unexpected pos 1058835008 vs 1058834896

# %%
print('finished')
